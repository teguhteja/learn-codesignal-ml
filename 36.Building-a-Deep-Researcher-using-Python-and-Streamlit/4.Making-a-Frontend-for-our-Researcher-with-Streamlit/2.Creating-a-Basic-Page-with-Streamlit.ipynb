# %% [markdown]
# # Unit 2

# %% [markdown]
# ## Creating a Basic Page with Streamlit
#
# ## Introduction: Building Your First DeepResearcher Page
#
# Welcome back\! In the last lesson, you learned what **Streamlit** is and how it helps you build interactive web apps using Python. Now, you are ready to take the next step and create the main page for your **DeepResearcher** tool.
#
# In this lesson, you will learn how to:
#
#   * Add a title and helpful instructions to your app
#   * Collect user input using simple widgets
#   * Put everything together to create a clean, interactive page
#
# By the end of this lesson, you will have a working starting point for your **DeepResearcher** frontend. This page will be the foundation for all the features you add in future lessons.
#
# -----
#
# ## Structuring the Page: Titles and Descriptions
#
# A good app starts with a clear title and some helpful instructions. In **Streamlit**, you can do this with `st.title()`, `st.write()`, and `st.markdown()`.
#
# Let's start by setting up the page title.
#
# ```python
# import streamlit as st
# st.title("🧠 DeepResearcher")
# ```
#
# `st.title()` displays a large, bold title at the top of your app. Here, we use an emoji and the name of our tool to make it stand out.
#
# Next, let's add a short description to tell users what the app does. You can use `st.write()` or `st.markdown()` for this. Both work for simple text, but `st.markdown()` lets you use Markdown formatting if you want.
#
# ```python
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
# ```
#
# This line adds a short, clear description under the title.
#
# -----
#
# ## Adding User Inputs with Widgets
#
# Now, let's make the page interactive by adding **widgets**. Widgets are elements like text boxes, sliders, and buttons that let users provide input to your app.
#
# ### Text Input
#
# To let users enter their research topic, use `st.text_input()`:
#
# ```python
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
# ```
#
#   * The first argument is the **label** shown above the input box.
#   * The `placeholder` shows a hint inside the box until the user types something.
#   * The value the user enters is stored in the `user_query` variable.
#
# ### Slider
#
# Suppose you want users to choose how many research iterations the tool should run. You can use `st.slider()`:
#
# ```python
# max_iterations = st.slider("Max research iterations", 1, 10, 3)
# ```
#
#   * The first argument is the **label**.
#   * The next two numbers are the **minimum and maximum values** (1 to 10).
#   * The last number is the **default value** (3).
#
# ### Button
#
# To let users start the research process, add a button:
#
# ```python
# button = st.button("Run Research")
# ```
#
#   * The label on the button is **"Run Research."**
#   * When the user clicks the button, `button` becomes `True` for that run.
#
# -----
#
# ## Complete Example: Putting It All Together
#
# Let's combine everything into a single app page. Here's how the code looks when you put all the pieces together:
#
# ```python
# import streamlit as st
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # User input
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
#
# # Iteration slider
# max_iterations = st.slider("Max research iterations", 1, 10, 3)
#
# # Submit button
# button = st.button("Run Research")
# ```
#
# What happens in this code:
#
#   * The page is given a title and a description.
#   * The user can type in a research topic.
#   * The user can choose the number of research iterations.
#   * The user can click a button to start the research.
#
# This simple layout is the starting point for your **DeepResearcher** frontend.
#
# -----
#
# ## Summary And What's Next
#
# In this lesson, you learned how to:
#
#   * Add a title and description to your **Streamlit** app
#   * Collect user input with **text boxes, sliders, and buttons**
#   * Combine these elements to create a clean, interactive page
#
# This basic page is the foundation for your **DeepResearcher** tool. In the next practice exercises, you'll get hands-on experience building and customizing this page. Soon, you'll be ready to add more advanced features and make your research assistant even smarter\!
#
# Would you like to review the specific syntax for any of the widgets, like `st.text_input()` or `st.slider()`, before moving on to the exercises?

# %% [markdown]
# ## Building Your First Streamlit Page
#
# Now that you've learned about Streamlit and its capabilities, let's put that knowledge into practice! In this exercise, you'll create the basic structure for your DeepResearcher app.
#
# Your task is to build the foundation of your app by:
#
# Setting up the page configuration with a title and a centered layout
# Adding a clear, eye-catching title with an emoji
# Including a brief description that explains what your app does
# This exercise focuses on creating a clean visual structure before we add any interactive elements. When you run your code, you should see your title and description displayed neatly on the page.
#
# Building this foundation is an important first step — it gives users immediate context about your app and sets the stage for all the interactive features we'll add later!
#
# ```python
# import streamlit as st
#
# # TODO: Set the page configuration with title "DeepResearcher" and centered layout
#
# # TODO: Add a title with "🧠 DeepResearcher"
#
# # TODO: Add a description explaining what the app does
#
# ```
#
# Here is the completed `app.py` file with the basic structure for your DeepResearcher page:
#
# ```python
# import streamlit as st
#
# # TODO: Set the page configuration with title "DeepResearcher" and centered layout
# st.set_page_config(page_title="DeepResearcher", layout="centered")
#
# # TODO: Add a title with "🧠 DeepResearcher"
# st.title("🧠 DeepResearcher")
#
# # TODO: Add a description explaining what the app does
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
# # Alternatively, using markdown for a more prominent description:
# # st.markdown("AI-powered research assistant that performs real-time web exploration and synthesis.")
# ```
#
# -----
#
# ## ✅ Explanation of the Code
#
# 1.  **`st.set_page_config(...)`**: This is usually the first Streamlit command in your script. It configures settings that apply to the entire browser tab, specifically:
#       * `page_title="DeepResearcher"`: Sets the text that appears in the **browser tab** title.
#       * `layout="centered"`: Makes the main content area of the app **narrow and centered** for a cleaner look, which is often preferred for text-heavy applications.
# 2.  **`st.title("🧠 DeepResearcher")`**: Displays a large, prominent title on the page itself.
# 3.  **`st.write(...)`**: A versatile command used here to add a simple line of text underneath the title, providing the user with an immediate understanding of the app's function.
#
# Your next step is to run this script\! Would you like a reminder of the command to run your app?

# %% [markdown]
# ## Adding User Input to Your App
#
# Excellent job setting up the basic structure of your app! Now, let's make it interactive by adding a way for users to tell your app what they want to research.
#
# In this exercise, you'll add a text input widget — the primary way users will communicate with your research assistant.
#
# Your task is to:
#
# Add a text input widget using st.text_input()
# Label it clearly as "Enter your research topic:"
# Include a helpful placeholder, such as "e.g. Impact of AI in healthcare"
# Store what the user types in a variable called user_query
# This text input is the heart of your app's functionality — it's where the research journey begins! By adding this interactive element, you're transforming your app from a static page into a tool that responds to what your users need.
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # TODO: Add a text input widget with the label "Enter your research topic:"
# # and placeholder "e.g. Impact of AI in healthcare"
# # Store the result in a variable called user_query
#
# # Display what the user entered (optional)
# # Uncomment the code below once you've created the user_query variable
# # if user_query:
# #     st.write(f"Researching: {user_query}")
#
# ```
#
# Here is the completed `app.py` file with the interactive text input widget, fulfilling your task:
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # TODO: Add a text input widget with the label "Enter your research topic:"
# # and placeholder "e.g. Impact of AI in healthcare"
# # Store the result in a variable called user_query
# user_query = st.text_input(
#     "Enter your research topic:",
#     placeholder="e.g. Impact of AI in healthcare"
# )
#
# # Display what the user entered (optional)
# # Uncomment the code below once you've created the user_query variable
# if user_query:
#     st.write(f"🔍 Researching: **{user_query}**")
# ```
#
# -----
#
# ## 🛠️ Key Component Added
#
# The core addition is the line:
#
# ```python
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
# ```
#
#   * **`st.text_input()`**: This function displays a text box on your app.
#   * The first argument is the **label** that tells the user what to type.
#   * The `placeholder` provides a **hint** inside the empty box.
#   * The key is that the text the user types is **automatically stored** in the `user_query` variable, which you can use later in your script.
#
# The optional display code (`if user_query: st.write(...)`) demonstrates Streamlit's reactivity: as soon as the user finishes typing and presses Enter (or clicks outside the box), the entire script reruns, and the app displays the confirmation text.
#
# Would you like to continue building the DeepResearcher app by adding the next interactive element, the **slider**?

# %% [markdown]
# ## Adding a Research Depth Slider
#
# Fantastic work adding the text input to your app! Now, let's give users more control over their research by adding a slider widget.
#
# In this exercise, you'll create a slider that lets users specify how many iterations of research they want the AI to perform. This gives them control over how deep the research goes.
#
# Your task is to:
#
# Add a slider widget labeled "Max research iterations"
# Set it to accept values from 1 to 10, with 3 as the default
# Store the selected value in a variable called max_iterations
# Display a message showing the user which value they've selected
# This slider adds another layer of interactivity to your app, making it more flexible and user-friendly. When you complete this exercise, your app will be one step closer to becoming a fully functional research assistant!
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # User input
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
#
# # TODO: Add a slider for "Max research iterations" with range from 1 to 10 and default value of 3
# # Store the result in a variable called max_iterations
#
# # TODO: Display the chosen number of iterations to the user
# ```
#
# That's the perfect next step for adding flexibility to your app\! Here is the completed `app.py` file with the interactive slider widget:
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # User input
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
#
# # TODO: Add a slider for "Max research iterations" with range from 1 to 10 and default value of 3
# # Store the result in a variable called max_iterations
# max_iterations = st.slider(
#     "Max research iterations",  # Label
#     1,                          # Minimum value
#     10,                         # Maximum value
#     3                           # Default value
# )
#
# # TODO: Display the chosen number of iterations to the user
# st.info(f"Depth set to **{max_iterations}** research iterations.")
# ```
#
# -----
#
# ## ⚙️ How the Slider Works
#
# The key addition is the `st.slider()` function:
#
# ```python
# max_iterations = st.slider("Max research iterations", 1, 10, 3)
# ```
#
#   * **`st.slider(...)`**: Displays a horizontal track with a handle that the user can drag.
#   * **"Max research iterations"**: This is the label displayed above the slider.
#   * **`1` and `10`**: These define the minimum and maximum boundary values for the slider.
#   * **`3`**: This is the starting **default value** when the app first loads.
#   * The chosen value is automatically stored in the **`max_iterations`** variable, which will dynamically update every time the user moves the slider.
#
# Now your app can accept both a **topic** and a desired **depth**\!
#
# The final interactive element to add is a button to trigger the whole process. Would you like to add the **"Run Research" button** next?

# %% [markdown]
# ## Adding Interactive Buttons with Feedback
#
# Wonderful progress with the slider implementation! Now, let's complete our app interface by adding a button that users can click to start their research journey.
#
# In this exercise, you'll create an interactive button that provides feedback when clicked — a crucial element of any user-friendly application.
#
# Your task is to:
#
# Create a button labeled "Run Research" using st.button()
# Store the button's state in a variable called start_research
# Add a conditional statement that checks if the button was clicked
# Display confirmation messages when the button is clicked
# This button is the final piece that brings your app to life! When users click it, they'll receive immediate feedback that their research request is being processed. This responsiveness is what makes Streamlit apps feel dynamic and engaging.
#
# By completing this exercise, you'll have built a fully functional user interface that collects a research topic, customizes research depth, and responds to user actions — all the essential elements of an interactive web application!
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # User input
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
#
# # Iteration slider
# max_iterations = st.slider("Max research iterations", 1, 10, 3)
# st.write(f"The research will run for {max_iterations} iterations.")
#
# # TODO: Create a button labeled "Run Research" and store its state in a variable called start_research
#
# # TODO: Add a conditional statement that checks if the button was clicked
# # TODO: Inside the conditional, display a success message and a processing message
#
#
# ```
#
# This is a great step to complete the user interface\! Adding an interactive button with feedback significantly improves the user experience.
#
# Here is the completed code that includes the "Run Research" button and the conditional feedback messages:
#
# ```python
# import streamlit as st
#
# st.set_page_config(page_title="DeepResearcher", layout="centered")
# st.title("🧠 DeepResearcher")
# st.write("AI-powered research assistant that performs real-time web exploration and synthesis.")
#
# # User input
# user_query = st.text_input("Enter your research topic:", placeholder="e.g. Impact of AI in healthcare")
#
# # Iteration slider
# max_iterations = st.slider("Max research iterations", 1, 10, 3)
# st.write(f"The research will run for **{max_iterations}** iterations.")
#
# # Create a button labeled "Run Research" and store its state in a variable called start_research
# start_research = st.button("Run Research")
#
# # Add a conditional statement that checks if the button was clicked
# if start_research:
#     # Inside the conditional, display a success message and a processing message
#     st.success(f"Starting research on: **{user_query}**")
#     st.info("Processing... The AI is now exploring the web and synthesizing information.")
#
#     # You would typically call your research function here
#     # For example: research_results = run_deep_researcher(user_query, max_iterations)
#
# ```
#
# -----
#
# ### **Explanation of Changes**
#
# 1.  **Button Creation:**
#
#     ```python
#     start_research = st.button("Run Research")
#     ```
#
#       * `st.button("Run Research")` creates the button with the label "Run Research."
#       * The return value is a **boolean** (`True` or `False`). It is `True` only for the single script rerun that occurs immediately after the user clicks the button, and `False` otherwise. This value is stored in the `start_research` variable.
#
# 2.  **Conditional Feedback:**
#
#     ```python
#     if start_research:
#         st.success(f"Starting research on: **{user_query}**")
#         st.info("Processing... The AI is now exploring the web and synthesizing information.")
#     ```
#
#       * The `if start_research:` statement checks if the button was clicked.
#       * `st.success()` displays a **green confirmation box**, which is excellent for immediate, positive feedback. It incorporates the user's input for clarity.
#       * `st.info()` displays a **blue/neutral box** indicating a task is in progress, giving the user an expectation of what's happening next.
#
# This completes the interactive front-end\! Would you like to explore how to display placeholder **results** after the button is clicked, or perhaps move on to a new Streamlit feature like **sidebars**?
