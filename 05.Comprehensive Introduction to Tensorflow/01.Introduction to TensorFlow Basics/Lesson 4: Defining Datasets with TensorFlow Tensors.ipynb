# %% [markdown]
# ## Introduction
# Welcome to today's lesson on the essential aspect of Tensorflow: Defining datasets using tensors. As you know, one major use of Tensorflow lies in the domain of machine learning. One fundamental knowledge you need to have is handling datasets for your machine learning models, more specifically how to define them using tensors. Let's get our hands dirty with some code!
#
# ## Contextual Understanding: Tensors as Datasets
# While programming, we use different data types to represent and process the information that our program needs. Similarly, in machine learning, we handle vast amounts of data. This data needs to be represented in a way the machine learning model can effectively use.
#
# It's crucial to understand this manual process of defining datasets with TensorFlow tensors. However, in practical applications, especially when training models with TensorFlow, much of this conversion and data handling can be automated. TensorFlow has the capability to automatically convert numpy arrays and other data formats into tensors when fed into the model. This automation significantly streamlines the process, allowing us to focus more on model architecture and less on data formatting complexities.
#
# Understanding both the manual process gives you a deeper insight into how TensorFlow manages data. It equips you with the knowledge to debug or modify data preprocessing steps if needed and appreciate the convenience TensorFlow offers in handling datasets within models.
#
# Let's take a look at some python code to generate Tensorflow tensors using numpy arrays and how we can define a dataset with these tensors.
#
# ## Tensor Generation: From Numpy Arrays to Tensors
# Let's assume you have some data stored as numpy arrays, and you want to convert it into tensors. How do you go about doing it?
#
# The tf.constant() function in Tensorflow comes to your rescue. It creates a constant tensor from a tensor-like object. "Tensor-like" refers to any type of data that can be converted into a tensor — in our case, numpy arrays.
#
# Look at the code snippet below:
#
# ```Python
#
# import tensorflow as tf
# import numpy as np
#
# # Define a simple array as input data
# X = np.array([
#     [1.0, 2.0],
#     [2.0, 1.0],
#     [3.0, 4.0],
#     [4.0, 3.0]
# ])
#
# # Define the target outputs for our dataset
# y = np.array([0, 1, 0, 1])
#
# # Convert X and y into TensorFlow tensors
# X_tensor = tf.constant(X, dtype=tf.float32)
# y_tensor = tf.constant(y, dtype=tf.int32)
#
# # Print tensors
# print("X_tensor:\n", X_tensor)
# print("y_tensor:\n", y_tensor)
# ```
#
# Here, X and y are numpy arrays. We're using tf.constant() to convert these arrays into Tensorflow tensors X_tensor and y_tensor. You'll notice we also specify dtype=tf.float32 for X_tensor. This is the data type for the elements of the resulting tensor. Since numpy array X contained floating point numbers, we set the dtype to tf.float32. For y_tensor, we set the dtype to tf.int32 because y contained integer values.
#
# The output of the above code will be:
#
# ```sh
#
# X_tensor:
#  tf.Tensor(
# [[1. 2.]
#  [2. 1.]
#  [3. 4.]
#  [4. 3.]], shape=(4, 2), dtype=float32)
#
# y_tensor:
#  tf.Tensor([0 1 0 1], shape=(4,), dtype=int32)
# ```
#
# This output illustrates the tensor versions of our numpy arrays. The shapes of the tensors (4, 2) for X_tensor and (4,) for y_tensor indicate the dimensions of our datasets, perfectly formatted for use in TensorFlow models.
#
# ## Lesson Summary and Practice
# Congratulations, you've just learned how to define a dataset using tensors in TensorFlow. You've seen how to convert numpy arrays (the common data format while working with machine learning models) into TensorFlow tensors using the tf.constant() function.
#
# Now, let's put these newly gained knowledge to test. In the next set of exercises, you'll be asked to create datasets using TensorFlow. Your understanding and skills for handling tensors will be greatly enhanced through them!
#
# Remember, the only way to learn to code is to code. So, get ready to dive headfirst into practice!

# %% [markdown]
# ## Tensor Data Conversion Essentials
# Building on what we've covered about converting numpy arrays into TensorFlow tensors, let's delve into a practical application. Run the provided code to see how numpy arrays are converted to TensorFlow tensors using tf.constant(). This ensures the data has the correct shape and type for machine learning. No modifications needed, simply execute and observe.
#
#
# ```py
# import tensorflow as tf
# import numpy as np
#
# # Define a simple array as input data
# X = np.array([
#     [1.0, 2.0],
#     [2.0, 1.0],
#     [3.0, 4.0],
#     [4.0, 3.0]
# ])
#
# # Define the target outputs for our dataset
# y = np.array([0, 1, 0, 1])
#
# # Convert X and y into TensorFlow tensors
# X_tensor = tf.constant(X, dtype=tf.float32)
# y_tensor = tf.constant(y, dtype=tf.int32)
#
# # Print tensors
# print("X_tensor:\n", X_tensor)
# print("y_tensor:\n", y_tensor)
#
# ```

# %% [markdown]
# ## Modify Dataset to Match Requirements
#
# Continuing from the previous tasks, we will now modify the existing code to match a new dataset. Currently, the code defines the targets with general numerical data. We need to imagine that we have a system that only receives boolean values for y, so we will convert our tensor to boolean.
#
# Change the y_tensor in the given code to reflect this new requirement.
#
# ```py
# import tensorflow as tf
# import numpy as np
#
# # Define a simple array as input data
# X = np.array([
#     [1.0, 2.0],
#     [2.0, 1.0],
#     [3.0, 4.0],
#     [4.0, 3.0]
# ])
#
# # Define the target outputs for our dataset
# y = np.array([0, 1, 0, 1])
#
# # Convert X and y into TensorFlow tensors
# X_tensor = tf.constant(X, dtype=tf.float32)
# y_tensor = tf.constant(y, dtype=tf.bool) # Change dtype of y to tf.bool
#
# # Print tensors
# print("X_tensor:\n", X_tensor)
# print("y_tensor:\n", y_tensor)
#
# ```

# %% [markdown]
# ## Convert Celebrity Data to Tensors
#
# Great progress so far!
#
# In this practice, you will convert a dataset of celebrity attributes and their fan-following figures into TensorFlow tensors. Your task is to add the missing code to convert the celeb_attributes numpy array into a TensorFlow tensor with data type tf.float32 and the fan_following numpy array into a TensorFlow tensor with data type tf.int32.
#
#
# ```py
# import tensorflow as tf
# import numpy as np
#
# # Provided house features: number of bedrooms, square footage
# house_features = np.array([
#     [3, 2000],
#     [4, 2500],
#     [2, 1500],
#     [5, 3000]
# ])
#
# # Provided house prices in thousands
# house_prices = np.array([500, 650, 400, 750])
#
# # Convert the numpy arrays into TensorFlow tensors with dtype=tf.int32
# house_features_tensor = tf.convert_to_tensor(house_features, dtype=tf.int32)
# house_prices_tensor = tf.convert_to_tensor(house_prices, dtype=tf.int32)
#
# # Print the resulting tensors
# print("House Features Tensor:\n", house_features_tensor)
# print("House Prices Tensor:\n", house_prices_tensor)
#
#
# ```

# %% [markdown]
# ## Convert Data to TensorFlow Tensors
# Great job so far! Now it's time to fully apply your knowledge. For the following housing data sets, your mission is to convert these arrays into TensorFlow tensors, and finally print the resulting tensors.
#
# ```py
# import tensorflow as tf
# import numpy as np
#
# # Provided house features: number of bedrooms, square footage
# house_features = np.array([
#     [3, 2000],
#     [4, 2500],
#     [2, 1500],
#     [5, 3000]
# ])
#
# # Provided house prices in thousands
# house_prices = np.array([500, 650, 400, 750])
#
# # Convert the numpy arrays into TensorFlow tensors with dtype=tf.int32
# house_features_tensor = tf.convert_to_tensor(house_features, dtype=tf.int32)
# house_prices_tensor = tf.convert_to_tensor(house_prices, dtype=tf.int32)
#
# # Print the resulting tensors
# print("House Features Tensor:\n", house_features_tensor)
# print("House Prices Tensor:\n", house_prices_tensor)
#
#
# ```
