# %% [markdown]
# # Unit 2

# %% [markdown]
# ## Factors 1-4: Structure Prompts, Tools, and Context

# %% [markdown]
# ## Fill in the Blanks about Agent Foundations

# %% [markdown]
# ## Quiz on Reliable LLM Agent Foundations

# %% [markdown]
# ## Making Sense of Structured Interactions

# %% [markdown]
# ## Making Sense of Structured Interactions
