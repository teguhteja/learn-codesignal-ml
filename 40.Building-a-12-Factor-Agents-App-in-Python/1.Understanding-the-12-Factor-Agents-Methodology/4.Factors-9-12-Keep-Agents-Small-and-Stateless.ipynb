# %% [markdown]
# # Unit 4

# %% [markdown]
# ## Factors 9-12: Keep Agents Small and Stateless

# %% [markdown]
# ## Fill in the Blanks about Agent Architecture

# %% [markdown]
# ## Quiz on Scalable Agent Architecture

# %% [markdown]
# ## Demystifying Production Architecture
