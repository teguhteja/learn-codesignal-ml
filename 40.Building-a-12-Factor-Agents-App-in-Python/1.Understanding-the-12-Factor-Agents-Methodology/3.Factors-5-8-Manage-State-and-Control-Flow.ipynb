# %% [markdown]
# # Unit 3

# %% [markdown]
# ## Factors 5-8: Manage State and Control Flow

# %% [markdown]
# ## Fill in the Blanks on Agent Control

# %% [markdown]
# ## Quiz on Agent State and Control Flow

# %% [markdown]
# ## Understanding State and Control Flow

# %% [markdown]
# ## Understanding State and Control Flow
