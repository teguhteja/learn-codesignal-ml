# %% [markdown]
# # Lesson 5: Mastering Error Handling in Go
#
# Here's the updated code to handle a nil pointer check on a string pointer named `text`:
#
# ---
#
# ### Code: Handling Nil Pointer for String in Go
#
# ```go
# package main
#
# import "fmt"
#
# func main() {
#     var text *string = nil
#
#     if text == nil {
#         fmt.Println("Text is nil and cannot be processed.")
#     } else {
#         fmt.Println("Length of the text is:", len(*text))
#     }
#
#     // Assigning a value to the string pointer
#     str := "Hello, Space Voyager!"
#     text = &str
#
#     if text == nil {
#         fmt.Println("Text is nil and cannot be processed.")
#     } else {
#         fmt.Println("Length of the text is:", len(*text))
#     }
# }
# ```
#
# ---
#
# ### Explanation:
# 1. **Nil Pointer Check:**
#    - The condition `text == nil` checks if the string pointer `text` is nil (uninitialized).
#    - If true, the program prints a friendly message: `"Text is nil and cannot be processed."`
#
# 2. **Safe Dereferencing:**
#    - If `text` is not nil, it is dereferenced with `*text`, and the length of the string it points to is calculated using the `len` function.
#
# 3. **Assigning a Valid Value:**
#    - After assigning the string `"Hello, Space Voyager!"` to the pointer, the program safely processes the string.
#
# ---
#
# ### Output:
# ```
# Text is nil and cannot be processed.
# Length of the text is: 20
# ```
#
# ---
#
# ### Benefits of This Approach:
# - **Avoids Runtime Errors:** Prevents Go's `panic` caused by dereferencing nil pointers.
# - **Handles Strings Gracefully:** Ensures safe processing of string pointers.
# - **Clear Feedback:** Provides user-friendly error messages when the pointer is nil.
#
# Let’s keep exploring and mastering Go, Space Voyager! 🚀

# %% [markdown]
# ## Space Expedition: Managing Fuel Allocation Error
#
# We are on the brink of a major space expedition, and it's time to allocate the fuel to our fleet of rockets. Each rocket should receive an equal share of fuel. Unfortunately, due to an oversight, we attempted to distribute 100 fuel units to zero rockets. This has resulted in an error which ideally should never have occurred.
#
# In Go, you cannot directly handle division by zero as an exception because Go design does not include exceptions like other languages. Check how we handle it here: simply validating the denominator!
#
# Execute the Go code provided to see how the error is managed and ensures our program doesn't crash!
#
# package main
#
# import "fmt"
#
# func main() {
#     fuel := 100
#     rockets := 0
#
#     if rockets == 0 {
#         fmt.Println("Oops! Number of rockets can't be zero!")
#     } else {
#         fuelPerRocket := fuel / rockets
#         fmt.Printf("Each rocket can carry %d units of fuel\n", fuelPerRocket)
#     }
# }
#
# The provided Go code handles the division by zero scenario gracefully by validating the denominator before performing the division. Here's a detailed walkthrough:
#
# ---
#
# ## **Explanation of the Code**
#
# ### Code Breakdown:
# 1. **Variable Initialization**:
#    `fuel` is initialized to 100 units, and `rockets` is mistakenly set to 0.
#
# 2. **Denominator Validation**:
#    The code checks if the value of `rockets` is 0.
#    - If `rockets == 0`, an error message is printed to prevent division by zero.
#    - Otherwise, it calculates `fuelPerRocket` by dividing `fuel` by `rockets`.
#
# 3. **Output Results**:
#    - If `rockets == 0`, the program outputs:
#      `"Oops! Number of rockets can't be zero!"`
#    - If `rockets > 0`, the program distributes the fuel evenly among the rockets and prints the amount each rocket receives.
#
# ---
#
# ### **The Code**
# ```go
# package main
#
# import "fmt"
#
# func main() {
#     fuel := 100           // Total fuel available
#     rockets := 0          // Number of rockets (mistakenly set to 0)
#
#     // Validate the denominator to prevent division by zero
#     if rockets == 0 {
#         fmt.Println("Oops! Number of rockets can't be zero!")
#     } else {
#         fuelPerRocket := fuel / rockets
#         fmt.Printf("Each rocket can carry %d units of fuel\n", fuelPerRocket)
#     }
# }
# ```
#
# ---
#
# ### **Key Points**
# 1. **Error Prevention**:
#    Go doesn't have exceptions like other languages, so errors like division by zero must be handled explicitly.
#    - By adding a conditional check (`rockets == 0`), the program avoids runtime errors.
#
# 2. **Program Stability**:
#    Handling such edge cases ensures the program doesn't crash unexpectedly, keeping it stable and user-friendly.
#
# ---
#
# ### **Expected Output**
# Since the number of rockets (`rockets`) is 0 in the current setup:
# ```
# Oops! Number of rockets can't be zero!
# ```
#
# If `rockets` were set to a non-zero value, e.g., `rockets := 5`:
# ```
# Each rocket can carry 20 units of fuel
# ```
#
# ---
#
# ### **Conclusion**
# This code is a simple yet powerful example of how to handle errors like division by zero in Go. By validating inputs beforehand, we can avoid crashes and provide meaningful feedback to the user. Perfect for real-world scenarios like resource allocation in space expeditions! 🚀

# %% [markdown]
# ## Handling File Not Found Error in Go
#
# Space Explorer, you're now venturing through the cosmos of code! We're simulating a space distance calculation that could potentially introduce a division by zero error. This time, instead of merely changing a variable's value to avoid the error, you're tasked with implementing an error-checking mechanism. Use Go's if-else pattern to check if timeTravelled is zero and handle the error gracefully by printing an error message. Ready for a safe exploration?
#
# package main
#
# import "fmt"
#
# func main() {
#     // Simulating space distance calculation
#     const lightSpeed = 299792 // km/s
#     var timeTravelled int = 0 // introduces a potential division by zero error
#
#     // Your task: Implement error checking mechanism for division by zero
#
#     distance := lightSpeed / timeTravelled // Risky calculation without error handling
#
#     fmt.Printf("Distance traveled: %dkm\n", distance)
# }
#
#
# Here's how you can safely handle the potential division by zero error using Go's `if-else` pattern:
#
# ```go
# package main
#
# import "fmt"
#
# func main() {
#     // Simulating space distance calculation
#     const lightSpeed = 299792 // km/s
#     var timeTravelled int = 0 // introduces a potential division by zero error
#
#     // Implement error checking mechanism for division by zero
#     if timeTravelled == 0 {
#         fmt.Println("Error: Division by zero! Time traveled cannot be zero.")
#     } else {
#         distance := lightSpeed / timeTravelled
#         fmt.Printf("Distance traveled: %dkm\n", distance)
#     }
# }
# ```
#
# ### Explanation:
# 1. **Check for Division by Zero**:
#    - Before performing the division, the code checks if `timeTravelled` is `0`.
#
# 2. **Error Handling**:
#    - If `timeTravelled` is `0`, it prints an error message and avoids the division, preventing a runtime panic.
#
# 3. **Safe Division**:
#    - If `timeTravelled` is not `0`, it performs the division safely and calculates the distance.
#
# ### Output Scenarios:
# 1. When `timeTravelled = 0`:
#    ```
#    Error: Division by zero! Time traveled cannot be zero.
#    ```
#
# 2. When `timeTravelled > 0` (e.g., `timeTravelled = 10`):
#    ```
#    Distance traveled: 29979km
#    ```
#
# This approach ensures safe exploration through the cosmos of code without unexpected crashes! 🚀

# %% [markdown]
# ## Safe Space Journey: Implement Division Error
#
# In this stellar Go programming task, we need to compute the mass ratio between Earth and Mars. Utilize the celestial_body_mass map provided and make sure to elegantly handle the absence of a key in the map.
#
# Rise to the occasion and ensure safe navigation through Go's error handling patterns!
#
# package main
#
# import (
#     "fmt"
# )
#
# func main() {
#     earthMass := 5.97e24
#     celestialBodyMass := map[string]float64{"Mars": 6.39e23, "Jupiter": 1.898e27}
#
#     // TODO: Calculate the earth-to-mars mass ratio and handle a potential missing key error for Mars
# }
#
# Here's how you can safely compute the mass ratio between Earth and Mars, handling the possibility of a missing key in the `celestialBodyMass` map:
#
# ```go
# package main
#
# import (
#     "fmt"
# )
#
# func main() {
#     earthMass := 5.97e24
#     celestialBodyMass := map[string]float64{"Mars": 6.39e23, "Jupiter": 1.898e27}
#
#     // Check if Mars exists in the map
#     marsMass, exists := celestialBodyMass["Mars"]
#     if !exists {
#         fmt.Println("Error: Mars is not found in the celestialBodyMass map.")
#         return
#     }
#
#     // Calculate the Earth-to-Mars mass ratio
#     massRatio := earthMass / marsMass
#     fmt.Printf("The Earth-to-Mars mass ratio is approximately %.2f\n", massRatio)
# }
# ```
#
# ### Explanation:
# 1. **Key Lookup with Error Handling**:
#    - The `map` lookup returns two values: the value for the key and a boolean indicating whether the key exists.
#    - `marsMass, exists := celestialBodyMass["Mars"]` checks if `"Mars"` is present in the map.
#
# 2. **Graceful Error Handling**:
#    - If `exists` is `false`, an error message is printed, and the program exits using `return`.
#
# 3. **Safe Calculation**:
#    - If `"Mars"` is found, the mass ratio is calculated safely without runtime errors.
#
# 4. **Output Format**:
#    - The result is printed with `%.2f` to show two decimal places for better readability.
#
# ### Output Scenarios:
# 1. When `"Mars"` is present in the map:
#    ```
#    The Earth-to-Mars mass ratio is approximately 9.34
#    ```
#
# 2. When `"Mars"` is missing:
#    ```
#    Error: Mars is not found in the celestialBodyMass map.
#    ```
#
# This ensures your program navigates the cosmos of keys and values safely! 🚀
