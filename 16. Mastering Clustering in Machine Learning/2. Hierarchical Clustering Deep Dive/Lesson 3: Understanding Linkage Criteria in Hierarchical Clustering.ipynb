# %% [markdown]
# # Lesson 3: Understanding Linkage Criteria in Hierarchical Clustering
#
# Here's a more organized and polished version of the text you provided on "Understanding Linkage Criteria in Hierarchical Clustering":
#
# ---
#
# ### **Introduction**
#
# Welcome to our lesson on "Understanding Linkage Criteria in Hierarchical Clustering". In this session, we will explore specific linkage criteria and their role in hierarchical clustering.
#
# Our main objective is to explain four types of linkage criteria: Single, Complete, Average linkage, and Ward's method. We will also demonstrate how to implement these criteria using Python with the `AgglomerativeClustering` class from the `sklearn.cluster` package. Let's dive into the journey of hierarchical clustering without further ado.
#
# ### **What is Linkage and Why is it Important?**
#
# Hierarchical clustering is a favored method for cluster analysis in data mining, as it helps visualize the grouping of similar objects into clusters. In each step of hierarchical clustering, some objects or clusters are linked based on a specific criterion known as 'Linkage Criteria'.
#
# Linkage Criteria determine the distance between clusters and dictate how clusters are merged at each step of hierarchical clustering. Different linkage methods define how the distance between clusters is measured, each providing a unique definition of cluster distance.
#
# Choosing the right linkage method can significantly influence the shape and size of the clusters. Let's explore each of these linkage methods in detail.
#
# ### **Single Linkage**
#
# Single Linkage, also known as the Minimal Intercluster Method, computes the distance between two clusters as the smallest distance from any point in one cluster to any point in the other cluster. This method looks for the shortest link or the nearest neighbor. Although single linkage can produce fine, detailed dendrograms and handle non-elliptical shapes, it can sometimes result in 'chaining', where clusters may be forced together due to a single close pair of points.
#
# ### **Complete Linkage**
#
# Complete Linkage, or Maximum Intercluster Method, computes the distance between two clusters as the largest distance from any point in one cluster to any point in another cluster. This method focuses on the furthest points or the furthest neighbors in the clusters and works well with clusters that are compact in nature. It also tends to avoid 'chaining', resulting in more balanced, even clusters than single linkage.
#
# ### **Average Linkage**
#
# The Average Linkage method computes the distance between two clusters as the average distance from all pairs of points, one point in each cluster. This method is less susceptible to noise and outliers and creates clusters of roughly equal diameters, though it may favor globally compact clusters over small local minima.
#
# ### **Ward's Method**
#
# Ward's Method, distinct from the other three, calculates the sum of squared Euclidean distances to the centroids of the clusters, aiming to create compact clusters of roughly equal size. The primary intention of Ward's method is to minimize the total within-cluster variance, choosing the cluster pair to merge such that the increase in total within-cluster variance is the smallest possible.
#
# ### **Comparing Different Linkage Methods**
#
# Let's compare different linkage results using the sample code provided. We will generate synthetic data using the `make_blobs` function from `sklearn.datasets` and run `AgglomerativeClustering` using each linkage method to plot the results.
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data
# X, _ = make_blobs(n_samples=150, centers=4, cluster_std=1.2, random_state=42)
#
# # Define the different linkage methods to be compared
# linkage_methods = ['single', 'complete', 'average', 'ward']
#
# # Create subplots with 2 rows and 2 columns and flatten the axs array for easier indexing
# fig, axs = plt.subplots(2, 2, figsize=(10, 10))
# axs = axs.flatten()
#
# # Loop through each linkage method and apply Agglomerative Clustering
# for i, linkage in enumerate(linkage_methods):
#     clustering = AgglomerativeClustering(n_clusters=4, linkage=linkage)
#     labels = clustering.fit_predict(X)
#     # Plot the clusters
#     axs[i].scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
#     axs[i].set_title(f'Linkage: {linkage}')
#     axs[i].set_xlabel('Feature 1')
#     axs[i].set_ylabel('Feature 2')
#     axs[i].grid(True)
# plt.tight_layout(pad=3.0)
# plt.show()
# ```
#
# This visual comparison can give you a clear understanding of how different linkage methods can lead to entirely different clustering results.
#
# ---
#
# This revised version organizes the information into clear sections, making it easier to follow and understand the content.
#
# rapikan dan tambahkan dengan artikel sebelumnya "Choosing the Right Linkage Method
# The choice of linkage method in Hierarchical Clustering mainly depends on the problem domain, shape of data, and specific requirements of our clustering task.
#
# Here are some factors to consider when choosing the right linkage method:
#
# Single Linkage: Single Linkage is a good option when we intend to capture insight into the data's fine granularity. It works well when the clusters naturally have a chain-like or non-compact structure. However, it may produce elongated and less balanced clusters due to its sensitivity to outliers and noise.
#
# Complete Linkage: Complete linkage might be the choice when we want more balanced, compact, and well-separated clusters. It is less prone to chaining effect but may break large clusters, leading to less-optimal global solutions.
#
# Average Linkage: Average Linkage strikes a balance between single and complete linkage. It is less sensitive to noise and outliers and usually produces well-defined and balanced clusters. It works great when the clusters are relatively similar in terms of diameters.
#
# Ward's Method: Ward's method seeks to minimize the total within-cluster variance, so it usually generates more uniform-sized, tightly packed clusters. It is a nice choice when we expect clusters to have similar sizes or to be compact and isolated. However, Ward's method could be biased towards globular clusters.
#
# Remember, there's no universal best choice for all datasets and scenarios. The choice of the linkage method should be based on the nature of the data, problem-specific requirements, and the results of our clustering, validated by domain knowledge. Experimenting with different linkage methods and evaluating their performances can also be helpful to find the right method.
#
# As you advance further into hierarchical clustering and conduct more practical experiments, you'll be able to make more informed decisions regarding the choice of linkage method.
#
# Lesson Summary and Practice
# In this lesson, we dove deep into the four fundamental types of linkage criteria: Single, Complete, Average linkage, and Ward's method. We learned their working mechanisms, implemented them in Python, and understood their distinct roles in hierarchical clustering. We observed the effects of these linkage methods in real time through a visual comparison.
#
# Upcoming practice exercises will test and cement your newly gained wisdom about these crucial concepts in hierarchical clustering. Keep learning, and enjoy the journey!

# %% [markdown]
# ## Exploring Star Clusters: The Impact of Different Linkage Methods
#
# Imagine you've just discovered a distant planetary system, and you're on a mission to group the planets based on their similarities. The code provided uses different linkage methods in hierarchical clustering to achieve this with synthetic data of stars. By running the code, you'll visualize how changing the linkage method influences the shape and grouping of the clusters.
#
# ```py
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data with a set seed for reproducibility
# X, _ = make_blobs(n_samples=50, centers=3, center_box=(-3, 3), random_state=42)
#
# # Define the different linkage methods to be compared
# linkage_methods = ['single', 'complete', 'average', 'ward']
#
# # Create subplots with 2 rows and 2 columns
# fig, axs = plt.subplots(2, 2, figsize=(10, 10))
#
# # Flatten the axs array for easier indexing
# axs = axs.flatten()
#
# # Loop through each linkage method and apply Agglomerative Clustering
# for i, linkage in enumerate(linkage_methods):
#     # Initialize AgglomerativeClustering with 3 clusters using one of the provided linkage methods
#     clustering = AgglomerativeClustering(n_clusters=3, linkage=linkage)
#     # Fit and predict labels
#     labels = clustering.fit_predict(X)
#
#     # Plot the clusters (complete the plotting code using the correct variables)
#     axs[i].scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
#     axs[i].set_title(f'Linkage: {linkage}')
#     axs[i].set_xlabel('Feature 1')
#     axs[i].set_ylabel('Feature 2')
#     axs[i].grid(True)
#
# # Show the plot
# plt.tight_layout(pad=3)
# plt.show()
#
# ```
#
# Your Python script is well-structured and ready to visualize the effects of different linkage methods in hierarchical clustering using synthetic data. This example is perfect for demonstrating how changing the linkage method can influence the shape and grouping of clusters, akin to grouping planets in a newly discovered planetary system based on their similarities.
#
# Here’s a brief explanation of each section of your code to ensure it's clear how it works:
#
# 1. **Import Libraries**: You're importing necessary Python libraries:
#     - `numpy` for handling large, multi-dimensional arrays and matrices.
#     - `matplotlib.pyplot` for plotting graphs.
#     - `make_blobs` from `sklearn.datasets` for generating isotropic Gaussian blobs for clustering.
#     - `AgglomerativeClustering` from `sklearn.cluster` for performing hierarchical clustering.
#
# 2. **Generate Synthetic Data**:
#     - `make_blobs` is used to create 50 samples grouped into 3 clusters within a specified range (`center_box=(-3, 3)`). The `random_state` parameter ensures that the output is the same each time the code is run for reproducibility.
#
# 3. **Define Linkage Methods**:
#     - You specify the different linkage methods to be compared: 'single', 'complete', 'average', and 'ward'. Each of these methods has a distinct way of calculating the distance between clusters, which will affect the resulting cluster shapes and groupings.
#
# 4. **Setup Plotting Environment**:
#     - You prepare a 2x2 subplot using `matplotlib` to visualize the results for each linkage method. The `figsize` parameter sets the size of the overall figure.
#
# 5. **Clustering and Plotting**:
#     - The loop iterates over the defined linkage methods, applying `AgglomerativeClustering` with each method to the synthetic data. Each method uses 3 clusters.
#     - After fitting the model to the data and predicting the labels, you plot the results. Each subplot represents the clusters formed using a different linkage method, colored by their labels. The plots are titled according to the linkage method used, and axes are labeled as 'Feature 1' and 'Feature 2'.
#
# 6. **Display the Plot**:
#     - `plt.tight_layout(pad=3)` adjusts the subplots to make sure there's no overlap, and `plt.show()` displays the figure.
#
# This script is an excellent tool for visualizing how the choice of linkage method in hierarchical clustering can lead to different groupings of data points, which can be analogous to classifying planets based on their characteristics in a newly discovered planetary system. Each method provides a unique perspective on the data, highlighting the importance of choosing the right method based on the specific characteristics of the data.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# Generate synthetic data with a set seed for reproducibility
X, _ = make_blobs(n_samples=50, centers=3, center_box=(-3, 3), random_state=42)

# Define the different linkage methods to be compared
linkage_methods = ['single', 'complete', 'average', 'ward']

# Create subplots with 2 rows and 2 columns
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Flatten the axs array for easier indexing
axs = axs.flatten()

# Loop through each linkage method and apply Agglomerative Clustering
for i, linkage in enumerate(linkage_methods):
    # Initialize AgglomerativeClustering with 3 clusters using one of the provided linkage methods
    clustering = AgglomerativeClustering(n_clusters=3, linkage=linkage)
    # Fit and predict labels
    labels = clustering.fit_predict(X)
    
    # Plot the clusters (complete the plotting code using the correct variables)
    axs[i].scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
    axs[i].set_title(f'Linkage: {linkage}')
    axs[i].set_xlabel('Feature 1')
    axs[i].set_ylabel('Feature 2')
    axs[i].grid(True)

# Show the plot
plt.tight_layout(pad=3)
plt.show()

# %% [markdown]
# ## Exploring Cluster Numbers in Hierarchical Clustering
#
# Now, Stellar Navigator, let's experiment with the linkage in the given AgglomerativeClustering. Let's use the complete linkage method instead. Adjust the code appropriately and see how the results change. Remember to update the plot title as well to use the proper linkage name.
#
# ```py
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data
# X, _ = make_blobs(n_samples=30, centers=3, center_box=(-2, 2), random_state=42)
#
# # Apply Agglomerative Clustering
# clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')
#
# # Fit and predict labels
# labels = clustering.fit_predict(X)
#
# # Plot the clusters
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
# plt.title('Linkage: ward')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.grid(True)
# plt.show()
#
#
# ```
#
# To adjust your code to use the "complete" linkage method in the `AgglomerativeClustering` and reflect this change in the plot title, you'll need to modify the `linkage` parameter in the `AgglomerativeClustering` function and update the title in the `plt.title()` call. Here's how you can do it:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data
# X, _ = make_blobs(n_samples=30, centers=3, center_box=(-2, 2), random_state=42)
#
# # Apply Agglomerative Clustering using 'complete' linkage
# clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')
#
# # Fit and predict labels
# labels = clustering.fit_predict(X)
#
# # Plot the clusters
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
# plt.title('Linkage: Complete')  # Updated plot title to reflect the linkage method used
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.grid(True)
# plt.show()
# ```
#
# ### Explanation of Changes:
# - **Linkage Method**: Changed from `'ward'` to `'complete'` in the `AgglomerativeClustering` instantiation. The 'complete' linkage method considers the maximum distance between points in each cluster when forming new clusters, which tends to produce more compact and well-separated clusters compared to 'ward', which minimizes the variance within each cluster.
# - **Plot Title**: Updated from `'Linkage: ward'` to `'Linkage: Complete'` to accurately describe the linkage method used in the visualization.
#
# This adjustment will allow you to observe how the complete linkage method groups the data points differently from the ward linkage method, providing insights into how the choice of linkage impacts the clustering results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# Generate synthetic data
X, _ = make_blobs(n_samples=30, centers=3, center_box=(-2, 2), random_state=42)

# Apply Agglomerative Clustering using 'complete' linkage
clustering = AgglomerativeClustering(n_clusters=3, linkage='complete')

# Fit and predict labels
labels = clustering.fit_predict(X)

# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
plt.title('Linkage: Complete')  # Updated plot title to reflect the linkage method used
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exploring Cluster Configurations in Hierarchical Clustering
#
# Let's simplify our space adventure a tad, Space Voyager! Focus on one linkage method and explore its clustering behavior with a new twist. Modify the starter code to use the 'ward' linkage method and set a custom distance metric, the 'euclidean' distance. This is a single leap into understanding the impact of distance on cluster formation.
#
# ```py
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data with a different random state
# X, _ = make_blobs(n_samples=100, centers=3, center_box=(-2, 2), random_state=24)
#
# # TODO: # Modify linkage and distance metric here to use Ward's method with Euclidean distance
# clustering = AgglomerativeClustering(n_clusters=3, linkage='average', metric='manhattan')
#
# # Fit and predict labels
# labels = clustering.fit_predict(X)
#
# # Plot the clusters
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
# # TODO: Don't forget to update the title as well
# plt.title('Linkage: Average with Manhattan distance')
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.grid(True)
# plt.show()
#
# ```
#
# To adjust your code to focus specifically on the 'ward' linkage method using the 'euclidean' distance metric, we need to make a few modifications. Notably, the 'ward' linkage method inherently uses the 'euclidean' distance, so the `metric` parameter does not need to be explicitly set when using 'ward'. Here’s how you can modify your code:
#
# ```python
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Generate synthetic data with a different random state
# X, _ = make_blobs(n_samples=100, centers=3, center_box=(-2, 2), random_state=24)
#
# # Modify linkage to use Ward's method (Euclidean distance is used by default with Ward's method)
# clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')
#
# # Fit and predict labels
# labels = clustering.fit_predict(X)
#
# # Plot the clusters
# plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
# plt.title('Linkage: Ward with Euclidean distance')  # Updated title to reflect the linkage method and distance metric
# plt.xlabel('Feature 1')
# plt.ylabel('Feature 2')
# plt.grid(True)
# plt.show()
# ```
#
# ### Key Adjustments:
# - **Linkage Method**: Set to `'ward'`, which is appropriate for identifying clusters with a minimum variance approach. Note that the 'ward' method only works with the 'euclidean' distance metric, which is why the `metric` parameter is not specified separately.
# - **Plot Title**: Updated to `'Linkage: Ward with Euclidean distance'` to correctly describe the linkage method and the implicit use of the Euclidean distance.
#
# This setup will allow you to explore how the Ward linkage method groups the data points based on minimizing the within-cluster variance, which is calculated using the Euclidean distance between points in the space. This visualization will help you understand the clustering behavior and the impact of this particular distance metric on cluster formation.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# Generate synthetic data with a different random state
X, _ = make_blobs(n_samples=100, centers=3, center_box=(-2, 2), random_state=24)

# Modify linkage to use Ward's method (Euclidean distance is used by default with Ward's method)
clustering = AgglomerativeClustering(n_clusters=3, linkage='ward')

# Fit and predict labels
labels = clustering.fit_predict(X)

# Plot the clusters
plt.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
plt.title('Linkage: Ward with Euclidean distance')  # Updated title to reflect the linkage method and distance metric
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Merging Clusters in the Cosmos
#
# You're doing stellar work! Now, take on this challenge: write the code to cluster stars using the 'average' linkage method. Let's see your code shine bright!
#
# ```py
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Create a dataset with make_blobs
# X, _ = make_blobs(n_samples=50, centers=3, cluster_std=0.60, random_state=0)
#
# # Setup plot
# fig, ax = plt.subplots(figsize=(5, 5))
#
# # TODO: Add code to initialize AgglomerativeClustering with the 'average' linkage method
#
# # TODO: Add code to scatter plot the results, with colors for different clusters and set the title to 'Linkage: average'
#
# # Show the plot
# plt.tight_layout()
# plt.show()
#
# ```
#
# To complete your task of clustering stars using the 'average' linkage method, I'll fill in the missing parts of your code. This includes initializing the `AgglomerativeClustering` with the specified linkage method and plotting the results accordingly. Here's how you can do it:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.datasets import make_blobs
# from sklearn.cluster import AgglomerativeClustering
#
# # Create a dataset with make_blobs
# X, _ = make_blobs(n_samples=50, centers=3, cluster_std=0.60, random_state=0)
#
# # Setup plot
# fig, ax = plt.subplots(figsize=(5, 5))
#
# # Initialize AgglomerativeClustering with the 'average' linkage method
# clustering = AgglomerativeClustering(n_clusters=3, linkage='average')
#
# # Fit and predict labels
# labels = clustering.fit_predict(X)
#
# # Scatter plot the results, with colors for different clusters
# ax.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')
#
# # Set the title to 'Linkage: Average'
# ax.set_title('Linkage: Average')
# ax.set_xlabel('Feature 1')
# ax.set_ylabel('Feature 2')
# ax.grid(True)
#
# # Show the plot
# plt.tight_layout()
# plt.show()
# ```
#
# ### Explanation:
# - **AgglomerativeClustering Initialization**: The clustering object is initialized with `n_clusters=3` and `linkage='average'`. The 'average' linkage method calculates the average distance between all pairs of points in any two clusters and uses this metric to decide which clusters to merge.
# - **Plotting**: After fitting the model and predicting the labels, the clusters are visualized using a scatter plot. The `c=labels` argument colors the points based on their cluster labels, providing a clear visual distinction between the clusters.
# - **Plot Aesthetics**: The plot is titled 'Linkage: Average' to reflect the linkage method used. Additional labels for axes and grid lines improve the readability and presentation of the plot.
#
# This setup will effectively demonstrate the behavior of the average linkage method in clustering synthetic data, helping visualize how clusters are formed based on the average distances between them.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import AgglomerativeClustering

# Create a dataset with make_blobs
X, _ = make_blobs(n_samples=50, centers=3, cluster_std=0.60, random_state=0)

# Setup plot
fig, ax = plt.subplots(figsize=(5, 5))

# Initialize AgglomerativeClustering with the 'average' linkage method
clustering = AgglomerativeClustering(n_clusters=3, linkage='average')

# Fit and predict labels
labels = clustering.fit_predict(X)

# Scatter plot the results, with colors for different clusters
ax.scatter(X[:, 0], X[:, 1], c=labels, cmap='viridis', marker='o', edgecolor='k')

# Set the title to 'Linkage: Average'
ax.set_title('Linkage: Average')
ax.set_xlabel('Feature 1')
ax.set_ylabel('Feature 2')
ax.grid(True)

# Show the plot
plt.tight_layout()
plt.show()
