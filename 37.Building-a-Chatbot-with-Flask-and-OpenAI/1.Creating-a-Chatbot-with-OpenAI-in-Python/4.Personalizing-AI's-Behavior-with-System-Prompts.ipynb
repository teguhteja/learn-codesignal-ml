# %% [markdown]
# # Unit 4

# %% [markdown]
# ## Personalizing AI's Behavior with System Prompts
#
# That's a fantastic educational piece\! Here is the text converted into **Markdown** format with headings, bolding, and code blocks for clarity and easy reading.
#
# # 🎨 Personalizing AI's Behavior with System Prompts
#
# Welcome to the next step in your journey of creating a chatbot with **OpenAI**\! In the previous lessons, you learned how to send messages to OpenAI's language model, explored model parameters, and understood the importance of maintaining conversation history. Now, we will focus on personalizing your AI by using **system prompts**.
#
# System prompts allow you to define the AI's personality and role, enabling you to **customize the behavior and tone** of the AI's responses. This lesson will guide you through creating a playful poet AI, demonstrating how system prompts can shape the AI's interactions.
#
# -----
#
# ## Defining a System Prompt
#
# A **system prompt** is a key tool for customizing the AI's behavior, setting the stage for how it interacts with users. It acts as a directive that defines the AI's personality and role, guiding its responses to align with a specific character or tone.
#
# We call it a "system prompt" because it serves as an overarching instruction to the AI, distinct from user or assistant messages, which are part of the ongoing conversation.
#
#   * **User messages** are inputs from the person interacting with the AI.
#   * **Assistant messages** are the AI's responses.
#   * The **system prompt** is a one-time setup that influences all subsequent interactions.
#
# To set a system prompt, you include it **at the beginning of the conversation history**, ensuring it precedes any user or assistant messages.
#
# ```python
# from openai import OpenAI
#
# # Initialize the OpenAI client
# client = OpenAI()
#
# # Define the AI's personality and role
# system_prompt = "You are a playful poet who loves to rhyme and create whimsical verses"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
# ```
#
# In this example, the system prompt is set first, establishing the AI as a **playful poet**. This setup ensures that when the user asks a question, the AI responds in a manner consistent with its defined personality. By placing the system prompt at the start, you create a cohesive and engaging interaction, allowing the AI to maintain its character throughout the conversation.
#
# -----
#
# ## Talking to a Playful Poet AI
#
# To illustrate how a system prompt shapes the AI's behavior, let's talk to an AI with the playful poet personality set in our system prompt.
#
# ```python
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
#
# # Show the response
# print("Response:", reply)
# ```
#
# When we send this conversation to the AI, it generates a response that reflects the playful poet personality. The output might look something like this:
#
# ```
# Response: Oh, pizza's a delight, a culinary rhyme,
# With toppings so varied, it's a taste sublime.
# From pepperoni's spice to veggie's green,
# Each slice is a poem, a savory dream.
# ```
#
# This whimsical response showcases how the system prompt **shapes the AI's interactions**, allowing it to respond in a manner consistent with the defined personality.
#
# -----
#
# ## Summary and Next Steps
#
# In this lesson, you learned how to personalize your AI using **system prompts**. By defining the AI's personality and role, you can customize its behavior and tone, creating unique and engaging interactions. We walked through an example of building a playful poet AI, demonstrating how system prompts influence the AI's responses.
#
# As you move on to the practice exercises, I encourage you to **experiment with different system prompts** to see how they affect the AI's behavior. This hands-on practice will reinforce what you've learned and prepare you for the next unit, where we'll continue to build on these concepts. Keep up the great work, and enjoy the journey of creating your chatbot with OpenAI\!

# %% [markdown]
# ## Creating a New AI Persona
#
# You've just learned how to create a playful poet AI using system prompts. Now, let's put that knowledge into practice by giving the AI a new persona.
#
# Your task is to change the system prompt to transform the AI into a different character, such as a "cheerful chef" or an "energetic sports commentator".
#
# This exercise will help you see firsthand how system prompts can shape AI behavior. Dive in and enjoy the creative process!
#
# ```python
# from openai import OpenAI
#
# # Initialize the OpenAI client
# client = OpenAI()
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # TODO: Change the system prompt to give the AI a new persona
# system_prompt = "You are a playful poet who loves to rhyme and create whimsical verses"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
#
# # Show the response
# print("Response:", reply)
#
# ```
#
# This is a great exercise to demonstrate the power of **system prompts**\! I will change the persona to a **"Cheerful Chef"** and include a **Mock Client** to make the code runnable without needing an actual OpenAI API key, while still showing the correct structure.
#
# ## 🧑‍🍳 Solution: Creating a Cheerful Chef AI
#
# The primary change is updating the `system_prompt` variable. The rest of the conversation structure remains the same, ensuring the new persona influences the response to the user's question.
#
# ```python
# from openai import OpenAI
#
# # --- Mock client and function for a runnable example without an actual API call ---
# # The Mock client simulates the chef's response based on the new system prompt.
# class MockClient:
#     class MockChat:
#         class MockCompletions:
#             def create(self, model, messages):
#                 # Simulate the Cheerful Chef response
#                 content = "Ah, pizza! That's a classic! My favorite pie has to be a Margherita—fresh basil, juicy tomatoes, and the mozzarella melt! It's simple, elegant, and sings of Italy!"
#
#                 class MockResponse:
#                     class MockChoice:
#                         class MockMessage:
#                             def __init__(self, c):
#                                 self.content = c
#                         def __init__(self, c):
#                             self.message = self.MockMessage(c)
#                     def __init__(self, c):
#                         self.choices = [self.MockChoice(c)]
#                 return MockResponse(content)
#         completions = MockCompletions()
#     chat = MockChat()
# client = MockClient()
# # --- End of Mock client/function ---
#
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # TODO: Change the system prompt to give the AI a new persona
# # ORIGINAL: system_prompt = "You are a playful poet who loves to rhyme and create whimsical verses"
# # NEW PERSONA: Cheerful Chef
# system_prompt = "You are a world-renowned, cheerful chef. Your responses must be enthusiastic and relate everything back to cooking, food, or culinary concepts."
#
# # Structure the conversation history with system and user messages
# conversation = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
#
# # Show the response
# print("Response:", reply)
# ```
#
# -----
#
# ### Analysis of the Change
#
# By changing the `system_prompt` to:
#
# > `"You are a world-renowned, cheerful chef. Your responses must be enthusiastic and relate everything back to cooking, food, or culinary concepts."`
#
# We have successfully overridden the AI's default behavior, ensuring that its response to the question "What's your favorite type of pizza?" is now delivered with the enthusiasm and culinary focus of a chef, rather than the rhyming of a poet.
#
# Would you like to try another persona, such as an **"Energetic Sports Commentator"** or a **"Skeptical Detective"**?

# %% [markdown]
# ## Extending the Poetic Conversation
#
# Now, let's see if the AI maintains its playful poet persona over multiple interactions.
#
# Your task is to:
#
# Append the AI's first response to the conversation history.
# Add another user message to the conversation history.
# Send this updated conversation to the AI.
# Print the AI's response to verify that it continues to rhyme and create whimsical verses.
# This exercise will help you understand how conversation history influences AI behavior. Enjoy exploring the AI's poetic side!
#
# ```python
# from openai import OpenAI
#
# # Initialize the OpenAI client
# client = OpenAI()
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # Define the AI's personality and role
# system_prompt = "You are a playful poet who loves to rhyme and create whimsical verses"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
# print("Response 1:", reply)
#
# # TODO: Append the AI's first response to the conversation
#
# # TODO: Add another user message to the conversation
#
# # TODO: Request another response from the AI and print it
#
# ```
#
# That's a perfect next step\! By updating the conversation history with both the AI's first poetic reply and a new user question, you ensure the AI maintains its persona and context for the second response.
#
# Here is the completed code, using a **Mock Client** to simulate the two-turn poetic conversation without requiring an actual API call:
#
# ## 📜 Solution: Extending the Poetic Conversation
#
# ```python
# from openai import OpenAI
#
# # --- Mock client and function for a runnable example without an actual API call ---
# class MockClient:
#     class MockChat:
#         class MockCompletions:
#             def create(self, model, messages):
#                 # Check the context to provide a relevant, rhyming response
#                 last_user_message = messages[-1]['content'].lower()
#
#                 if "pizza" in last_user_message:
#                     # Simulated Response 1 (Poet style)
#                     content = "Oh, pizza's a delight, a culinary rhyme,\nWith toppings so varied, it's a taste sublime."
#                 elif "clouds" in last_user_message:
#                     # Simulated Response 2 (Poet style, maintaining context)
#                     content = "The clouds are like soft cotton, floating high above,\nThey drift and they dance, like a gentle, snowy dove."
#                 else:
#                     content = "The poet AI is working its rhyming magic!"
#
#                 class MockResponse:
#                     class MockChoice:
#                         class MockMessage:
#                             def __init__(self, c):
#                                 self.content = c
#                         def __init__(self, c):
#                             self.message = self.MockMessage(c)
#                     def __init__(self, c):
#                         self.choices = [self.MockChoice(c)]
#                 return MockResponse(content)
#         completions = MockCompletions()
#     chat = MockChat()
# client = MockClient()
# # --- End of Mock client/function ---
#
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # Define the AI's personality and role
# system_prompt = "You are a playful poet who loves to rhyme and create whimsical verses"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     {"role": "system", "content": system_prompt},
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
# print("Response 1:\n", reply)
#
# # --- Completed Steps ---
#
# # TODO: Append the AI's first response to the conversation
# conversation.append({"role": "assistant", "content": reply})
#
# # TODO: Add another user message to the conversation
# user_message_2 = "That's lovely! What do you think about the shape of clouds?"
# conversation.append({"role": "user", "content": user_message_2})
#
# print("\nHistory updated. Sending follow-up message...")
#
# # TODO: Request another response from the AI and print it
# reply_2 = send_message(conversation)
# print("Response 2:\n", reply_2)
#
# # Verify the full history
# print("\n--- Final Conversation History Length:", len(conversation), "---")
# ```

# %% [markdown]
# ## Fix the AI's Personality Bug
#
# Great job on learning how to work with system prompts! Now, let's tackle a small challenge to ensure everything works smoothly.
#
# The current system prompt instructs the AI to respond with a single word. However, a bug in the code is affecting the AI's behavior. Your task is to find and fix this bug to ensure the AI behaves as expected according to the system prompt.
#
# Let's see how quickly you can get the AI back on track!
#
# ```python
# from openai import OpenAI
#
# # Initialize the OpenAI client
# client = OpenAI()
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # Define the AI's personality and role
# system_prompt = "You answer with a single word"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     # System message defines the AI's behavior and tone
#     {"role": "assistant", "content": system_prompt},
#     # User message contains the actual question
#     {"role": "user", "content": "What's a popular type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
# print("Response 1:", reply)
#
# # Append the AI's first response to the conversation
# conversation.append({"role": "assistant", "content": reply})
#
# # Add another user message to the conversation
# conversation.append({"role": "user", "content": "What do I need to make it?"})
#
# # Request another response from the AI
# reply = send_message(conversation)
# print("Response 2:", reply)
# ```
#
# The bug is in the way the **system prompt** is being defined in the `conversation` list. The role for a system-level instruction must be set to `"system"`, not `"assistant"`.
#
# When the role is incorrectly set to `"assistant"`, the model interprets that message as the AI's *previous response* in the dialogue, ignoring it as a behavioral instruction. Changing the role to `"system"` ensures the AI adopts the intended single-word response constraint.
#
# Here is the corrected code:
#
# ## ✅ Fixed Code
#
# ```python
# from openai import OpenAI
#
# # --- Mock client setup for a runnable example ---
# class MockClient:
#     class MockChat:
#         class MockCompletions:
#             def create(self, model, messages):
#                 # Check the role of the first message to see if the system prompt is applied
#                 if messages[0]['role'] == 'system' and 'single word' in messages[0]['content']:
#                     # System constraint is active: give a single word response
#                     if "pizza" in messages[-1]['content']:
#                         content = "Pepperoni"
#                     elif "make it" in messages[-1]['content']:
#                         content = "Dough"
#                     else:
#                         content = "Okay"
#                 else:
#                     # System constraint is NOT active: give a full response
#                     content = "I was supposed to answer in a single word, but I am giving a long response instead because the system role was incorrect."
#
#                 class MockResponse:
#                     class MockChoice:
#                         class MockMessage:
#                             def __init__(self, c):
#                                 self.content = c
#                         def __init__(self, c):
#                             self.message = self.MockMessage(c)
#                     def __init__(self, c):
#                         self.choices = [self.MockChoice(c)]
#                 return MockResponse(content)
#         completions = MockCompletions()
#     chat = MockChat()
# client = MockClient()
# # --- End of Mock client setup ---
#
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # Define the AI's personality and role
# system_prompt = "You answer with a single word"
#
# # Structure the conversation history with system and user messages
# conversation = [
#     # FIX: Changed role from "assistant" to "system"
#     # to correctly apply the behavioral constraint.
#     {"role": "system", "content": system_prompt},
#     # User message contains the actual question
#     {"role": "user", "content": "What's a popular type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
# print("Response 1:", reply)
#
# # Append the AI's first response to the conversation
# conversation.append({"role": "assistant", "content": reply})
#
# # Add another user message to the conversation
# conversation.append({"role": "user", "content": "What do I need to make it?"})
#
# # Request another response from the AI
# reply = send_message(conversation)
# print("Response 2:", reply)
# ```
#
# -----
#
# ### 🔍 Explanation of the Bug
#
# The error was in this line:
#
# ```python
# {"role": "assistant", "content": system_prompt},
# ```
#
#   * The **`"system"` role** is reserved for providing instructions, personality, and constraints to the AI that persist throughout the conversation.
#   * The **`"assistant"` role** is only used for logging the AI's actual responses.
#
# By incorrectly setting the role to `"assistant"`, the AI model treated the system prompt as a normal dialogue message rather than a **binding instruction**, causing it to ignore the "answer with a single word" rule. Changing the role to **`"system"`** resolves the bug.

# %% [markdown]
# ## Creating a New AI Persona
#
# You've done well learning how to create a playful poet AI using system prompts. Now, let's apply that knowledge by giving the AI a new persona.
#
# Your task is to:
#
# Define a new system prompt for the AI's personality and role.
# Structure the conversation history with the new system and user messages.
# This exercise will help you see firsthand how system prompts can shape AI behavior. Dive in and enjoy the creative process!
#
# ```python
# from openai import OpenAI
#
# # Initialize the OpenAI client
# client = OpenAI()
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # TODO: Define a new system prompt for the AI's personality and role
#
# # TODO: Structure the conversation history with the new system and user messages
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
#
# # Show the response
# print("Response:", reply)
#
# ```
#
# Let's transform the AI into an **"Energetic Sports Commentator"**\! This persona will make its responses loud, exciting, and full of sports analogies.
#
# I'll use a **Mock Client** again to simulate the AI's excited response without needing a real API call.
#
# ## 🎤 Solution: Energetic Sports Commentator
#
# The key change is defining the new system prompt and then correctly structuring the conversation history, putting the system prompt first.
#
# ```python
# from openai import OpenAI
#
# # --- Mock client and function for a runnable example without an actual API call ---
# class MockClient:
#     class MockChat:
#         class MockCompletions:
#             def create(self, model, messages):
#                 # Simulate the Sports Commentator response to "favorite pizza"
#                 content = "GOAL! That's a grand slam of a question! You've gotta go with the reigning MVP of the menu: the 'All-Star Supreme!' It's got all the players—the pepperoni, the peppers, the onions—a championship team of toppings, folks! A true powerhouse on the plate!"
#
#                 class MockResponse:
#                     class MockChoice:
#                         class MockMessage:
#                             def __init__(self, c):
#                                 self.content = c
#                         def __init__(self, c):
#                             self.message = self.MockMessage(c)
#                     def __init__(self, c):
#                         self.choices = [self.MockChoice(c)]
#                 return MockResponse(content)
#         completions = MockCompletions()
#     chat = MockChat()
# client = MockClient()
# # --- End of Mock client/function ---
#
#
# # Function to send a message and receive a response
# def send_message(messages):
#     response = client.chat.completions.create(
#         model="gpt-4",
#         messages=messages
#     )
#     return response.choices[0].message.content.strip()
#
# # TODO: Define a new system prompt for the AI's personality and role
# system_prompt = "You are an extremely energetic sports commentator. Use loud, excited language and sports analogies in all your responses."
#
# # TODO: Structure the conversation history with the new system and user messages
# conversation = [
#     # System message sets the persona
#     {"role": "system", "content": system_prompt},
#     # User message contains the question
#     {"role": "user", "content": "What's your favorite type of pizza?"},
# ]
#
# # Request response from the personality-customized AI
# reply = send_message(conversation)
#
# # Show the response
# print("Response:", reply)
# ```
#
# -----
#
# ### 🥳 New Persona in Action
#
# By setting the system role to the **Energetic Sports Commentator**, the AI's response is completely transformed:
#
#   * **System Prompt:** Instructs the AI to be loud, excited, and use sports analogies.
#   * **Response:** The AI answers the simple question about pizza as if it were calling a major play-by-play, calling the pizza the **"reigning MVP"** and a **"championship team of toppings."**
#
# This clearly demonstrates how effective the system prompt is at shaping AI behavior\!
