# %% [markdown]
# # Lesson 2: Interacting with Generative AI
#
# # Interacting with Generative AI
#
# Ever feel stuck on how to get the best out of AI tools? Think of Generative AI as a creative partner that helps you brainstorm, refine ideas, and even provide fresh angles you hadn’t considered. Now that you know what Generative AI is, let’s explore how to communicate with it effectively, understand its limitations, and use it responsibly.
#
# ## How Generative AI Responds to Prompts
#
# Generative AI tools respond to prompts—the instructions or questions you provide. Think of prompts as giving directions to a creative partner. The clearer and more specific your prompt, the better the AI can assist you. For example:
#
# **Vague Prompt:**
# *"Write a story."*
#
# **Specific Prompt:**
# *"Write a short mystery story about a detective solving a theft in a futuristic museum."*
#
# The second prompt gives the AI more context, leading to a more focused and useful result.
#
# ## Crafting Effective Prompts
#
# - **Be Specific:** Include details about the tone, style, or format you want.
# - **Iterate:** If the first result isn’t perfect, refine your prompt and try again.
# - **Use Examples:** Reference existing works or styles to guide the AI (e.g., *"Write a poem in the style of Maya Angelou"*).
#
# ### Example:
# Instead of:
# *"Give me marketing ideas."*
#
# Try:
# *"Generate five social media post ideas for a coffee shop’s summer promotion, focusing on iced drinks and outdoor seating."*
#
# ## Understanding Limitations and Biases
#
# - **No True Understanding:** Generative AI mimics patterns but doesn’t “know” facts. Always verify crucial information (e.g., an AI suggesting a ‘natural remedy’ for a symptom that actually requires a doctor’s diagnosis).
# - **Biases:** Since AI learns from existing data, it can reflect biases in that data (e.g., defaulting to male examples when describing a CEO).
# - **Creativity Gaps:** Highly original or deeply emotional content may still benefit from human nuance.
#
# ### Case Study – Project Management Pitfall
# A manager asks GenAI to create a software launch timeline. The AI drafts a plan, but when a developer falls ill, it can’t automatically reassign tasks or adjust deadlines. Human judgment is needed to keep the project on track.
#
# **Key Takeaway:** Use GenAI for planning phases, but rely on human judgment for execution and real-time adjustments.
#
# ## Ethical and Responsible Use
#
# - **Avoid Plagiarism:** Don’t present AI-generated content as entirely your own.
# - **Disclose AI Use:** Be transparent if you’ve used AI to create content for work, school, or public platforms.
# - **Double-Check:** Verify facts, citations, and sensitive content (e.g., legal or financial advice).
#
# Generative AI is here to amplify your efforts, not replace human insight. By combining the AI’s strengths with your own creativity and critical thinking, you can produce more effective and responsible outputs.
#
# ### Ready to practice? Let’s apply these concepts with hands-on exercises!

# %% [markdown]
# ## Mastering Prompt Design: Effective vs. Ineffective Examples
#
# Classify the following prompts as "Effective" or "Ineffective" based on how well they guide Generative AI to produce useful results.
#
# ```markdown
# 1. "Design a minimalist logo for a sustainable clothing brand, using green and white colors and a leaf motif."
# - Effective or Ineffective
#
# 2. "Write a 200-word blog post about adopting rescue dogs, focusing on the emotional benefits for families."
# - Effective or Ineffective
#
# 3. "Write something about dogs."
# - Effective or Ineffective
#
# 4. "Create a logo."
# - Effective or Ineffective
#
# ```
#
# Here is the classification of the prompts as **"Effective"** or **"Ineffective"** based on how well they guide Generative AI:
#
# "Design a minimalist logo for a sustainable clothing brand, using green and white colors and a leaf motif."
#
# **Effective**
# (Provides clear style, purpose, color scheme, and theme.)
#
# "Write a 200-word blog post about adopting rescue dogs, focusing on the emotional benefits for families."
#
# **Effective**
# (Specifies word count, topic, and key focus, ensuring a well-structured response.)
#
# "Write something about dogs."
#
# **Ineffective**
# (Too vague; lacks guidance on format, purpose, or specific topic.)
#
# "Create a logo."
#
# **Ineffective**
# (Too broad; does not specify style, industry, or design preferences.)
#
# Let me know if you need any further refinements! 🚀

# %% [markdown]
# ## AI Appropriateness: Navigating Ethics and Limits
#
# Decide whether Generative AI "Is Appropriate" or "Is Not Appropriate" for the following scenarios, based on its limitations and ethical considerations.
#
# ```markdown
# 1. "Drafting a heartfelt condolence letter to a grieving friend."
# - Is Appropriate or Is Not Appropriate
#
# 2. "Generating ideas for a children’s book about kindness."
# - Is Appropriate or Is Not Appropriate
#
# 3. "Writing a legal contract for a business partnership."
# - Is Appropriate or Is Not Appropriate
#
# 4. "Creating a playlist of songs for a workout session."
# - Is Appropriate or Is Not Appropriate
#
# ```
#
# Here’s the classification based on Generative AI's limitations and ethical considerations:
#
# 1. "Drafting a heartfelt condolence letter to a grieving friend."
#    - **Is Not Appropriate**
#    (AI can suggest wording, but a condolence letter should be deeply personal and emotionally authentic.)
#
# 2. "Generating ideas for a children’s book about kindness."
#    - **Is Appropriate**
#    (AI can brainstorm creative story ideas and themes, which can then be refined by a human writer.)
#
# 3. "Writing a legal contract for a business partnership."
#    - **Is Not Appropriate**
#    (Legal contracts require precise legal knowledge, jurisdiction-specific details, and human legal expertise to ensure validity.)
#
# 4. "Creating a playlist of songs for a workout session."
#    - **Is Appropriate**
#    (AI can generate song recommendations based on tempo, genre, and user preferences.)
#
#
# Let me know if you need any clarifications! 🚀

# %% [markdown]
# ## Boundary Check: AI’s Real-Time Limits
#
# Classify the following scenarios as “Suitable for GenAI” or “Requires Human Intervention” based on whether they involve real-time coordination or nuanced human judgment.
#
# ```markdown
# 1. "Drafting initial themes for a marketing campaign."
# - Suitable or Requires Human
#
# 2. "Reassigning IT support tickets during a server outage."
# - Suitable or Requires Human
#
# 3. "Mediating a debate between teams about budget priorities."
# - Suitable or Requires Human
#
# 4. "Generating a first-draft inventory checklist."
# - Suitable or Requires Human
#
# ```
#
# 1. "Drafting initial themes for a marketing campaign."
#    - **Suitable for GenAI**
#    (AI can brainstorm and suggest themes based on trends and brand guidelines.)
#
# 2. "Reassigning IT support tickets during a server outage."
#    - **Requires Human Intervention**
#    (Real-time decision-making and prioritization require human oversight, especially in urgent situations.)
#
# 3. "Mediating a debate between teams about budget priorities."
#    - **Requires Human Intervention**
#    (Budget discussions involve negotiation, compromise, and emotional intelligence, which AI lacks.)
#
# 4. "Generating a first-draft inventory checklist."
#    - **Suitable for GenAI**
#    (AI can assist in compiling and organizing checklist items based on past data or predefined categories.)
