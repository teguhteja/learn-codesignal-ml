# %% [markdown]
# # Lesson 3: Streamlining Daily Tasks with AI Assistance
#
# # Streamlining Daily Tasks with GenAI
#
# Welcome to Unit 3 of **Applying Generative AI in Everyday Professional Tasks!** Let’s explore how AI can become your productivity partner by handling routine tasks, organizing meetings, and planning projects—giving you more time for bigger-picture, strategic work. Beyond saving time, these AI-assisted approaches help maintain consistency, reduce human error, and free your mental bandwidth for creativity and innovation.
#
# ## Automating Repetitive Writing Tasks
#
# GenAI excels at creating formulaic content, which makes drafting routine communication quick and convenient while preserving a professional tone. For example:
#
# * **Emails:** "Draft a polite follow-up to clients who haven’t signed contracts"
# * **Reports:** "Auto-generate weekly team productivity summaries"
# * **Documentation:** "Convert bullet points into process guides"
#
# **Example:**
#
# Your Request: "Write a standard 'out of office' reply mentioning backup contacts."
# AI Output:
# "Thank you for your email! I’m away until June 20th. For urgent matters, contact Maria (maria@company.com) or Liam (liam@company.com)."
#
# **Remember to scan AI-generated text for accuracy and tone before sending.** Your professional judgment is crucial in ensuring final content aligns with company culture and communication standards.
#
# ## Generating Action Items from Meeting Transcripts
#
# Transform chaotic discussions into clear tasks and deadlines. This helps prevent important items from slipping through the cracks and keeps the team aligned on next steps:
#
# * **Upload Transcript:** "Identify action items from attached Zoom meeting recording"
# * **Assign Ownership:** "Tag tasks to marketing team where mentioned"
# * **Set Deadlines:** "Extract all time references as due dates"
#
# **Pro Tip:** Always verify AI-generated tasks against meeting context—AI might miss implied priorities or nuances. A quick review ensures clarity and prevents miscommunication.
#
# ## Creating Project Timelines with Natural Language Inputs
#
# Build project plans faster using everyday language. Clear, easily shareable timelines keep everyone on the same page and reduce time spent in back-and-forth planning:
#
# * **Basic Request:** "Create a 3-month product launch timeline with design, testing, and marketing phases"
# * **Detailed Prompt:** "Develop a Gantt chart for website migration including dependencies: content audit must finish before CMS setup"
# * **Real-World Scenario:** "Plan a 6-week social media campaign promoting our new app. Include content creation days, review periods, and platform-specific posting schedules."
#
# Armed with these AI-generated outlines, you can then refine scheduling details and adapt as the project evolves.
#
# ---
#
# ## Key Principles
#
# * **Customization:** Tailor AI outputs to your organization’s unique workflows and brand tone.
# * **Verification:** Double-check auto-generated dates, content, and task owners for accuracy.
# * **Transparency:** Clearly label AI-assisted content so colleagues understand how certain text or timelines were produced, fostering trust and clear collaboration.
#
# With these approaches, AI can take care of the busywork while you stay focused on innovation and strategy. Let’s practice!

# %% [markdown]
# ## Efficiency Audit: Smart or Sloppy?
#
# Classify these GenAI uses for daily tasks as "Effective" or "Ineffective".
#
# ```markdown
# 1. "Using AI to draft 20 similar customer onboarding emails."
# - Effective or Ineffective
#
# 2. "Submitting an AI-generated project timeline without checking for conflicting deadlines."
# -Effective or Ineffective
#
# 3. "Asking AI to convert bullet points into a formatted incident report."
# - Effective or Ineffective
#
# 4. "Using AI to generate action items from a meeting about sensitive layoffs."
# - Effective or Ineffective
#
# ```
#
# Here is the classification of those GenAI uses:
#
# 1.  **"Using AI to draft 20 similar customer onboarding emails."**
#     -   **Effective.** This is an excellent use of GenAI. The task is repetitive and formulaic, which is where AI excels at saving time and ensuring consistency.
#
# 2.  **"Submitting an AI-generated project timeline without checking for conflicting deadlines."**
#     -   **Ineffective.** While using AI to create the timeline is a good first step, submitting it without human verification is sloppy. This goes against the key principle of "Verification" and can lead to serious project issues.
#
# 3.  **"Asking AI to convert bullet points into a formatted incident report."**
#     -   **Effective.** This is an effective use of GenAI. The user is providing the core content (the bullet points) and asking the AI to handle the formatting and narrative structure, which is a great time-saver.
#
# 4.  **"Using AI to generate action items from a meeting about sensitive layoffs."**
#     -   **Ineffective.** This is a very poor use of GenAI. The topic is highly sensitive and requires extreme care, nuance, and discretion. A human should handle the summary and action items to ensure appropriate language and confidentiality, rather than trusting an AI with such a delicate task.

# %% [markdown]
# ## From Meeting Chaos to Clear Actions
#
# Scenario:
# Your team discussed a website redesign in a 45-minute call. Create an AI prompt to extract action items that:
#
# Specifies format (table with columns: Task, Owner, Deadline)
# Requests prioritization of urgent items
# Asks to flag unresolved questions
#
# ```markdown
# Your Prompt:
# "Create action items from this meeting transcript."
#
# ```
#
# I can help with that. Here's a revised AI prompt you can use to get clear, actionable results from your meeting transcript.
#
# -----
#
# ### The Prompt
#
# ```
# From the meeting transcript about the website redesign, please extract all action items. Organize the items into a table with the following columns:
#
# **Task**: A clear, concise description of the action to be taken.
# **Owner**: The name of the person responsible for the task. If no owner was assigned, state "Unassigned."
# **Deadline**: The agreed-upon date for completion. If no deadline was mentioned, state "To be determined."
#
# After the table, provide a separate, prioritized list of the top three most **urgent** tasks that need to be addressed immediately.
#
# Finally, list any outstanding or **unresolved questions** that were raised but not answered during the discussion.
# ```

# %% [markdown]
# ## Decision Time: Should You Automate with GenAI?
#
# You are a project manager working on a critical project with tight deadlines. Your team has just finished a brainstorming session, generating a 25-page document filled with ideas and action points. You need to extract key action items and assign responsibilities quickly.
#
# Your colleague suggests using GenAI to automatically generate the action items and assign team members based on their roles to save time.
#
# Is this a good idea? Please include a clear and concise recommendation as well as a short explanation of your reasoning.
#
# Your response should be roughly 50-100 words. While you won't be penalized if it's longer, aim for clarity and brevity.
#
# ```markdown
# Is it advisable to use GenAI to generate and assign the action items from the brainstorming document? Why or why not?
#
# ```
#
# I advise against using GenAI to automatically assign action items. While it can be highly effective for summarizing and extracting key information from the document, it lacks the nuanced understanding of team member availability, workload, and specific skill sets. A team member might be a good fit for a task on paper, but they may already be over-committed.
#
# **Recommendation:** Use GenAI to extract the list of potential action items, then manually assign the owners and deadlines to ensure accuracy and fairness. This approach leverages AI for efficiency while maintaining a human-centric approach to project management.
