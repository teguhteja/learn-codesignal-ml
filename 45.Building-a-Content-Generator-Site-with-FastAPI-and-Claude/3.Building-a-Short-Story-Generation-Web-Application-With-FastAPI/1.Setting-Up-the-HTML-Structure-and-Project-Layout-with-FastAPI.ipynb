# %% [markdown]
# ## Setting Up the HTML Structure and Project Layout with FastAPI
#
# # Building the HTML Structure for AI Short Story Generator
#
# ## Course Introduction
#
# Welcome to the first lesson of our course on building a Short Story Generation Web Application with FastAPI. In this lesson, we will focus on setting up the basic HTML structure for our application. This foundational step is crucial, as it lays the groundwork for the entire web application. By the end of this lesson, you will have a well-structured HTML document that serves as the backbone for our AI Short Story Generator. Let's dive in and start building!
#
# ---
#
# ## App File Structure
#
# Before we start building the HTML for our story generation interface, let's take a moment to understand how our FastAPI application is organized. A clear file structure helps us stay organized as our project grows in complexity.
#
# Here's the structure we'll be working with:
#
# ```
# app/
# │
# ├── main.py                     # Entry point for running the FastAPI app
# │
# ├── controllers/                # FastAPI route logic
# │   └── story_generator_controller.py
# │
# ├── services/                   # Core logic for story generation
# │   └── story_generator_service.py
# │
# ├── models/                     # Manages data and helper logic
# │   ├── story_manager.py
# │   └── prompt_manager.py
# │
# ├── data/                       # Data template for story prompt
# │   └── story_prompt_template.txt
# │
# ├── static/                     # Frontend static files (CSS, JS, etc.)
# │   ├── style.css
# │   └── script.js
# │
# └── templates/                  # HTML templates rendered by FastAPI
#     └── index.html
# ```
#
# ---
#
# ## How FastAPI Serves Static Files and Templates
#
# - **Templates**: FastAPI uses the `Jinja2Templates` class to render HTML templates. Templates are stored in the `templates/` directory.
# - **Static Files**: Static files such as CSS and JavaScript are served using FastAPI's `StaticFiles` class. These files are placed in the `static/` directory and mounted in the FastAPI app.
#
# In your FastAPI app, you might mount the static directory like this:
#
# ```python
# from fastapi import FastAPI
# from fastapi.staticfiles import StaticFiles
#
# app = FastAPI()
# app.mount("/static", StaticFiles(directory="app/static"), name="static")
# ```
#
# And in your HTML template, you can link to your stylesheet as follows:
#
# ```html
# <link rel="stylesheet" href="/static/style.css">
# ```
#
# This tells FastAPI to serve the `style.css` file from the `static` folder.
#
# ---
#
# ## Creating the Basic HTML Document Structure
#
# Let's start by setting up the basic HTML structure in the `app/templates/index.html` file. This will serve as the foundation for our web application.
#
# ### 1. DOCTYPE Declaration and HTML Tag
#
# Begin by declaring the document type and opening the HTML tag with the language attribute set to English.
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# ```
#
# > **Note**: The `<!DOCTYPE html>` declaration defines the document type and version of HTML. The `<html lang="en">` tag specifies the language of the document, which is important for accessibility and SEO.
#
# ### 2. Head Element
#
# Next, add the head element, which contains metadata about the document.
#
# ```html
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# ```
#
# > **Details**:
# > - The `<meta charset="UTF-8">` tag sets the character encoding for the document, ensuring it can display all characters correctly.
# > - The `<meta name="viewport" content="width=device-width, initial-scale=1.0">` tag ensures the page is responsive and displays correctly on all devices.
# > - The `<title>` tag sets the title of the page, which appears in the browser tab.
# > - The `<link>` tag links the CSS file using FastAPI's Jinja2 `url_for` function, ensuring the styles are applied to the page.
#
# ### 3. Body Element
#
# Finally, add the body element, which will contain the content of the page.
#
# ```html
# <body>
# </body>
# ```
#
# > **Note**: The `<body>` tag is where all the visible content of the page will go. For now, it's empty, but we'll be adding more elements soon.
#
# ---
#
# ## Adding Tab Navigation
#
# Now, let's create a tab navigation system within the body element. This will allow users to switch between different sections of the application.
#
# ### Tabs Container
#
# Start by creating a `div` with the class `tabs` to hold the navigation buttons.
#
# ```html
# <div class="tabs">
#     <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#     <button class="tab-button" onclick="openTab('history')">View History</button>
# </div>
# ```
#
# > **Details**:
# > - The `<div class="tabs">` element acts as a container for the tab buttons.
# > - Each `<button>` element represents a tab. The `onclick` attribute calls the `openTab` function with the respective tab ID, allowing users to switch between tabs.
#
# ### Generate Tab Content
#
# Create a `div` with the ID `generate` to hold the content for the "Generate Story" tab.
#
# ```html
# <div id="generate" class="tab-content">
#     <div class="container">
#         <h1>AI Short Story Generator</h1>
#         <input type="text" id="prompt" placeholder="Enter your story theme...">
#         <label for="tone">Tone (Optional):</label>
#         <select id="tone">
#             <option value="">None</option>
#             <option value="Mysterious">Mysterious</option>
#             <option value="Adventurous">Adventurous</option>
#             <option value="Humorous">Humorous</option>
#             <option value="Inspirational">Inspirational</option>
#         </select>
#         <button id="generate-button" onclick="generateStory()">Generate Story</button>
#         <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#         <div id="story-container"></div>
#     </div>
# </div>
# ```
#
# > **Details**:
# > - The `<h1>` element serves as the title for the tab.
# > - The `<input>` element allows users to enter a story theme.
# > - The `<select>` element provides a dropdown menu for selecting the tone of the story.
# > - The `<button>` element triggers the `generateStory` function to generate a story.
# > - The `<p>` element displays a loading message while the story is being generated.
# > - The `<div id="story-container">` is where the generated story will be displayed.
#
# ### History Tab Content
#
# Create a `div` with the ID `history` to hold the content for the "View History" tab.
#
# ```html
# <div id="history" class="tab-content" style="display:none;">
#     <div class="container">
#         <h1>Story History</h1>
#         <button onclick="fetchHistory()">Load Previous Stories</button>
#         <div id="history-container"></div>
#     </div>
# </div>
# ```
#
# > **Details**:
# > - The `<h1>` element serves as the title for the tab.
# > - The `<button>` element triggers the `fetchHistory` function to load previous stories.
# > - The `<div id="history-container">` is where the history of stories will be displayed.
# > - The `style="display:none;"` attribute ensures this tab is initially hidden.
#
# ---
#
# ## Finalizing the HTML Structure and Summary
#
# ### Script Tag
#
# Add the script tag at the end of the body to include the JavaScript file and ensure everything is well organized.
#
# ```html
# <script src="{{ url_for('static', path='script.js') }}"></script>
# ```
#
# > **Note**: This script tag links the JavaScript file using FastAPI's Jinja2 `url_for` function, ensuring the scripts are correctly loaded.
#
# ### Verify Structure
#
# Ensure all elements are correctly nested and organized within the HTML structure. This is crucial for the application to function properly.
#
# ---
#
# ## Complete HTML Code
#
# Here's the complete `index.html` file with all the elements combined:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <!-- Tabs Navigation -->
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <!-- Generate Story Tab -->
#     <div id="generate" class="tab-content">
#         <div class="container">
#             <h1>AI Short Story Generator</h1>
#             <input type="text" id="prompt" placeholder="Enter your story theme...">
#             <label for="tone">Tone (Optional):</label>
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#             <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#             <div id="story-container"></div>
#         </div>
#     </div>
#
#     <!-- History Tab -->
#     <div id="history" class="tab-content" style="display:none;">
#         <div class="container">
#             <h1>Story History</h1>
#             <button onclick="fetchHistory()">Load Previous Stories</button>
#             <div id="history-container"></div>
#         </div>
#     </div>
#
#     <!-- JavaScript -->
#     <script src="{{ url_for('static', path='script.js') }}"></script>
# </body>
# </html>
# ```
#
# ---
#
# ## Summary
#
# In summary, we've set up the basic HTML structure for our AI Short Story Generator application. This includes:
# - Creating a tab navigation system
# - Developing content for the "Generate Story" and "View History" tabs
# - Linking the necessary CSS and JavaScript files
#
# In the upcoming practice exercises, you'll have the opportunity to reinforce these concepts and ensure your HTML structure is ready for further development.
#
# ---
#
# *End of Lesson*

# %% [markdown]
# ## Mounting the Static Directory
#
# Now that we understand our application's file structure, it's time to put that knowledge into practice! In this exercise, you'll configure your application to serve static files, which are essential for applying CSS styles to your web pages.
#
# In later tasks, we will set up the HTML template and CSS file, but first your application need to have access to the static directory. To fix this, you need to:
#
#     Import the StaticFiles class from FastAPI
#     Mount the static directory to make your CSS file accessible
#
# This simple configuration will transform your plain HTML interface into a styled, user-friendly application. Once you complete this exercise, you'll see how proper styling dramatically improves the look and feel of your story generator!
#
# ```
# from fastapi import FastAPI, Request
# # TODO: Import StaticFiles
# from fastapi.responses import HTMLResponse
# from fastapi.middleware.cors import CORSMiddleware
# from controllers.story_generator_controller import StoryGeneratorController
# from fastapi.templating import Jinja2Templates
#
# app = FastAPI()
# controller = StoryGeneratorController()
#
# # TODO: Mount the static directory using app.mount
#
# templates = Jinja2Templates(directory="templates")
#
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
#
#
# @app.get("/", response_class=HTMLResponse)
# async def index(request: Request):
#     return templates.TemplateResponse(
#         request=request,
#         name="index.html",
#         context={}
#     )
#
#
# @app.post("/api/generate_story")
# async def generate_story(request: Request):
#     data = await request.json()
#     prompt = data.get("prompt")
#     tone = data.get("tone")
#     return controller.generate_story(prompt, tone)
#
#
# @app.get("/api/get_stories")
# async def get_stories(request: Request):
#     return controller.get_stories()
#
# ```
#
# ```python
# from fastapi import FastAPI, Request
# from fastapi.staticfiles import StaticFiles  # Import StaticFiles
# from fastapi.responses import HTMLResponse
# from fastapi.middleware.cors import CORSMiddleware
# from controllers.story_generator_controller import StoryGeneratorController
# from fastapi.templating import Jinja2Templates
#
# app = FastAPI()
# controller = StoryGeneratorController()
#
# # Mount the static directory using app.mount
# app.mount("/static", StaticFiles(directory="static"), name="static")
#
# templates = Jinja2Templates(directory="templates")
#
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
#
#
# @app.get("/", response_class=HTMLResponse)
# async def index(request: Request):
#     return templates.TemplateResponse(
#         request=request,
#         name="index.html",
#         context={}
#     )
#
#
# @app.post("/api/generate_story")
# async def generate_story(request: Request):
#     data = await request.json()
#     prompt = data.get("prompt")
#     tone = data.get("tone")
#     return controller.generate_story(prompt, tone)
#
#
# @app.get("/api/get_stories")
# async def get_stories(request: Request):
#     return controller.get_stories()
# ```

# %% [markdown]
# ## Creating the HTML Document Foundation
#
# Skip to main content
# Setting Up the HTML Structure and Project Layout with FastAPI
#
# Let's start building the foundation of our web interface! In this exercise, you'll create the basic HTML skeleton for our AI Short Story Generator.
#
# Your task is to set up the essential HTML structure in the "app/templates/index.html" file by:
#
#     Adding the DOCTYPE declaration
#     Creating the HTML element with the English language setting
#     Building a complete head section with proper meta tags, a title, and a CSS link
#     Including an empty body tag (we'll fill this with content in later exercises)
#
# Follow the TODO comments in the starter code to complete each part of the structure. This HTML foundation is crucial as it will support all the interactive elements we'll add in upcoming exercises. Let's build a solid base for our story generator!
#
# ```
# <!-- TODO: Add the DOCTYPE declaration here -->
#
# <!-- TODO: Add the HTML tag with language attribute set to English -->
#
# <!-- TODO: Add the head element with all necessary meta information -->
#
# <!-- TODO: Add an empty body element -->
#
#
# ```
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <!-- Body content will be added in later exercises -->
# </body>
# </html>
# ```

# %% [markdown]
# ## Adding Tab Navigation to Interface
#
# Excellent work on creating the HTML foundation! Now, let's make our application interactive by adding a navigation system. Users need a way to switch between generating new stories and viewing their history.
#
# Your task is to add a tab navigation bar inside the body element of our HTML document. You'll need to:
#
#     Create a div with the class "tabs" to serve as our navigation container.
#     Add two buttons inside this div with the class "tab-button":
#         A "Generate Story" button that calls openTab('generate') when clicked.
#         A "View History" button that calls openTab('history') when clicked.
#
# This navigation system will be the control center of our application, allowing users to easily switch between different features. In the next exercise, we'll fill in the content for each of these tabs.
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <!-- TODO: Create a div with class "tabs" for the navigation bar -->
#
#     <!-- TODO: Add two button elements with class "tab-button" inside the tabs div:
#          - First button should say "Generate Story" and call openTab('generate') when clicked
#          - Second button should say "View History" and call openTab('history') when clicked -->
#
#     <!-- Tab content will be added in future exercises -->
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Building the Story Generation Form
#
# Fantastic job setting up the navigation tabs! Now it's time to build the heart of our application — the story generation form where users will input their creative ideas.
#
# Your task is to fill in the "Generate Story" tab content with all the necessary form elements. You'll need to:
#
#     Add a container div for proper layout.
#     Create an h1 header with the title.
#     Add a text input where users can type their story themes.
#     Include a dropdown menu for selecting different story tones.
#     Create a button that will trigger the story generation process.
#     Add a loading message (initially hidden) for user feedback.
#     Include an empty container where the generated story will appear.
#
# Follow the TODO comments in the starter code to add each element in the right place. This form will be where all the magic happens — users will input their ideas here and receive AI-generated stories in return!
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content">
#         <!-- TODO: Add a container div for layout -->
#
#         <!-- TODO: Add an h1 header with the title "AI Short Story Generator" -->
#
#         <!-- TODO: Add an input element with id "prompt" and placeholder text for the story theme -->
#
#         <!-- TODO: Add a label for the tone dropdown -->
#
#         <!-- TODO: Add a select dropdown with id "tone" containing options for different story tones:
#              - None (empty value)
#              - Mysterious
#              - Adventurous
#              - Humorous
#              - Inspirational -->
#
#         <!-- TODO: Add a button with id "generate-button" that calls generateStory() when clicked -->
#
#         <!-- TODO: Add a paragraph with id "loading-message" that's initially hidden (style="display: none;") -->
#
#         <!-- TODO: Add an empty div with id "story-container" where the generated story will appear -->
#     </div>
# </body>
# </html>
#
# ```
#
# Here is the complete HTML structure with all the form elements, dropdown options, loading feedback, and response container implemented:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content">
#         <!-- Container div for layout -->
#         <div class="container">
#             <!-- Header title -->
#             <h1>AI Short Story Generator</h1>
#
#             <!-- Input element for story theme -->
#             <input type="text" id="prompt" placeholder="Enter your story theme or idea here..." />
#
#             <!-- Label for tone selection -->
#             <label for="tone">Choose Story Tone:</label>
#
#             <!-- Select dropdown for story tone -->
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#
#             <!-- Generate button -->
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#
#             <!-- Loading indicator message (initially hidden) -->
#             <p id="loading-message" style="display: none;">Crafting your story, please wait...</p>
#
#             <!-- Output container for generated story -->
#             <div id="story-container"></div>
#         </div>
#     </div>
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Creating the Story History Interface
#
# Wonderful progress on the story generation form! Now let's complete our interface by building the "View History" tab, where users can access their previously created stories.
#
# Your task is to fill in the "View History" tab content with all the necessary elements. You'll need to:
#
#     Add a container div for proper layout.
#     Create an h1 header with the title "Story History."
#     Add a button that calls the fetchHistory() function when clicked.
#     Include an empty div where the history of stories will be displayed.
#
# Follow the TODO comments in the starter code to add each element in the right place. This tab will complete our application by giving users access to their creative journey — allowing them to revisit and share their favorite generated stories!
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content" style="display:none;">
#         <div class="container">
#             <h1>AI Short Story Generator</h1>
#             <input type="text" id="prompt" placeholder="Enter your story theme...">
#             <label for="tone">Tone (Optional):</label>
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#             <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#             <div id="story-container"></div>
#         </div>
#     </div>
#
#     <div id="history" class="tab-content">
#         <!-- TODO: Add a container div for layout -->
#
#         <!-- TODO: Add an h1 header with the title "Story History" -->
#
#         <!-- TODO: Add a button that calls fetchHistory() when clicked with text "Load Previous Stories" -->
#
#         <!-- TODO: Add an empty div with id "history-container" where previous stories will be displayed -->
#     </div>
# </body>
# </html>
#
# ```
#
# Here is the complete HTML structure with the "View History" tab elements implemented:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content" style="display:none;">
#         <div class="container">
#             <h1>AI Short Story Generator</h1>
#             <input type="text" id="prompt" placeholder="Enter your story theme...">
#             <label for="tone">Tone (Optional):</label>
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#             <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#             <div id="story-container"></div>
#         </div>
#     </div>
#
#     <div id="history" class="tab-content">
#         <!-- Container div for layout -->
#         <div class="container">
#             <!-- Header title -->
#             <h1>Story History</h1>
#
#             <!-- Button to fetch story history -->
#             <button onclick="fetchHistory()">Load Previous Stories</button>
#
#             <!-- Output container where historical stories will be rendered -->
#             <div id="history-container"></div>
#         </div>
#     </div>
# </body>
# </html>
#
# ```

# %% [markdown]
# ## Linking JavaScript to Complete the Interface
#
# You've done an amazing job building both the story generation form and history interface! Now let's put the final piece in place to make everything work together.
#
# Your task is to add the <script> tag at the end of the <body> element that links to our JavaScript file. This connection is essential because it powers all the interactive features we've set up — from tab switching to story generation and history loading.
#
# Simply add the <script> tag using Flask's url_for function to correctly link to the script.js file in the static folder. This approach ensures Flask will properly resolve the file path regardless of how the application is deployed.
#
# Check if the script works by switching between the "Generate Story" and "View Story" tabs.
#
# With this final addition, your HTML structure will be complete and ready for the next steps in our development journey. You'll soon see how all these carefully structured elements come to life with CSS styling and JavaScript functionality!
#
# ```
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content">
#         <div class="container">
#             <h1>AI Short Story Generator</h1>
#             <input type="text" id="prompt" placeholder="Enter your story theme...">
#             <label for="tone">Tone (Optional):</label>
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#             <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#             <div id="story-container"></div>
#         </div>
#     </div>
#
#     <div id="history" class="tab-content" style="display:none;">
#         <div class="container">
#             <h1>Story History</h1>
#             <button onclick="fetchHistory()">Load Previous Stories</button>
#             <div id="history-container"></div>
#         </div>
#     </div>
#
#     <!-- TODO: Add the script tag to link the JavaScript file using Flask's url_for function -->
# </body>
# </html>
#
# ```
#
# Here is the complete HTML code with the `<script>` tag added at the end of the `<body>` using `url_for('static', path='script.js')`:
#
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>AI Short Story Generator</title>
#     <link rel="stylesheet" href="{{ url_for('static', path='style.css') }}">
# </head>
# <body>
#     <div class="tabs">
#         <button class="tab-button" onclick="openTab('generate')">Generate Story</button>
#         <button class="tab-button" onclick="openTab('history')">View History</button>
#     </div>
#
#     <div id="generate" class="tab-content">
#         <div class="container">
#             <h1>AI Short Story Generator</h1>
#             <input type="text" id="prompt" placeholder="Enter your story theme...">
#             <label for="tone">Tone (Optional):</label>
#             <select id="tone">
#                 <option value="">None</option>
#                 <option value="Mysterious">Mysterious</option>
#                 <option value="Adventurous">Adventurous</option>
#                 <option value="Humorous">Humorous</option>
#                 <option value="Inspirational">Inspirational</option>
#             </select>
#             <button id="generate-button" onclick="generateStory()">Generate Story</button>
#             <p id="loading-message" style="display: none;">Generating story... Please wait.</p>
#             <div id="story-container"></div>
#         </div>
#     </div>
#
#     <div id="history" class="tab-content" style="display:none;">
#         <div class="container">
#             <h1>Story History</h1>
#             <button onclick="fetchHistory()">Load Previous Stories</button>
#             <div id="history-container"></div>
#         </div>
#     </div>
#
#     <!-- Link the static JavaScript file -->
#     <script src="{{ url_for('static', path='script.js') }}"></script>
# </body>
# </html>
#
# ```
#
# With this tag in place, your application can now trigger functions like `openTab()`, `generateStory()`, and `fetchHistory()` directly from the UI controls.
