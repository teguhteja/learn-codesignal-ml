# %% [markdown]
# ## Using Contextual Modifiers in Content Generation
#
# # Contextual Modifiers in Content Generation
#
# Welcome to the final lesson of this course, where we will explore the concept of **contextual modifiers**. Contextual modifiers are powerful tools that allow you to tailor AI-generated content to fit specific contexts or scenarios. Unlike tone modifiers, which adjust the style or mood of the content, contextual modifiers focus on the setting or background in which the content is framed. This lesson will guide you through the process of using contextual modifiers to enhance the relevance and quality of your generated content.
#
# ---
#
# ## Recall: Setting Up the Anthropic Client
#
# Before we dive into contextual modifiers, let's briefly recall how to set up the Anthropic client. This is a reminder from previous lessons, where we initialized the client to interact with the Claude model. Make sure you have your API key ready and set up your environment as follows:
#
# ```python
# import os
# from anthropic import Anthropic
#
# # Initialize the Anthropic client
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# ```
#
# This setup allows you to communicate with the Claude model and generate content based on your prompts.
#
# ---
#
# ## Understanding and Defining Contextual Modifiers
#
# **Contextual modifiers** are phrases or keywords that define the setting or scenario for the content you want to generate. They help the AI understand the context in which the content should be framed, leading to more relevant and engaging outputs.
#
# Here are some examples of different contexts you might use:
#
# * **Academic Context:** `"A historical analysis of the Renaissance, academic context"`
# * **Speculative Context:** `"A futuristic vision of technology, speculative context"`
# * **Intimate Context:** `"A personal diary entry, intimate context"`
# * **Informative Context:** `"A travel guide to Paris, informative context"`
#
# By using these modifiers, you can guide the AI to generate content that fits the desired context, making it more suitable for specific audiences or purposes.
#
# ---
#
# ## Implementing Contextual Modifiers in Code
#
# Let's walk through the process of implementing contextual modifiers in your code. We'll start by defining a list of context-styled prompts and then use the Anthropic client to generate content for each one.
#
# First, create a list of prompts that include your desired contextual modifiers:
#
# ```python
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
# ]
#
# ```
#
# Each prompt in this list specifies a different context, which will guide the AI in generating content that fits the scenario.
#
# Next, iterate over the list of context modifiers and use the `messages.create` method to generate content for each one:
#
# ```python
# for context_prompt in context_modifiers:
#     response = client.messages.create(
#         model='claude-3-5-sonnet-20241022',
#         max_tokens=1000,
#         messages=[
#             {
#                 "role": "user",
#                 "content": context_prompt,
#             }
#         ]
#     )
#
# ```
#
# In this code, the `messages.create` method sends the context prompt to the Claude model, which then generates content based on the specified context.
#
# Finally, process the response from the API and display the generated content:
#
# ```python
#     # Process and display the generated content
#     generated_content = response.content[0].text
#     print(generated_content)
#
# ```
#
# This step extracts the text content from the response object and prints it, allowing you to see the output generated for each context.
#
# ---
#
# ## Summary and Preparation for Practice
#
# In this lesson, you learned how to use contextual modifiers to tailor AI-generated content to specific scenarios. By defining context-styled prompts and using the Anthropic client, you can create content that is more relevant and engaging for your intended audience. As you move on to the practice exercises, experiment with different contexts to see how they affect the generated content.
#
# Congratulations on reaching the end of this course! You've gained valuable skills in content generation using the Claude model, and you're now equipped to apply these techniques in real-world scenarios. Keep exploring and experimenting with different modifiers to continue enhancing your AI-generated content!

# %% [markdown]
# ## Iterating Through Contextual Modifiers List
#
# Now that you've learned about contextual modifiers and how they can enhance AI-generated content, let's start with a simple exercise to get comfortable with the data structure we'll be using.
#
# In this exercise, you'll practice working with the list of contextual modifiers we just discussed. Your task is to complete the code by writing a loop that iterates through the list of contextual modifiers and prints each one to the console.
#
# This foundational skill will help you understand how to access each modifier before we connect them to the Claude API in upcoming exercises. Mastering this basic list iteration will make working with contextual modifiers much easier as we progress!
#
# ```
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
# ]
#
# # TODO: Write a loop that iterates through the context_modifiers list
# # and prints each modifier to the console
#
#
# ```

# %% [markdown]
# ## Expanding Your Contextual Modifiers Collection
#
# Excellent work on mastering the basic iteration through contextual modifiers! Now let's take a step further by expanding our collection of contexts.
#
# In this exercise, you'll enhance the existing list of contextual modifiers by adding a new one: "An environmental report, analytical context." Your task is to locate where to add this new modifier in the code and insert it properly.
#
# After adding the new modifier, run the code to verify that all five contexts (including your new addition) appear in the output. This hands-on practice will help you become comfortable with modifying data structures that you'll soon use with the Claude API to generate diverse content types.
#
# ```
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context"
# ]
#
# # TODO: Add a new contextual modifier: "An environmental report, analytical context"
#
# # Print each contextual modifier
# for modifier in context_modifiers:
#     print(modifier)
#
# ```
#
# Here is the complete, placeholder-free implementation with the new contextual modifier added to the list:
#
# ```python
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
#     "An environmental report, analytical context"
# ]
#
# # Print each contextual modifier
# for modifier in context_modifiers:
#     print(modifier)
#
# ```

# %% [markdown]
# ## Simulating API Responses for Testing
#
# Nice job expanding your collection of contextual modifiers! Now, let's take a practical step toward understanding how API responses work without using up your API quota.
#
# Most AI services, including Claude, limit the number of requests you can make within a certain time period or charge you based on usage. This is called an API quota. Exceeding your quota can result in extra charges or being temporarily blocked from making more requests. That's why it's important to test your code with simulated data before making real API calls.
#
# In this exercise, you'll simulate what happens when Claude responds to a contextual modifier. Your task is to create a mock API response dictionary that matches Claude's response structure for one of the contextual modifiers in our list.
#
# You'll need to:
#
#     Select the first contextual modifier from the context_modifiers list (the Renaissance one).
#     Create a simulated API response as a Python dictionary that mimics Claude’s real response structure.
#         The dictionary should include a content key, which is a list containing at least one object.
#         Each object in the content list should have a type (set to "text") and a text field (containing a short, relevant academic analysis of the Renaissance).
#     Extract the text content from the simulated response (from the correct nested location).
#     Print the extracted content to the console.
#
# This practice is valuable for testing your code during development and understanding how to process API responses correctly. Being able to work with simulated data will make you more efficient when building applications that use AI services!
#
# ```
# import os
# from anthropic import Anthropic
#
# # Initialize the Anthropic client (not used in this simulation)
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
# ]
#
# # TODO: Select the first contextual modifier to simulate a response for
# selected_modifier = None  # Using the first modifier
# print(f"Simulating API response for: {selected_modifier}")
#
# # TODO: Create a simulated API response dictionary that matches Claude's response structure
# # The response should include content appropriate for the selected contextual modifier
# # Hint: Claude's responses have a nested structure with content as a list of objects
#
# # TODO: Process and display the simulated content from the response
# # TODO: Extract the text content from the simulated response and print it
#
# ```
#
# Here is the complete, placeholder-free implementation simulating an Anthropic Claude API message response object as a Python dictionary and extracting the text content from its nested structure:
#
# ```python
# import os
# from anthropic import Anthropic
#
# # Initialize the Anthropic client (not used in this simulation)
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
# ]
#
# # Select the first contextual modifier to simulate a response for
# selected_modifier = context_modifiers[0]
# print(f"Simulating API response for: {selected_modifier}\n")
#
# # Create a simulated API response dictionary matching Claude's response structure
# simulated_response = {
#     "id": "msg_01A2b3C4d5E6f7G8h9I0",
#     "type": "message",
#     "role": "assistant",
#     "model": "claude-sonnet-4-5-20250929",
#     "content": [
#         {
#             "type": "text",
#             "text": "The Renaissance marked a pivotal transition from medieval scholasticism to early modern humanism in Western Europe. Characterized by a revival of classical antiquity, innovations in empirical perspective, and significant developments in political philosophy, this period fundamentally reshaped intellectual discourse and societal structures from the 14th to the 17th century."
#         }
#     ],
#     "stop_reason": "end_turn",
#     "usage": {
#         "input_tokens": 18,
#         "output_tokens": 62
#     }
# }
#
# # Extract the text content from the nested simulated response structure
# extracted_content = simulated_response["content"][0]["text"]
#
# # Process and display the simulated content
# print("=" * 60)
# print("EXTRACTED SIMULATED RESPONSE:")
# print("=" * 60)
# print(extracted_content)
#
# ```

# %% [markdown]
# ## Adding Better Error Handling to API Calls
#
#
# Now that you've learned how to simulate API responses, let's move on to making our code more reliable when working with real APIs. In real-world applications, API calls can fail for many reasons — network issues, authentication problems, or service outages.
#
# In previous exercises you added basic error handling, in this one, you'll add specific error handling to our contextual modifiers code. Your task is to wrap the API call in try-except blocks to catch potential exceptions and handle them gracefully.
#
# You'll need to:
#
#     Add try-except blocks around the call to client.messages.create
#     Import specific exception types from the Anthropic library
#     Create helpful error messages for different error scenarios
#     Ensure your code continues processing other modifiers even if one fails
#
# This skill is essential for building robust applications that can recover from unexpected issues. Well-handled errors make your programs more user-friendly and easier to troubleshoot when things go wrong!
#
# ```
# import os
# from anthropic import Anthropic
#
# # Initialize the Anthropic client
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
# ]
#
# # Generate content for each context-styled prompt
# for context_prompt in context_modifiers:
#     print(f"\nProcessing: {context_prompt}")
#     # TODO: Add try-except blocks around the API call to handle potential errors
#     # TODO: Import and catch specific exceptions like APIError, APITimeoutError, RateLimitError
#     response = client.messages.create(
#         model='claude-sonnet-4-5-20250929',
#         max_tokens=1000,
#         messages=[
#             {
#                 "role": "user",
#                 "content": context_prompt,
#             }
#         ]
#     )
#     # Process and display the generated content
#     generated_content = response.content
#     print(generated_content)
#     print("-" * 50)
#
# ```
#
# Here is the complete, robust implementation importing specific Anthropic SDK exceptions (`APIError`, `APITimeoutError`, `RateLimitError`, `APIConnectionError`) and wrapping the API call inside `try-except` blocks:
#
# ```python
# import os
# from anthropic import Anthropic, APIError, APITimeoutError, RateLimitError, APIConnectionError
#
# # Initialize the Anthropic client
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
# ]
#
# # Generate content for each context-styled prompt
# for context_prompt in context_modifiers:
#     print(f"\nProcessing: {context_prompt}")
#
#     try:
#         response = client.messages.create(
#             model='claude-sonnet-4-5-20250929',
#             max_tokens=1000,
#             messages=[
#                 {
#                     "role": "user",
#                     "content": context_prompt,
#                 }
#             ]
#         )
#
#         # Process and display the generated content
#         generated_content = response.content[0].text
#         print("\nGENERATED CONTENT:")
#         print(generated_content)
#
#     except RateLimitError as e:
#         print(f"⚠️ Rate Limit Exceeded: You have hit your API quota limit. Details: {e}")
#     except APITimeoutError as e:
#         print(f"⏱️ Request Timeout: The request to Anthropic servers timed out. Details: {e}")
#     except APIConnectionError as e:
#         print(f"🌐 Connection Error: Could not reach Anthropic servers. Check your network connection. Details: {e}")
#     except APIError as e:
#         print(f"❌ API Error ({e.status_code}): {e.message}")
#     except Exception as e:
#         print(f"💥 Unexpected Error: {str(e)}")
#
#     print("-" * 50)
#
# ```

# %% [markdown]
# ## Creating Interactive Content Selection Menus
#
# Fantastic work on adding error handling to your API calls! Now, let's make your application more user-friendly by adding interactivity.
#
# In this exercise, you'll transform your code from automatically processing all contextual modifiers to allowing users to choose which one they want to use. This puts the user in control of the content generation process.
#
# You'll need to:
#
#     Display a numbered menu showing all available contextual modifiers
#     Collect and validate user input to select a specific modifier
#     Generate content using only the selected modifier instead of processing all of them
#     Run the code by executing python solution.py in a new terminal.
#
# This enhancement makes your application more practical for real-world use, where users typically want to generate specific content rather than everything at once. Adding user input is an important skill that will help you build more interactive and responsive AI applications!
#
# ```
# import os
# from anthropic import Anthropic, APIError, APITimeoutError, RateLimitError
#
# # Initialize the Anthropic client
# client = Anthropic(api_key=os.environ.get("ANTHROPIC_API_KEY"))
#
# # Define prompts with contextual modifiers
# context_modifiers = [
#     "A historical analysis of the Renaissance, academic context",
#     "A futuristic vision of technology, speculative context",
#     "A personal diary entry, intimate context",
#     "A travel guide to Paris, informative context",
# ]
#
# # TODO: Display a numbered menu of available contextual modifiers
# # Hint: Use a loop with enumerate to show each option with a number
#
# # TODO: Get user selection and validate it's within the correct range
# # Hint: Use a while loop with try-except to handle invalid inputs
#
# # TODO: Get the selected contextual modifier based on user input
#
# # Generate content for each context-styled prompt
# for context_prompt in context_modifiers:
#     print(f"\nProcessing: {context_prompt}")
#     try:
#         response = client.messages.create(
#             model='claude-sonnet-4-5-20250929',
#             max_tokens=1000,
#             messages=[
#                 {
#                     "role": "user",
#                     "content": context_prompt,
#                 }
#             ]
#         )
#         # Process and display the generated content
#         generated_content = response.content
#         print(generated_content)
#     except RateLimitError:
#         print("Error: Rate limit exceeded. Please wait before making more requests.")
#     except APITimeoutError:
#         print("Error: The request timed out. Please try again later.")
#     except APIError as e:
#         print(f"API Error: {e}")
#     except Exception as e:
#         print(f"An unexpected error occurred: {e}")
#     print("-" * 50)
#
# ```
