# %% [markdown]
# ## Creating and Managing a Story Prompt Template
#
# # Introduction and Overview
#
# Welcome to the first lesson of our course on building a short story generation service. In this lesson, we will focus on creating the base prompt, which is a crucial component for guiding the story generation process. A well-structured prompt serves as the foundation for generating creative content, ensuring that the output aligns with the desired theme and style. By the end of this lesson, you will understand how to create and manage a story prompt template, which will be used throughout the course to generate engaging short stories.
#
# ---
#
# ## Recall: Basics of File Handling
#
# Before we dive into creating the base prompt, let's quickly recall some basics of file handling. This will be essential, as we will be working with a text file to store our story prompt template.
#
# To open a file for reading, you can use the `open()` function. This function requires the file path and the mode in which you want to open the file. To read a file, you use the `'r'` mode:
#
# ```python
# file_path = 'data/story_prompt_template.txt'
# file = open(file_path, 'r')
#
# ```
#
# Here, `file` is a variable that holds a file object, which allows you to interact with the file's contents.
#
# Once you have opened a file, you can read its contents using the `read()` method:
#
# ```python
# content = file.read()
# print("File content:")
# print(content)
#
# ```
#
# After reading the file, it's important to close it to free up system resources:
#
# ```python
# file.close()
#
# ```
#
# Alternatively, you can use the `with` statement to handle files, which automatically closes the file after the block of code is executed:
#
# ```python
# with open(file_path, 'r') as file:
#     content = file.read()
#
# print("File content:")
# print(content)
#
# ```
#
# The `with` statement also helps prevent common issues, such as file descriptor leaks or forgetting to close the file in case an exception occurs midway. It simplifies file handling logic and is the recommended way to manage external resources.
#
# ---
#
# ## Understanding the Story Prompt Template
#
# The story prompt template is a text file that outlines the structure and requirements for generating a short story. Let's examine the components of the `story_prompt_template.txt` file:
#
# ```text
# # ROLE
# You are a creative writer for 'StoryCraft Co.', a leading storytelling agency specializing in crafting engaging short stories across various genres.
#
# # THEME
# {user_input}
#
# # TASK
# Your task is to create a captivating short story that aligns with the theme provided. Ensure the story has a clear beginning, middle, and end, with well-developed characters and a compelling plot.
#
# # STYLE REQUIREMENTS
# - Tone: {tone}
# - Language: Vivid and descriptive.
# - Structure: Introduction, development, climax, resolution.
# - Length: Approximately 1000 words.
#
# # OUTPUT REQUIREMENTS
# The story must be suitable for:
# - Online publications
# - Storytelling events
# - Personal enjoyment
#
# Ensure high readability and engagement. Deliver a polished, imaginative piece ready for publication.
#
# ```
#
# ### Component Breakdown
#
# * **Role:** Defines the perspective of the writer.
# * **Theme:** A placeholder `{user_input}` that will be replaced with the user's input.
# * **Task:** Describes the main objective of the story.
# * **Style Requirements:** Language, structure, and length of the story and a placeholder `{tone}` that will be replaced with the user's input.
# * **Output Requirements:** Lists the intended uses for the story.
#
# These components guide the story generation process, ensuring consistency and alignment with the desired output.
#
# ---
#
# ## Implementing the PromptManager Class
#
# Now, let's implement the `PromptManager` class, which will manage the loading and formatting of the story prompt template.
#
# Start by defining the `PromptManager` class with a docstring to describe its purpose:
#
# ```python
# class PromptManager:
#     """Manages the loading and formatting of the story prompt template for consistency."""
#
#     @classmethod
#     def load_base_prompt(cls, file_path: str = 'data/story_prompt_template.txt') -> str:
#         try:
#             with open(file_path, 'r') as f:
#                 return f.read()
#         except Exception as e:
#             print(f"Error loading prompt template: {e}")
#             return (
#                 "# ROLE\nYou are a creative writer.\n\n"
#                 "# THEME\n{user_input}\n\n"
#                 "# TASK\nPlease generate an engaging short story.\n"
#             )
#
#     @classmethod
#     def format_prompt(cls, user_input: str, tone: str) -> str:
#         base_prompt = cls.load_base_prompt()
#         return base_prompt.format(user_input=user_input, tone=tone)
#
# ```
#
# * The `load_base_prompt` method attempts to open and read the file specified by `file_path`. If successful, it returns the file's contents. If an error occurs, it prints an error message and returns a default prompt.
# * The `format_prompt` method calls `load_base_prompt` to get the template, then uses the `format` method to replace `{user_input}` and `{tone}` with the actual user input.
#
# ---
#
# ## Integrating the PromptManager in the Main Application
#
# Finally, let's see how to use the `PromptManager` class in the main application to generate a formatted prompt:
#
# ```python
# from models.prompt_manager import PromptManager
#
# user_input = "A mysterious adventure in an enchanted forest"
# tone = "Engaging and imaginative"
#
# formatted_prompt = PromptManager.format_prompt(user_input, tone)
#
# print("Generated Prompt:")
# print(formatted_prompt)
#
# ```
#
# 1. Import the `PromptManager` class.
# 2. Define a `user_input` string with the desired theme and a `tone` string with the desired tone.
# 3. Call `format_prompt` to generate the formatted prompt.
# 4. Print the generated prompt to see the result.
#
# ### Output
#
# ```text
# Generated Prompt:
# # ROLE
# You are a creative writer for 'StoryCraft Co.', a leading storytelling agency specializing in crafting engaging short stories across various genres.
#
# # THEME
# A mysterious adventure in an enchanted forest
#
# # TASK
# Your task is to create a captivating short story that aligns with the theme provided. Ensure the story has a clear beginning, middle, and end, with well-developed characters and a compelling plot.
#
# # STYLE REQUIREMENTS
# - Tone: Engaging and imaginative.
# - Language: Vivid and descriptive.
# - Structure: Introduction, development, climax, resolution.
# - Length: Approximately 1000 words.
#
# # OUTPUT REQUIREMENTS
# The story must be suitable for:
# - Online publications
# - Storytelling events
# - Personal enjoyment
#
# Ensure high readability and engagement. Deliver a polished, imaginative piece ready for publication.
#
# ```
#
# ---
#
# ## Summary and Preparation for Practice
#
# In this lesson, we explored the importance of a structured prompt in guiding the story generation process. We examined the components of the `story_prompt_template.txt` file and implemented the `PromptManager` class to manage and format the prompt. By integrating the `PromptManager` in the main application, we demonstrated how to generate a formatted prompt using user input.
#
# As you move on to the practice exercises, focus on experimenting with different themes and observe how the prompt adapts. This hands-on practice will reinforce the concepts learned and prepare you for more advanced topics in subsequent lessons.

# %% [markdown]
# ## Reading and Displaying a Story Prompt Template in Python
#
# Now that you've learned about file handling in Python, let's put that knowledge into practice! In this exercise, you'll create the load_base_prompt function to read our story prompt template and return it — a fundamental first step in building our story generation service.
#
# When following the TODO comments, you'll need to:
#
#     Open the template file using the with statement
#     Read and return the file's content
#     Add basic error handling
#
# Remember to use the proper file path and read mode ('r'). The with statement is particularly useful as it automatically handles closing the file for you, which is good practice for resource management.
#
# This hands-on exercise will help you get comfortable with file operations before we move on to implementing more complex functions inside the PromptManager class in our next steps.
#
# ```
# class PromptManager:
#     """Manages the loading and formatting of the story prompt template for consistency."""
#
#     @classmethod
#     def load_base_prompt(cls, file_path: str = 'app/data/story_prompt_template.txt') -> str:
#         """Load the base prompt from a file."""
#         # TODO: Open the file using the with statement and read its content
#         # Hint: Use open() with 'r' mode inside a with statement
#
#         # TODO: Return the file content
#
#         # TODO: Add basic error handling in case the file is not found or other issues occur
#
# ```
#
# Here is the complete, placeholder-free implementation of the `PromptManager` class with file handling and error recovery:
#
# ```python
# class PromptManager:
#     """Manages the loading and formatting of the story prompt template for consistency."""
#
#     @classmethod
#     def load_base_prompt(cls, file_path: str = 'app/data/story_prompt_template.txt') -> str:
#         """Load the base prompt from a file."""
#         try:
#             with open(file_path, 'r', encoding='utf-8') as f:
#                 return f.read()
#         except FileNotFoundError:
#             print(f"Error: Prompt template file not found at path '{file_path}'. Using default fallback.")
#             return (
#                 "# ROLE\nYou are a creative writer.\n\n"
#                 "# THEME\n{user_input}\n\n"
#                 "# TASK\nPlease generate an engaging short story.\n"
#             )
#         except Exception as e:
#             print(f"An unexpected error occurred while reading prompt template: {e}")
#             return (
#                 "# ROLE\nYou are a creative writer.\n\n"
#                 "# THEME\n{user_input}\n\n"
#                 "# TASK\nPlease generate an engaging short story.\n"
#             )
#
# ```

# %% [markdown]
# ## Implementing Prompt Formatting for Story Generation
#
# Excellent job reading the template file! Now let's take the next step in our story generation service by implementing the format_prompt method in the PromptManager class. This method is crucial as it takes user input and tone, then inserts them into our template.
#
# In this exercise you'll follow the TODO comments, completing the format_prompt method to:
#
#     Load the base prompt using the existing load_base_prompt method
#     Replace the {user_input} and {tone} placeholders with the actual user values
#     Return the fully formatted prompt
#
# You will also modify the solution.py file to call your method with sample inputs ("A journey through time" and a chosen tone) and display the result, allowing you to verify that the placeholder substitution works correctly.
#
# This exercise builds directly on your file-handling skills and introduces string formatting — a key technique for creating dynamic content in our story generation service.
#
# ```
# # prompt_manager.py
# class PromptManager:
#     """Manages the loading and formatting of the story prompt template for consistency."""
#
#     @classmethod
#     def load_base_prompt(cls, file_path: str = 'app/data/story_prompt_template.txt') -> str:
#         """Load the base prompt from a file."""
#         try:
#             with open(file_path, 'r') as f:
#                 return f.read()
#         except Exception as e:
#             print(f"Error loading prompt template: {e}")
#             return (
#                 "# ROLE\nYou are a creative writer.\n\n"
#                 "# THEME\n{user_input}\n\n"
#                 "# TASK\nPlease generate an engaging short story.\n"
#             )
#
#     @classmethod
#     def format_prompt(cls, user_input: str, tone: str) -> str:
#         """Format the prompt by inserting the user input and tone into the template."""
#         # TODO: Load the base prompt using the load_base_prompt method
#
#         # TODO: Use string formatting to replace the {user_input} and {tone} placeholders
#
#         # TODO: Return the formatted prompt
#         pass
#
#
# # solution.py
# from app.models.prompt_manager import PromptManager
#
# # Define sample inputs
# user_input = "A journey through time"
# tone = "Mysterious"
#
# # TODO: Call the format_prompt method with the user input and tone
#
# # TODO: Print the formatted prompt to verify it works correctly
# ```
#
# Here is the complete implementation for both `prompt_manager.py` and `solution.py`, replacing placeholders with working string formatting logic.
#
# ### `app/models/prompt_manager.py`
#
# ```python
# class PromptManager:
#     """Manages the loading and formatting of the story prompt template for consistency."""
#
#     @classmethod
#     def load_base_prompt(cls, file_path: str = 'app/data/story_prompt_template.txt') -> str:
#         """Load the base prompt from a file."""
#         try:
#             with open(file_path, 'r', encoding='utf-8') as f:
#                 return f.read()
#         except Exception as e:
#             print(f"Error loading prompt template: {e}")
#             return (
#                 "# ROLE\nYou are a creative writer.\n\n"
#                 "# THEME\n{user_input}\n\n"
#                 "# TASK\nPlease generate an engaging short story.\n"
#                 "# STYLE REQUIREMENTS\n- Tone: {tone}\n"
#             )
#
#     @classmethod
#     def format_prompt(cls, user_input: str, tone: str) -> str:
#         """Format the prompt by inserting the user input and tone into the template."""
#         base_prompt = cls.load_base_prompt()
#         return base_prompt.format(user_input=user_input, tone=tone)
#
# ```
#
# ---
#
# ### `solution.py`
#
# ```python
# from app.models.prompt_manager import PromptManager
#
# # Define sample inputs
# user_input = "A journey through time"
# tone = "Mysterious"
#
# # Call the format_prompt method with the sample inputs
# formatted_prompt = PromptManager.format_prompt(user_input=user_input, tone=tone)
#
# # Print the formatted prompt to verify output
# print("=== GENERATED PROMPT ===")
# print(formatted_prompt)
#
# ```

# %% [markdown]
# ## Testing Error Handling in PromptManager
#
# Now that you've implemented the format_prompt method, let's test the error handling in our PromptManager class! In real-world applications, things don't always go as planned — files might be missing, or paths might be incorrect. The error handling we built into our code helps make our application more reliable.
#
# In this exercise, you'll create a test script that deliberately triggers the error handling in the load_base_prompt method by using an incorrect file path. You'll then compare this with the normal behavior when using the correct path.
#
# Follow the TODO comments to:
#
#     Add a print statement explaining that you're testing with an incorrect file path, define a variable for an incorrect file path (e.g., 'data/nonexistent_file.txt'), and print the path you're attempting to use.
#     Call load_base_prompt with the incorrect path, store the result, and print the result after error handling (with a header before printing the actual result).
#     Add a print statement explaining that you're now testing with the correct file path, define a variable for the correct file path ('app/data/story_prompt_template.txt'), and print the path you're attempting to use.
#     Call load_base_prompt with the correct path, store the result, and print the result with the correct path (with a header before printing the actual result).
#     Add a comparison section that shows the difference between the two results by comparing the lengths of the strings.
#
# This exercise will show you how proper error handling prevents application crashes and provides fallback options when things go wrong — an essential skill for building robust applications that can handle unexpected situations.
#
# ```
# from app.models.prompt_manager import PromptManager
#
# # TODO: Add a print statement explaining that we're testing with an incorrect file path
# # Hint: Use a descriptive message that explains what we're about to do
#
# # TODO: Define a variable for an incorrect file path
# # Hint: Use a path to a file that doesn't exist, like 'data/nonexistent_file.txt'
#
# # TODO: Print the path we're attempting to use
#
# # TODO: Call load_base_prompt with the incorrect path and store the result
# # Hint: error_result = PromptManager.load_base_prompt(your_incorrect_path)
#
# # TODO: Print the result after error handling
# # Hint: Add a header before printing the actual result
#
# # TODO: Add a print statement explaining that we're now testing with the correct file path
# # Hint: Use a similar format to the first test for consistency
#
# # TODO: Define a variable for the correct file path
# # Hint: Use the default path 'app/data/story_prompt_template.txt'
#
# # TODO: Print the path we're attempting to use
#
# # TODO: Call load_base_prompt with the correct path and store the result
# # Hint: success_result = PromptManager.load_base_prompt(your_correct_path)
#
# # TODO: Print the result with the correct path
# # Hint: Add a header before printing the actual result
#
# # TODO: Add a comparison section that shows the difference between the two results
# # Hint: Compare the lengths of the strings to show they're different
#
#
#
# ```
#
# Here is the complete implementation for testing and comparing the error handling vs. successful execution in your `PromptManager`:
#
# ```python
# from app.models.prompt_manager import PromptManager
#
# # 1. Test with an incorrect file path
# print("\n" + "=" * 60)
# print("TEST 1: Testing PromptManager error handling with an incorrect file path...")
# print("=" * 60)
#
# incorrect_path = 'data/nonexistent_file.txt'
# print(f"Attempting to load template from: '{incorrect_path}'")
#
# error_result = PromptManager.load_base_prompt(incorrect_path)
#
# print("\n--- Fallback Result (Error Handled) ---")
# print(error_result)
#
#
# # 2. Test with the correct file path
# print("\n" + "=" * 60)
# print("TEST 2: Testing PromptManager with the correct file path...")
# print("=" * 60)
#
# correct_path = 'app/data/story_prompt_template.txt'
# print(f"Attempting to load template from: '{correct_path}'")
#
# success_result = PromptManager.load_base_prompt(correct_path)
#
# print("\n--- Success Result (Template Loaded) ---")
# print(success_result)
#
#
# # 3. Comparison Section
# print("\n" + "=" * 60)
# print("COMPARISON SUMMARY")
# print("=" * 60)
# print(f"Fallback prompt character count : {len(error_result)} chars")
# print(f"Template prompt character count : {len(success_result)} chars")
#
# if len(error_result) != len(success_result):
#     print("✓ Success! The error handling returned a fallback prompt without crashing the program.")
#
# ```

# %% [markdown]
# ## Comprehensive PromptManager Testing
