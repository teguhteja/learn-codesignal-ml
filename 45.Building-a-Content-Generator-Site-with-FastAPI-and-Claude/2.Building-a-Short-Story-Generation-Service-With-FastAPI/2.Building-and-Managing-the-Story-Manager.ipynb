# %% [markdown]
# ## Building and Managing the Story Manager
#
# # Unit 2: Building the Story Manager
#
# Welcome to the second unit of our course, where we will focus on building the **Story Manager** for our short story generation service. In the previous lesson, we laid the foundation by creating a structured base prompt using a prompt management system. Now, we will take the next step by developing a system to manage and store the stories generated by our service. The Story Manager will allow us to save, retrieve, and organize stories, making it a crucial component of our application.
#
# Before we dive into building the Story Manager, let's briefly recall some fundamental concepts:
#
# * **Class:** A blueprint for creating objects, allowing us to group related data and functionality together.
# * **Collection:** A way to store multiple items together, such as a list of stories.
#
# We will use these concepts to create and manage our stories efficiently.
#
# ---
#
# ## Creating the StoryManager Class
#
# Let's start by defining the structure for our Story Manager. This component will be responsible for managing our stories:
#
# ```python
# class StoryManager:
#     def __init__(self):
#         self.stories = []
#
# ```
#
# Here, we define a class named `StoryManager`. Inside this class, we set up a collection called `stories` that will hold our generated stories. This collection is initialized as empty, ready to store stories as they are created.
#
# > **Note:** This implementation keeps stories in memory only during the program’s execution. Once the program stops, the stored stories are lost. For long-term persistence, we’ll later need to store them in a database or file.
#
# ---
#
# ## Adding Stories to the Manager
#
# Next, we need a way to add stories to our manager. Let's create a method that allows us to do this:
#
# ```python
# def add_story(self, prompt, story):
#     self.stories.append({"id": len(self.stories), "prompt": prompt, "story": story})
#     return self.stories[-1]
#
# ```
#
# The `add_story` method takes two pieces of information: the `prompt` and the `story` itself. It creates a new entry containing a unique identifier (based on the current number of stories), the prompt, and the story. This entry is added to the collection of stories. The method then returns the newly added story, allowing us to confirm that it was successfully stored.
#
# ---
#
# ## Retrieving Stories
#
# To make our Story Manager useful, we need to be able to retrieve stories. Let's implement methods for this purpose:
#
# ```python
# def get_stories(self):
#     return self.stories
#
# def get_story_by_id(self, id):
#     return self.stories[id] if 0 <= id < len(self.stories) else None
#
# ```
#
# * The `get_stories` method returns the entire collection of stories, allowing us to access all stored stories at once.
# * The `get_story_by_id` method retrieves a specific story using its unique identifier. This is useful when we want to access a particular story without going through the entire collection.
#
# ---
#
# ## Implementing and Testing the StoryManager
#
# Now that we have our `StoryManager` class, let's see how to use it in practice. We'll implement a simple script to test our class:
#
# ```python
# from models.story_manager import StoryManager
#
# story_manager = StoryManager()
#
# fake_story_data = "This is a sample story generated by Claude."
# prompt = "Test prompt for StoryManager"
#
# result = story_manager.add_story(prompt, fake_story_data)
#
# print("Story Added Successfully:")
# print(result)
#
# print("\nAll Stored Stories:")
# print(story_manager.get_stories())
#
# ```
#
# In this script:
#
# 1. We import the `StoryManager` class.
# 2. We create an instance of `StoryManager`.
# 3. We simulate adding a story using a test prompt and fake story data.
# 4. The `add_story` method is called, and the result is printed to confirm the addition.
# 5. Finally, we print all stored stories using the `get_stories` method.
#
# ---
#
# ## Summary and Preparation for Practice
#
# In this lesson, we built the `StoryManager` class, which is essential for managing and storing stories in our short story generation service. We covered how to create the class, add stories with unique IDs, and retrieve them.
#
# As you move on to the practice exercises, you'll have the opportunity to apply these concepts and solidify your understanding. Remember, managing data effectively is key to building robust applications. Keep up the great work, and get ready to put your skills into practice!

# %% [markdown]
# ## Fix the get_story_by_id Method in StoryManager Class
#
# Now that we've built the basic structure of our StoryManager class, let's fix a bug that prevents us from retrieving specific stories. You'll notice that the get_story_by_id method is missing a crucial parameter, making it impossible to specify which story to retrieve.
#
# Following the TODO comments, your task is to:
#
#     Update the get_story_by_id method to correctly accept an id parameter.
#     Fix the method to properly return the story with the specified ID.
#     Add code to solution.py to test your fixed method by retrieving and displaying a story by its ID.
#
# This exercise will help you practice proper method parameter usage and basic debugging skills — essential abilities for any developer. By fixing this method, you'll ensure our story management system can properly access individual stories, which will be critical when we build the web interface later.
#
# ```
# # story_manager.py
# class StoryManager:
#     def __init__(self):
#         self.stories = []  # List to store generated stories
#
#     def add_story(self, prompt, story):
#         """Save story and return the id"""
#         self.stories.append({"id": len(self.stories), "prompt": prompt, "story": story})
#         return self.stories[-1]
#
#     def get_stories(self):
#         """Retrieve all generated stories."""
#         return self.stories
#
#     # TODO: Fix this method to correctly accept an id parameter
#     def get_story_by_id(self):
#         """Retrieve a story by id."""
#         return self.stories[id]
#
#
# # solution.py
# from app.models.story_manager import StoryManager
#
# story_manager = StoryManager()
# fake_story_data = "This is a sample story generated by Claude."  # Simulated story data
# prompt = "Test prompt for StoryManager"
#
# result = story_manager.add_story(prompt, fake_story_data)
# print("Story Added Successfully:")
# print(result)
# print("\nAll Stored Stories:")
# print(story_manager.get_stories())
#
# # TODO: Add code to test the get_story_by_id method
# # Retrieve a story with ID 0 and print it
# ```
#
# Here is the complete implementation with the fixed `get_story_by_id` method and the test code in `solution.py`:
#
# ### `app/models/story_manager.py`
#
# ```python
# class StoryManager:
#     def __init__(self):
#         self.stories = []  # List to store generated stories
#
#     def add_story(self, prompt, story):
#         """Save story and return the id"""
#         self.stories.append({"id": len(self.stories), "prompt": prompt, "story": story})
#         return self.stories[-1]
#
#     def get_stories(self):
#         """Retrieve all generated stories."""
#         return self.stories
#
#     def get_story_by_id(self, id):
#         """Retrieve a story by id with boundary checks."""
#         if 0 <= id < len(self.stories):
#             return self.stories[id]
#         return None
#
# ```
#
# ---
#
# ### `solution.py`
#
# ```python
# from app.models.story_manager import StoryManager
#
# story_manager = StoryManager()
# fake_story_data = "This is a sample story generated by Claude."  # Simulated story data
# prompt = "Test prompt for StoryManager"
#
# # Add a test story
# result = story_manager.add_story(prompt, fake_story_data)
# print("Story Added Successfully:")
# print(result)
#
# print("\nAll Stored Stories:")
# print(story_manager.get_stories())
#
# # Test the fixed get_story_by_id method
# print("\nRetrieving Story by ID (ID = 0):")
# retrieved_story = story_manager.get_story_by_id(0)
#
# if retrieved_story:
#     print("Found Story:")
#     print(retrieved_story)
# else:
#     print("Story with ID 0 was not found.")
#
# ```

# %% [markdown]
# ## Testing the StoryManager with Multiple Stories
#
# Now that you've fixed the bug in our get_story_by_id method, let's put our StoryManager to the test! You'll create a comprehensive test script to verify that our story management system works correctly with multiple stories.
#
# Your task is to create a test script that:
#
#     Adds at least three different stories with unique prompts and content
#     Retrieves all stories using the get_stories() method
#     Prints the results to verify that each story has a unique ID and is stored properly
#     Tests retrieving a specific story by ID
#
# This exercise will help you understand how the StoryManager handles multiple stories and how the ID assignment works automatically. By thoroughly testing the class, you'll gain confidence in its functionality before we integrate it into our web application.
#
# ```
# from app.models.story_manager import StoryManager
#
# # Create a StoryManager instance
# story_manager = StoryManager()
#
# # TODO: Add at least 3 different stories with unique prompts and content
# # Example of adding one story:
# # story_manager.add_story("Your prompt here", "Your story content here")
#
#
# # TODO: Retrieve all stories using the get_stories method
#
#
# # TODO: Print the results to verify:
# # - Each story has a unique ID
# # - The stories are stored properly
# # - IDs are assigned in order (0, 1, 2, etc.)
#
#
# # TODO: Test retrieving a specific story by ID
# ```
#
# Here is the complete test script demonstrating how the `StoryManager` handles multiple stories, auto-assigns zero-indexed sequential IDs, and retrieves individual entries cleanly:
#
# ```python
# from app.models.story_manager import StoryManager
#
# # Create a StoryManager instance
# story_manager = StoryManager()
#
# # 1. Add 3 different stories with unique prompts and content
# print("=== ADDING STORIES ===")
# story_manager.add_story(
#     "A lone astronaut discovers an ancient ruin on Mars.",
#     "Captain Vance stepped onto the dusty red soil, his flashlight illuminating symbols carved into the stone monolith..."
# )
#
# story_manager.add_story(
#     "A detective who can talk to house plants solves a crime.",
#     "The ficus in the corner rustled softly. 'He dropped the key behind the radiator,' it whispered..."
# )
#
# story_manager.add_story(
#     "A young baker discovers a secret recipe that cures sadness.",
#     "With a dash of cinnamon and a pinch of star anise, Maya pulled the golden loaf from the oven. Anyone who took a bite felt an overwhelming sense of peace..."
# )
#
# # 2. Retrieve all stories using get_stories()
# all_stories = story_manager.get_stories()
#
# # 3. Print and verify all stored stories
# print("\n=== VERIFYING ALL STORED STORIES ===")
# print(f"Total stories stored: {len(all_stories)}\n")
#
# for story in all_stories:
#     print(f"ID     : {story['id']}")
#     print(f"Prompt : {story['prompt']}")
#     print(f"Content: {story['story'][:80]}...")  # Display truncated preview
#     print("-" * 50)
#
# # 4. Test retrieving a specific story by ID
# print("\n=== RETRIEVING SPECIFIC STORY BY ID ===")
# target_id = 1
# retrieved_story = story_manager.get_story_by_id(target_id)
#
# if retrieved_story:
#     print(f"✓ Successfully retrieved Story #{target_id}:")
#     print(f"Prompt : {retrieved_story['prompt']}")
#     print(f"Story  : {retrieved_story['story']}")
# else:
#     print(f"❌ Failed to find story with ID {target_id}")
#
# ```

# %% [markdown]
# ## Implementing Error Handling for Invalid Story IDs

# %% [markdown]
# ## Implementing Keyword Search for Story Manager
