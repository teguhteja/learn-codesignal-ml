# %% [markdown]
# # Lesson 1: Probability Basics
#
#
# Welcome to our lesson on **"Probability Basics"!** This topic is crucial for making predictions and understanding uncertainties in machine learning. By the end of this lesson, you'll grasp the essentials of probability and learn how to calculate probabilities for various events using Python.
#
# ---
#
# ## What is Probability?
#
# Probability measures the likelihood of an event happening, quantifying uncertainty. For example, what are the chances it will rain tomorrow, or that a flipped coin will land on heads?
#
# Mathematically, the probability \( P(E) \) of an event \( E \) happening can be represented as:
#
# \[
# P(E) = \frac{\text{Number of favorable outcomes}}{\text{Total number of possible outcomes}}
# \]
#
# Probability ranges from 0 (impossible event) to 1 (certain event).
#
# ---
#
# ## Example: Using a Deck of Cards
#
# A standard deck has 52 cards. We'll calculate probabilities for different events using these cards.
#
# ### 1. **Probability of Drawing a Specific Card**
#
# Example: Probability of drawing an Ace.
#
# \[
# P(\text{Ace}) = \frac{\text{Number of Aces}}{\text{Total cards}} = \frac{4}{52}
# \]
#
# **Python Code:**
#
# ```python
# # Total number of cards in a standard deck
# total_cards = 52
#
# # Number of Aces in a standard deck
# aces = 4
#
# # Probability of drawing an Ace
# probability_of_ace = aces / total_cards
# print(f"Probability of drawing an Ace: {probability_of_ace:.2f}")
# ```
#
# Output: `Probability of drawing an Ace: 0.08`
#
# ---
#
# ### 2. **Probability of Drawing a Card of a Specific Suit**
#
# Example: Probability of drawing a card from the Hearts suit.
#
# \[
# P(\text{Hearts}) = \frac{\text{Number of Hearts}}{\text{Total cards}} = \frac{13}{52}
# \]
#
# **Python Code:**
#
# ```python
# # Number of cards from the Hearts suit
# cards_of_suit = 13
#
# # Probability of drawing a card from the Hearts suit
# probability_of_suit = cards_of_suit / total_cards
# print(f"Probability of drawing a card from the Hearts suit: {probability_of_suit:.2f}")
# ```
#
# Output: `Probability of drawing a card from the Hearts suit: 0.25`
#
# ---
#
# ## Probability Addition Rule
#
# ### a. **Mutually Exclusive Events**
#
# The probability of one of two mutually exclusive events happening is the sum of their individual probabilities.
#
# Example: Probability of drawing either an Ace or a King.
#
# \[
# P(\text{Ace or King}) = P(\text{Ace}) + P(\text{King})
# \]
#
# **Python Code:**
#
# ```python
# # Number of Kings in a standard deck
# kings = 4
#
# # Probability of drawing a King
# probability_of_king = kings / total_cards
#
# # Probability of drawing an Ace or a King
# probability_of_ace_or_king = probability_of_ace + probability_of_king
# print(f"Probability of drawing an Ace or a King: {probability_of_ace_or_king:.2f}")
# ```
#
# Output: `Probability of drawing an Ace or a King: 0.15`
#
# ---
#
# ### b. **Non-Mutually Exclusive Events**
#
# For events that can occur simultaneously, subtract the probability of both happening to avoid double-counting.
#
# Example: Probability of drawing either an Ace or a Heart.
#
# \[
# P(\text{Ace or Heart}) = P(\text{Ace}) + P(\text{Heart}) - P(\text{Ace of Hearts})
# \]
#
# **Python Code:**
#
# ```python
# # Number of Ace of Hearts
# ace_of_hearts = 1
#
# # Probability of drawing an Ace or a Heart
# probability_of_ace_or_heart = probability_of_ace + probability_of_suit - (ace_of_hearts / total_cards)
# print(f"Probability of drawing an Ace or a Heart: {probability_of_ace_or_heart:.2f}")
# ```
#
# Output: `Probability of drawing an Ace or a Heart: 0.31`
#
# ---
#
# ## Probability Multiplication Rule
#
# ### a. **Independent Events**
#
# For events that do not affect each other, multiply their individual probabilities.
#
# Example: Probability of drawing an Ace and then a King with replacement.
#
# \[
# P(\text{Ace and then King}) = P(\text{Ace}) \times P(\text{King})
# \]
#
# **Python Code:**
#
# ```python
# # Probability of drawing an Ace and then a King with replacement
# probability_of_ace_and_king = probability_of_ace * probability_of_king
# print(f"Probability of drawing an Ace and then a King: {probability_of_ace_and_king:.4f}")
# ```
#
# Output: `Probability of drawing an Ace and then a King: 0.0059`
#
# ---
#
# ### b. **Dependent Events**
#
# For events where one affects the other, adjust probabilities accordingly.
#
# Example: Probability of drawing an Ace and then a King without replacement.
#
# \[
# P(\text{Ace and then King}) = P(\text{Ace}) \times P(\text{King | Ace drawn})
# \]
#
# **Python Code:**
#
# ```python
# # Probability of drawing a King given an Ace has been drawn
# probability_of_king_given_ace_drawn = kings / (total_cards - 1)
#
# # Probability of drawing an Ace and then a King without replacement
# probability_of_ace_and_king_no_replace = probability_of_ace * probability_of_king_given_ace_drawn
# print(f"Probability of drawing an Ace and then a King: {probability_of_ace_and_king_no_replace:.4f}")
# ```
#
# Output: `Probability of drawing an Ace and then a King: 0.0060`
#
# ---
#
# ## Lesson Summary
#
# Great job! Today we covered:
#
# 1. **Basic Probability Concepts**:
#    - Mutually exclusive and non-mutually exclusive events.
#    - Independent and dependent events.
#
# 2. **Probability Calculations**:
#    - Using Python for practical examples.
#
# You should now feel confident with these probability basics. Next, practice these concepts to solidify your understanding. Let's move on to the exercises!

# %%
import numpy as np

def calculate_probability(favorable_outcomes, total_outcomes):
    """
    Calculate basic probability
    """
    return favorable_outcomes / total_outcomes

# Example: Probability of rolling a 6 on a fair die
prob_six = calculate_probability(1, 6)
print(f"Probability of rolling a 6: {prob_six:.2f}")

def conditional_probability(joint_prob, marginal_prob):
    """
    Calculate conditional probability
    P(A|B) = P(A∩B) / P(B)
    """
    return joint_prob / marginal_prob

# Example calculation
event_a = 0.3  # Probability of event A
event_b = 0.4  # Probability of event B
joint_prob = 0.2  # Probability of both events occurring

cond_prob = conditional_probability(joint_prob, event_b)
print(f"Conditional Probability: {cond_prob:.2f}")

# Created/Modified files during execution:
# No files created or modified

import matplotlib.pyplot as plt

def plot_normal_distribution(mean, std):
    """
    Plot normal distribution
    """
    x = np.linspace(mean - 4*std, mean + 4*std, 100)
    y = 1/(std * np.sqrt(2*np.pi)) * np.exp(-(x-mean)**2/(2*std**2))
    return x, y

# Example visualization
x, y = plot_normal_distribution(0, 1)
plt.plot(x, y)
plt.title("Standard Normal Distribution")
plt.show()
# Out:
# Probability of rolling a 6: 0.17
# Conditional Probability: 0.50

# %% [markdown]
# ## Probability of Rolling a 2 on a Die

# %% [markdown]
# ## Probability of Rolling 6 on Two Dice

# %% [markdown]
# ## Calculating Probability of Rolling a 6 or 5 on a Dice

# %% [markdown]
# ## Rolling a 6 on One Die and Not a 6 on the Other Die

# %% [markdown]
# ## Calculate Probability of Even or Divisible by Six Rolls

# %% [markdown]
# ## Conditional Probability of Drawing a Heart Given an Ace
