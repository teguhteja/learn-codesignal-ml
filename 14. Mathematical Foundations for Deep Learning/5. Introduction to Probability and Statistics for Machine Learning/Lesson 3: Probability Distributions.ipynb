# %% [markdown]
# # Lesson 3: Probability Distributions
#
# Hello! Today, we'll explore **Probability Distributions**, a key concept in statistics and machine learning.
# By the end of this lesson, you'll understand:
# - What probability distributions are,
# - Why they're essential, and
# - How to work with them in Python.
#
# Probability distributions help us understand how data behaves and the likelihood of different outcomes. They’re used in everyday tasks like predicting weather, recommending movies, and much more. Let's dive in!
#
# ---
#
# ## Understanding Probability Distributions
# A **Probability Distribution** describes how values of a random variable are distributed. It tells us the chances of different outcomes.
#
# Example: Rolling a six-sided die. Each number (1 to 6) has an equal chance of appearing.
#
# ### Why Probability Distributions Matter:
# 1. They help us understand data behavior.
# 2. They allow us to make predictions and decisions.
# 3. They are used in various fields like finance, medicine, and machine learning.
#
# ---
#
# ## Normal Distribution: Part 1
# The **Normal Distribution** (or Gaussian Distribution) is one of the most important probability distributions. Many natural phenomena follow this distribution, such as heights, IQ scores, and measurement errors.
#
# ### Key Characteristics:
# - **Shape**: Bell-shaped curve symmetrical around the mean.
# - **Parameters**:
#   - **Mean (μ)**: Average of all values.
#   - **Standard Deviation (σ)**: Measures how spread out values are from the mean.
#
# ### Example:
# Heights of adult men in a town have:
# - Mean (μ) = 70 inches
# - Standard Deviation (σ) = 3 inches
#
# Most men are around 70 inches tall, with fewer being much shorter or taller.
#
# ---
#
# ## Generating a Normal Distribution Sample in Python
# Let's generate a sample of 1,000 data points with:
# - Mean (μ) = 0
# - Standard Deviation (σ) = 1
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# mu = 0  # Mean
# sigma = 1  # Standard Deviation
# sample = np.random.normal(mu, sigma, 1000)  # Generate 1,000 data points
#
# # Plot the histogram
# plt.hist(sample, bins=30, density=True, alpha=0.6, color='g')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram of Normal Distribution Sample')
# plt.show()
# ```
#
# ---
#
# ## Normal Distribution: Part 2
# Increasing the number of data points and bins creates a plot closer to the iconic bell curve.
#
# ### Mathematical Formula for Normal Distribution:
# The **Probability Density Function (PDF)** is:
# \[
# f(x|\mu, \sigma^2) = \frac{1}{\sqrt{2\pi\sigma^2}} \exp\left(-\frac{(x-\mu)^2}{2\sigma^2}\right)
# \]
#
# ---
#
# ## Visualizing the PDF
# The **PDF** describes the likelihood of a random variable taking a specific value in a small interval.
#
# ```python
# from scipy.stats import norm
#
# # Parameters
# mu = 0
# sigma = 1
#
# # Generate x values and calculate PDF
# x = np.linspace(-3*sigma, 3*sigma, 1000)
# pdf = norm.pdf(x, mu, sigma)
#
# # Plot the PDF
# plt.plot(x, pdf, 'b-', lw=2)
# plt.xlabel('Value')
# plt.ylabel('Probability Density')
# plt.title('Probability Density Function (PDF)')
# plt.show()
# ```
#
# ---
#
# ## Visualizing the CDF
# The **Cumulative Distribution Function (CDF)** gives the probability that a random variable is less than or equal to a certain value.
#
# ```python
# # Calculate CDF for x values
# cdf = norm.cdf(x, mu, sigma)
#
# # Plot the CDF
# plt.plot(x, cdf, 'r-', lw=2)
# plt.xlabel('Value')
# plt.ylabel('Cumulative Probability')
# plt.title('Cumulative Distribution Function (CDF)')
# plt.show()
# ```
#
# ---
#
# ## Using CDF to Evaluate Probability
# **Example**: Calculate the probability of a value being between -1 and 1.
#
# Steps:
# 1. Find \( P(X \leq 1) \) (CDF at 1).
# 2. Find \( P(X \leq -1) \) (CDF at -1).
# 3. Subtract: \( P(-1 \leq X \leq 1) = P(X \leq 1) - P(X \leq -1) \).
#
# For \( \mu = 0, \sigma = 1 \):
# \[
# P(-1 \leq X \leq 1) = 0.84 - 0.16 = 0.68
# \]
#
# ---
#
# ## Lesson Summary
# Great job! 🎉 You've learned about **Probability Distributions**, focusing on the **Normal Distribution**. We covered:
# 1. Generating a normal distribution sample in Python,
# 2. Understanding concepts like PDF and CDF, and
# 3. Using the CDF to calculate probabilities.
#
# Next, practice generating distribution samples and calculating PDF and CDF values for different scenarios. Let's get started! 🚀

# %%
import numpy as np
import matplotlib.pyplot as plt

mu = 0  # mean
sigma = 1  # standard deviation
sample = np.random.normal(mu, sigma, 1000)  # generate a sample of 1000 data points

# Plot the sample
plt.hist(sample, bins=30, density=True, alpha=0.6, color='g')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Normal Distribution Sample')
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 1

# Calculate PDF for a range of values
x = np.linspace(-3*sigma, 3*sigma, 1000)
pdf = norm.pdf(x, mu, sigma)

# Plot the PDF
plt.plot(x, pdf, 'b-', lw=2)
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Probability Density Function (PDF) of Normal Distribution')
plt.show()

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

mu = 0
sigma = 1

# Calculate PDF for a range of values
x = np.linspace(-3*sigma, 3*sigma, 1000)
# Calculate CDF for a range of values
cdf = norm.cdf(x, mu, sigma)

# Plot the CDF
plt.plot(x, cdf, 'r-', lw=2)
plt.xlabel('Value')
plt.ylabel('Cumulative Probability')
plt.title('Cumulative Distribution Function (CDF) of Normal Distribution')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generate normal distribution
mu, sigma = 0, 1
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = norm.pdf(x, mu, sigma)

plt.plot(x, y)
plt.title('Normal Distribution')
plt.show()

# %%
from scipy.stats import binom

# Generate binomial distribution
n, p = 10, 0.5
k = np.arange(0, n+1)
binomial = binom.pmf(k, n, p)

plt.bar(k, binomial)
plt.title('Binomial Distribution')
plt.show()

# %% [markdown]
# ## Adjust and Plot PDFs with Different Standard Deviations
#
#
# Hey there, Space Wanderer! 🚀
#
# Imagine analyzing how the shape of the **Probability Density Function (PDF)** changes with different standard deviations (\( \sigma \)). By adjusting the \( \sigma \) values and plotting each corresponding PDF curve, you’ll visualize the impact of standard deviation on the shape of the distribution.
#
# Let’s get started!
#
# ```python
# from scipy.stats import norm
# import numpy as np
# import matplotlib.pyplot as plt
#
# mu = 0  # Mean
# sigmas = [0.5, 1, 2]  # List of different standard deviations
#
# # Generate a range of values
# x = np.linspace(-6, 6, 1000)
#
# # Calculate and plot the PDF for each sigma value in the list
# for sigma in sigmas:
#     pdf = norm.pdf(x, mu, sigma)  # Calculate the PDF for the current sigma
#     # Plot the PDF
#     plt.plot(x, pdf, label=f'sigma={sigma}')
#
# # Customize the plot
# plt.xlabel('Value')
# plt.ylabel('Probability Density')
# plt.title('PDF of Normal Distribution with Different Sigmas')
# plt.legend()
# plt.show()
# ```
#
# ### What This Code Does:
# 1. **Mean (\( \mu \))** is set to 0.
# 2. **Sigmas (\( \sigma \))**: A list of standard deviations `[0.5, 1, 2]`.
# 3. Generates a range of \( x \)-values from -6 to 6.
# 4. For each \( \sigma \):
#    - Calculates the PDF using `norm.pdf(x, mu, sigma)`.
#    - Plots the corresponding PDF curve.
# 5. Labels and visualizes the plots to compare how the PDF shape changes.
#
# ### Insights from the Plot:
# - **Smaller \( \sigma \)**: Results in a sharper, taller bell curve.
# - **Larger \( \sigma \)**: Results in a wider, flatter curve.
#
# Now it’s your turn! Run the code and observe how standard deviation influences the distribution. 🌠

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

mu = 0  # Mean
sigmas = [0.5, 1, 2]  # List of different standard deviations

# Generate a range of values
x = np.linspace(-6, 6, 1000)

# Calculate and plot the PDF for each sigma value in the list
for sigma in sigmas:
    pdf = norm.pdf(x, mu, sigma)  # Calculate the PDF for the current sigma
    # Plot the PDF
    plt.plot(x, pdf, label=f'sigma={sigma}')

# Customize the plot
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('PDF of Normal Distribution with Different Sigmas')
plt.legend()
plt.show()

# %% [markdown]
# ## Adjusting Mean Values and Plotting PDF
#
# Hey there, Space Explorer! 🚀
#
# You are tasked with completing code to plot the **Probability Density Function (PDF)** for normal distributions with different mean values (\( \mu \)). By completing and running the code, you’ll see how the mean affects the shape and position of the distribution curves.
#
# Let’s explore how the mean impacts these distributions. You got this! 💪
#
# ```python
# from scipy.stats import norm
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Define a list of different mean values
# mu_values = [-3, 0, 3]  # Example: means at -3, 0, and 3
# sigma = 1  # Fixed standard deviation
#
# # Generate a range of x-values
# x = np.linspace(-10, 10, 1000)
#
# # Create a figure
# plt.figure(figsize=(12, 6))
#
# # Calculate and plot the PDF for each mean value
# for mu in mu_values:
#     pdf = norm.pdf(x, mu, sigma)  # Calculate the PDF for each mean value
#     plt.plot(x, pdf, label=f'mu={mu}')  # Plot the PDF
#
# # Customize the plot
# plt.xlabel('Value')
# plt.ylabel('Probability Density')
# plt.title('PDF of Normal Distributions with Different Mean Values')
# plt.legend()
# plt.show()
# ```
#
# ### What This Code Does:
# 1. **Mean (\( \mu \))**: A list of different mean values `[−3, 0, 3]`.
# 2. **Standard Deviation (\( \sigma \))**: Fixed at 1 for all distributions.
# 3. Generates \( x \)-values ranging from -10 to 10.
# 4. For each \( \mu \):
#    - Calculates the PDF using `norm.pdf(x, mu, sigma)`.
#    - Plots the corresponding PDF curve.
# 5. Visualizes and labels the plot to compare the effect of different means.
#
# ### Insights from the Plot:
# - The **mean (\( \mu \))** determines the center of the distribution curve.
# - Curves shift horizontally based on the value of \( \mu \).
#
# Now it’s your turn to complete and run the code. Observe how the mean influences the position of the bell curve. 🌠
# ```

# %%
from scipy.stats import norm
import numpy as np
import matplotlib.pyplot as plt

# Define a list of different mean values
mu_values = [-3, 0, 3]  # Example: means at -3, 0, and 3
sigma = 1  # Fixed standard deviation

# Generate a range of x-values
x = np.linspace(-10, 10, 1000)

# Create a figure
plt.figure(figsize=(12, 6))

# Calculate and plot the PDF for each mean value
for mu in mu_values:
    pdf = norm.pdf(x, mu, sigma)  # Calculate the PDF for each mean value
    plt.plot(x, pdf, label=f'mu={mu}')  # Plot the PDF

# Customize the plot
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('PDF of Normal Distributions with Different Mean Values')
plt.legend()
plt.show()

# %% [markdown]
# ## Generate and Visualize Uniform Distribution Sample
#
# ```markdown
# # Exploring Uniform Distribution 🌟
#
# Great job, Space Wanderer! 🚀 Let's dive into **uniform distributions**, another fundamental type of distribution.
#
# In this task, you'll generate a sample from a uniform distribution and visualize it using a histogram. This will help you understand the characteristics of a uniform distribution, where all outcomes are equally likely.
#
# ### Here's the Code:
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Generate a uniform distribution sample
# sample = np.random.uniform(0, 1, 10000)
#
# # Plot the sample
# plt.hist(sample, bins=50, density=True, alpha=0.6, color='b')
# plt.xlabel('Value')
# plt.ylabel('Frequency')
# plt.title('Histogram of Uniform Distribution Sample')
# plt.show()
# ```
#
# ### What This Code Does:
# 1. **Generate Data**:
#    - Uses `np.random.uniform(0, 1, 10000)` to generate 10,000 random values uniformly distributed between 0 and 1.
# 2. **Plot the Data**:
#    - Visualizes the distribution using `plt.hist()`.
#    - Uses 50 bins for better resolution and `density=True` to normalize the histogram.
#    - Adds labels and a title for clarity.
#
# ### Key Insights About Uniform Distributions:
# - **Shape**: The histogram should appear as a flat (rectangular) distribution, reflecting equal likelihood for all values in the range.
# - **Range**: Values are strictly between 0 and 1 (in this example).
# - **Applications**: Used in simulations, random sampling, and scenarios where all outcomes have equal probability.
#
# Run the code and marvel at the simplicity and beauty of uniform distributions! 🌌
# ```

# %% [markdown]
# ## Plotting PDF and CDF of Exponential Distribution
#
#
# Great, Celestial Traveler! 🚀
#
# Let’s delve into the **Probability Density Function (PDF)** and **Cumulative Distribution Function (CDF)** of the **Exponential Distribution**. This distribution is characterized by the parameter **λ (lambda)**, represented as `lambda_param` in the code. Adjust this parameter to observe how it affects the plots.
#
# ---
#
# ### 📜 Code to Visualize the PDF and CDF:
#
# ```python
# from scipy.stats import expon
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Define lambda parameter
# lambda_param = 1
#
# # Calculate PDF for a range of values
# x = np.linspace(0, 10, 1000)
# pdf = expon.pdf(x, scale=1/lambda_param)
#
# # Calculate CDF for a range of values
# cdf = expon.cdf(x, scale=1/lambda_param)
#
# # Plot the PDF
# plt.figure(figsize=(12, 6))
#
# # Plot PDF
# plt.subplot(1, 2, 1)
# plt.plot(x, pdf, 'b-', lw=2)
# plt.xlabel('Value')
# plt.ylabel('Probability Density')
# plt.title('Probability Density Function (PDF) of Exponential Distribution')
#
# # Plot CDF
# plt.subplot(1, 2, 2)
# plt.plot(x, cdf, 'r-', lw=2)
# plt.xlabel('Value')
# plt.ylabel('Cumulative Probability')
# plt.title('Cumulative Distribution Function (CDF) of Exponential Distribution')
#
# plt.show()
# ```
#
# ---
#
# ### 🌟 What the Code Does:
# 1. **PDF Calculation**:
#    - The PDF describes the probability density of values within the distribution.
#    - Formula: \( \text{PDF}(x) = \lambda e^{-\lambda x} \)
#    - Implemented using `expon.pdf(x, scale=1/lambda_param)`.
#
# 2. **CDF Calculation**:
#    - The CDF gives the cumulative probability up to a certain value.
#    - Formula: \( \text{CDF}(x) = 1 - e^{-\lambda x} \)
#    - Implemented using `expon.cdf(x, scale=1/lambda_param)`.
#
# 3. **Visualization**:
#    - The left subplot displays the PDF.
#    - The right subplot displays the CDF.
#    - Adjust the `lambda_param` to observe changes in the curve's steepness.
#
# ---
#
# ### 🔍 Key Insights:
# - **Parameter λ (lambda)**:
#   - Controls the rate of decay of the exponential curve.
#   - Higher λ values make the distribution steeper (faster decay).
#   - Lower λ values make the distribution flatter (slower decay).
#
# - **Applications**:
#   - Used to model time intervals between events (e.g., waiting times, radioactive decay).
#
# ---
#
# Experiment with different **λ** values to see how the exponential distribution behaves. Happy exploring! 🌌

# %% [markdown]
# ## Plotting and Analyzing the CDF of a Normal Distribution
#
#
# Hello, Space Voyager! 🌌
#
# You're tasked with completing the code to plot the **Cumulative Distribution Function (CDF)** of human heights, modeled as a normal distribution with a mean of **170 cm** and a standard deviation of **10 cm**. After plotting, calculate and print the probability of a person having a height less than **165 cm**.
#
# ---
#
# ### 📜 Complete Code:
#
# ```python
# from scipy.stats import norm
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Mean and standard deviation
# mu = 170  # mean height in cm
# sigma = 10  # standard deviation in cm
#
# # Calculate CDF for a range of values
# x = np.linspace(mu - 3 * sigma, mu + 3 * sigma, 1000)
# cdf = norm.cdf(x, loc=mu, scale=sigma)  # Calculate the CDF
#
# # Plot the CDF
# plt.plot(x, cdf, 'r-', lw=2, label='CDF of Height')
# plt.xlabel('Height (cm)')
# plt.ylabel('Cumulative Probability')
# plt.title('Cumulative Distribution Function (CDF) of Human Heights')
# plt.legend()
# plt.grid()
# plt.show()
#
# # Find and print the probability of a height less than 165 cm
# probability = norm.cdf(165, loc=mu, scale=sigma)  # Probability for height < 165 cm
# print(probability)  # Output the probability
# ```
#
# ---
#
# ### 🌟 Code Explanation:
#
# 1. **Define Parameters**:
#    - `mu` = 170 cm (average height).
#    - `sigma` = 10 cm (standard deviation).
#
# 2. **Generate CDF**:
#    - Use `norm.cdf(x, loc=mu, scale=sigma)` to calculate the CDF for the range of heights defined by `x`.
#
# 3. **Plot CDF**:
#    - Use Matplotlib to plot the curve, labeling axes and adding a grid for clarity.
#
# 4. **Calculate Probability for Height < 165 cm**:
#    - Use `norm.cdf(165, loc=mu, scale=sigma)` to calculate the cumulative probability for heights less than **165 cm**.
#
# ---
#
# ### 🔍 Key Insights:
# - **CDF Visualization**:
#   - The curve represents cumulative probabilities, starting from 0 and approaching 1 as height increases.
#
# - **Real-Life Application**:
#   - This technique can estimate probabilities for various height ranges within a population.
#
# ---
#
# ### ✅ Example Output:
# If the probability of height < 165 cm is **30.85%**, the output will be:
# ```plaintext
# 0.3085
# ```
#
# Explore and experiment to solidify your understanding. You've got this, Space Voyager! 🚀
# ```

# %% [markdown]
# ## Plotting the CDF of Uniform Distribution for Sunlight Hours
#
# Here’s the solution to your task. Let's calculate the probability of having between 2 and 6 hours of sunlight using the **CDF of a uniform distribution**.
#
# ---
#
# ### 📜 Code with Solution:
#
# ```python
# from scipy.stats import uniform
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Set parameters for the uniform distribution
# a = 0  # minimum value
# b = 10  # maximum value
#
# # Generate data for uniform distribution
# x = np.linspace(a, b, 1000)
# # Calculate CDF
# cdf = uniform.cdf(x, loc=a, scale=b-a)
#
# # Plot the CDF
# plt.plot(x, cdf, 'r-', lw=2)
# plt.xlabel('Daily Sunlight Hours')
# plt.ylabel('Cumulative Probability')
# plt.title('Cumulative Distribution Function (CDF) of Daily Sunlight Hours')
# plt.grid()
# plt.show()
#
# # Calculate the probability of having [2, 6] hours of sunlight
# p_2 = uniform.cdf(2, loc=a, scale=b-a)  # CDF value at 2
# p_6 = uniform.cdf(6, loc=a, scale=b-a)  # CDF value at 6
# probability = p_6 - p_2  # Probability for the range [2, 6]
#
# print(f"Probability of having between 2 and 6 hours of sunlight: {probability:.4f}")
# ```
#
# ---
#
# ### 🔍 Key Steps:
#
# 1. **Define the Uniform Distribution**:
#    - `a = 0`: Minimum value of daily sunlight hours.
#    - `b = 10`: Maximum value of daily sunlight hours.
#    - The uniform distribution has a constant probability density.
#
# 2. **Generate the CDF**:
#    - Use `uniform.cdf(x, loc=a, scale=b-a)` to calculate the CDF over the range [0, 10].
#
# 3. **Calculate the Probability for [2, 6]**:
#    - Compute `CDF(6) - CDF(2)` to find the probability of sunlight hours being within the interval [2, 6].
#
# 4. **Visualize the CDF**:
#    - Plot the curve to observe how cumulative probability increases linearly for the uniform distribution.
#
# ---
#
# ### ✅ Example Output:
# For the range [2, 6]:
# ```plaintext
# Probability of having between 2 and 6 hours of sunlight: 0.4000
# ```
#
# ---
#
# This result shows that 40% of the total probability lies between 2 and 6 hours in a uniform distribution ranging from 0 to 10 hours. Great work, Space Wanderer! 🌞🚀
