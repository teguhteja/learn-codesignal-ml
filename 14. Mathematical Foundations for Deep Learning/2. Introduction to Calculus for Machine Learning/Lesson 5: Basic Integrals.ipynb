# %% [markdown]
# # Lesson 5: Basic Integrals
#
# Welcome! Today, we'll explore **integrals**, a fundamental concept in calculus that's key to many machine learning applications. Integrals help us understand areas under curves, representing things like accumulated quantities over time. By the end of this lesson, you'll know what integrals are, why they're important, and how to compute them using Python.
#
# ---
#
# ## Introduction to Integrals
#
# An **integral** in calculus sums infinite tiny pieces to calculate the total area under a curve. This is useful in many real-life situations. For example, measuring the distance a car travels by knowing its speed over time. The integral helps us accumulate those tiny speed changes to find the total distance.
#
# ### Types of Integrals
# 1. **Indefinite Integral**: Represents a family of functions and includes a constant of integration.
# 2. **Definite Integral**: Calculates the exact area under the curve between two points, \(a\) and \(b\).
#
# ---
#
# ## Area Approximation
#
# The simplest way to calculate a complex area is to approximate it with rectangles.
#
# **Example: \(y = x^2\) curve**
#
# Using 10 rectangles:
# ![Approximation with 10 Rectangles](example_10_rectangles.png)
#
# Using 20 rectangles:
# ![Approximation with 20 Rectangles](example_20_rectangles.png)
#
# As the number of rectangles increases, the approximation becomes more accurate.
#
# ### Formula for Area Approximation:
# \[
# \text{Area} \approx \sum_{i=1}^n f(x_i^*) \Delta x
# \]
# Where:
# - \(f(x_i^*)\): Height of the rectangle at sample point \(x_i^*\).
# - \(\Delta x = \frac{b-a}{n}\): Width of each rectangle.
#
# ---
#
# ## Understanding Integrals
#
# To get the exact area under a curve, we take the approximation to the limit by using **infinitely many rectangles** with infinitely small sizes.
#
# ### The Integral Formula:
# \[
# \int_a^b f(x) \, dx = \lim_{n \to \infty} \sum_{i=1}^n f(x_i^*) \Delta x
# \]
# Where:
# - \(\int_a^b f(x) \, dx\): Represents the exact area under the curve from \(a\) to \(b\).
# - \(\Delta x = \frac{b-a}{n}\): Width of each rectangle.
# - \(x_i^*\): A sample point in the \(i\)-th subinterval.
#
# ---
#
# ## Calculating Integrals with the Fundamental Theorem of Calculus
#
# The **Fundamental Theorem of Calculus** links differentiation and integration. It states that if \(F(x)\) is the antiderivative of \(f(x)\), then:
# \[
# \int_a^b f(x) \, dx = F(b) - F(a)
# \]
#
# ---
#
# ## Example: Integrating \(f(x) = x^2\)
#
# ### Steps:
# 1. **Find the Antiderivative**:
#    \[
#    F(x) = \frac{x^3}{3} + C
#    \]
#
# 2. **Evaluate at the Bounds**:
#    \[
#    F(1) = \frac{1^3}{3} = \frac{1}{3}, \quad F(0) = \frac{0^3}{3} = 0
#    \]
#
# 3. **Subtract the Values**:
#    \[
#    \int_0^1 x^2 \, dx = F(1) - F(0) = \frac{1}{3} - 0 = \frac{1}{3}
#    \]
#
# Result: The integral of \(x^2\) from 0 to 1 is \(\frac{1}{3}\).
#
# ---
#
# ## Numerical Integration: Trapezoidal Rule
#
# When exact integration is challenging, numerical methods like the **Trapezoidal Rule** approximate the area by dividing it into small trapezoids.
#
# ### Python Example:
#
# ```python
# import numpy as np
#
# def integrate(f, a, b, n=1000):
#     x = np.linspace(a, b, n)  # Generate n points between a and b
#     y = f(x)  # Apply function to each point
#     area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
#     return area
#
# # Sample function: f(x) = x^2
# f = lambda x: x**2
#
# # Compute integral of f from 0 to 1
# result = integrate(f, 0, 1)
# print("Integral of f(x) from 0 to 1:", result)  # Output: 0.3333335
# ```
#
# ---
#
# ### Step-by-Step Explanation:
# 1. **Import Libraries**: Use `numpy` for numerical operations.
# 2. **Define Integration Function**: The `integrate` function takes a function \(f\), limits \(a\) and \(b\), and the number of points \(n\).
# 3. **Generate Points**: Use `np.linspace` to create evenly spaced points between \(a\) and \(b\).
# 4. **Apply the Function**: Evaluate \(f(x)\) for each point.
# 5. **Calculate the Area**: Use `np.trapz` for numerical integration.
#
# Result: The numerical result, \(0.3333335\), is very close to the exact solution \(\frac{1}{3}\).
#
# ---
#
# ## Lesson Summary
#
# Fantastic! You've learned:
# 1. **Basics of Integrals**: Their significance in understanding areas under curves.
# 2. **Approximation Techniques**: Using rectangles and trapezoids.
# 3. **Exact Integration**: Via the Fundamental Theorem of Calculus.
# 4. **Numerical Integration**: Python implementation of the Trapezoidal Rule.
#
# Now it's time to practice! In the next session, you'll compute integrals of different functions and explore real-world applications of numerical integration.
#
# Let's dive in and solidify your understanding! 🚀
#
# ---

# %% [markdown]
# ## Adjust the Limits of Integration
#
# Here is the fixed markdown version of your code with the necessary adjustments and an explanation:
#
# ```markdown
# # Numerical Integration Using the Trapezoidal Rule
#
# Hey there, Stellar Navigator! 🎉
#
# Let's compute the area under the curve \( f(x) = x^2 \) from \( x = -1 \) to \( x = 2 \) using the **trapezoidal_rule** function. Update the limits in the code below, and visualize the result with a plot!
#
# ---
#
# ### Python Code
#
# ```python
# # Numerical integration using the trapezoidal rule
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Function for numerical integration
# def integrate(f, a, b, n=1000):
#     x = np.linspace(a, b, n)  # Generate n points between a and b
#     y = f(x)  # Apply function to each point
#     area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
#     return area, x, y
#
# # Sample function: f(x) = x^2
# f = lambda x: x**2
#
# # Set the limits of integration
# a = -1
# b = 2
#
# # Compute integral of f(x) from -1 to 2
# result, x, y = integrate(f, a, b)
# print("Integral of f(x) from -1 to 2:", result)  # Integral of f(x) from -1 to 2: 2.333333
#
# # Plotting the function and the area under the curve
# plt.figure(figsize=(8, 6))
# plt.plot(x, y, label='$f(x) = x^2$', color='blue')
# plt.fill_between(x, y, where=(x >= a) & (x <= b), color='skyblue', alpha=0.4)
# plt.axhline(0, color='black', lw=1)
# plt.axvline(0, color='black', lw=1)
# plt.title('Area under $f(x) = x^2$ from $x=-1$ to $x=2$')
# plt.xlabel('x')
# plt.ylabel('$f(x)$')
# plt.legend()
# plt.show()
# ```
#
# ---
#
# ### Key Changes Made:
# 1. **Adjusted Limits:** Set the integration bounds as \( a = -1 \) and \( b = 2 \) to reflect the new limits.
# 2. **Visualization:** Improved the plot with:
#    - A filled area between \( x = -1 \) and \( x = 2 \) to highlight the integration region.
#    - Axis lines and labels for better interpretation.
#
# ---
#
# ### Expected Output:
# - **Console Output:**
#   ```
#   Integral of f(x) from -1 to 2: 2.333333
#   ```
# - **Plot:**
#   A parabola \( f(x) = x^2 \) with a shaded region representing the integrated area.
#
# ---
#
# Now it's your turn to run the code and explore the results! 🚀

# %%
# Numerical integration using the trapezoidal rule
import numpy as np
import matplotlib.pyplot as plt

# Function for numerical integration
def integrate(f, a, b, n=1000):
    x = np.linspace(a, b, n)  # Generate n points between a and b
    y = f(x)  # Apply function to each point
    area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
    return area, x, y

# Sample function: f(x) = x^2
f = lambda x: x**2

# Set the limits of integration
a = -1
b = 2

# Compute integral of f(x) from -1 to 2
result, x, y = integrate(f, a, b)
print("Integral of f(x) from -1 to 2:", result)  # Integral of f(x) from -1 to 2: 2.333333

# Plotting the function and the area under the curve
plt.figure(figsize=(8, 6))
plt.plot(x, y, label='$f(x) = x^2$', color='blue')
plt.fill_between(x, y, where=(x >= a) & (x <= b), color='skyblue', alpha=0.4)
plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.title('Area under $f(x) = x^2$ from $x=-1$ to $x=2$')
plt.xlabel('x')
plt.ylabel('$f(x)$')
plt.legend()
plt.show()
# Out:
# Integral of f(x) from -1 to 2: 3.000004509013518

# %% [markdown]
# ## Complete the Trapezoidal Rule Integral and Plot the Graph
#
# Here's the fixed markdown version of your code with detailed steps and explanations:
#
# ```markdown
# # Numerical Integration of \( f(x) = \sin(x) \) Using the Trapezoidal Rule
#
# Hello, Space Explorer! 🚀
#
# Let's approximate the integral of the function \( f(x) = \sin(x) \) from \( x = 0 \) to \( x = \pi \) using the trapezoidal rule. Complete the missing lines in the code below and visualize the results. You've got this! 🌟
#
# ---
#
# ### Python Code
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Function for numerical integration
# def integrate(f, a, b, n=1000):
#     x = np.linspace(a, b, n)  # Generate n points between a and b
#     y = f(x)  # Apply function to each point
#     area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
#     return area
#
# # Define the function f(x) = sin(x)
# f = lambda x: np.sin(x)
#
# # Compute the integral of f(x) from 0 to π
# a = 0
# b = np.pi
# result = integrate(f, a, b)  # Fill in the correct parameters
# print("Integral of f(x) from 0 to π:", result)
#
# # Generate x and y points for visualization
# x = np.linspace(a, b, 1000)
# y = f(x)
#
# # Plotting the function and the integral area
# plt.figure(figsize=(8, 6))
# plt.plot(x, y, label=r'$f(x) = \sin(x)$', color='blue')
# plt.fill_between(x, 0, y, where=(x >= a) & (x <= b), color='lightblue', alpha=0.5)
# plt.title(r'Function $f(x) = \sin(x)$ and its Integral from $0$ to $\pi$')
# plt.xlabel('x')
# plt.ylabel(r'$f(x)$')
# plt.axhline(0, color='black', lw=1)
# plt.axvline(0, color='black', lw=1)
# plt.legend()
# plt.show()
# ```
#
# ---
#
# ### Key Adjustments:
# 1. **Function Definition:** Defined \( f(x) = \sin(x) \) using a lambda function.
#    ```python
#    f = lambda x: np.sin(x)
#    ```
# 2. **Correct Parameters:** Added the correct integration bounds \( a = 0 \), \( b = \pi \) when calling `integrate`.
#    ```python
#    result = integrate(f, a, b)
#    ```
# 3. **Visualization Enhancements:**
#    - Plotted \( f(x) \) with \( x \in [0, \pi] \).
#    - Filled the area under \( f(x) \) with a light blue color to highlight the integral.
#
# ---
#
# ### Expected Output:
# - **Console Output:**
#   ```
#   Integral of f(x) from 0 to π: 2.0
#   ```
#   (The exact value of the integral is \( 2 \).)
# - **Plot:**
#   A sine wave from \( x = 0 \) to \( x = \pi \) with a shaded region representing the computed integral.
#
# ---
#
# Now it's your turn to run the code and explore the results! 🌌

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function for numerical integration
def integrate(f, a, b, n=1000):
    x = np.linspace(a, b, n)  # Generate n points between a and b
    y = f(x)  # Apply function to each point
    area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
    return area

# Define the function f(x) = sin(x)
f = lambda x: np.sin(x)

# Compute the integral of f(x) from 0 to π
a = 0
b = np.pi
result = integrate(f, a, b)  # Fill in the correct parameters
print("Integral of f(x) from 0 to π:", result)

# Generate x and y points for visualization
x = np.linspace(a, b, 1000)
y = f(x)

# Plotting the function and the integral area
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$f(x) = \sin(x)$', color='blue')
plt.fill_between(x, 0, y, where=(x >= a) & (x <= b), color='lightblue', alpha=0.5)
plt.title(r'Function $f(x) = \sin(x)$ and its Integral from $0$ to $\pi$')
plt.xlabel('x')
plt.ylabel(r'$f(x)$')
plt.axhline(0, color='black', lw=1)
plt.axvline(0, color='black', lw=1)
plt.legend()
plt.show()
# Out:
# Integral of f(x) from 0 to π: 1.999998351770852

# %% [markdown]
# ## Compare Areas Under Two Functions Using Trapezoid Rule
#
# # Hello, Space Explorer!
#
# We're going to compare the areas under the curves of two functions: \(f(x) = x^2\) and \(g(x) = 2x\) from 0 to 2 using the trapezoid rule. Let's complete the code to calculate the integrals and generate a graph to visualize both functions and the calculated areas.
#
# You've got this!
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# def integrate(f, a, b, n=1000):
#     x = np.linspace(a, b, n)  # Generate n points between a and b
#     y = f(x)  # Apply function to each point
#     area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
#     return area
#
# # Define the functions f(x) = x^2 and g(x) = 2x
# f = lambda x: x**2
# g = lambda x: 2*x
#
# # Compute the integrals of f and g from 0 to 2
# integral_f = integrate(f, 0, 2)
# integral_g = integrate(g, 0, 2)
#
# # Print the calculated integrals
# print(f"Integral of f(x) = x^2 from 0 to 2: {integral_f}")
# print(f"Integral of g(x) = 2x from 0 to 2: {integral_g}")
#
# # Plotting the functions
# x = np.linspace(0, 2, 1000)
# y_f = f(x)
# y_g = g(x)
#
# plt.plot(x, y_f, label='f(x) = x^2')
# plt.plot(x, y_g, label='g(x) = 2x')
# plt.fill_between(x, y_f, alpha=0.3, label='Area under f(x)')
# plt.fill_between(x, y_g, alpha=0.3, label='Area under g(x)')
# plt.title("Comparison of Areas Under Curves")
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def integrate(f, a, b, n=1000):
    x = np.linspace(a, b, n)  # Generate n points between a and b
    y = f(x)  # Apply function to each point
    area = np.trapz(y, x)  # Use trapezoidal rule to estimate the integral
    return area

# Define the functions f(x) = x^2 and g(x) = 2x
f = lambda x: x**2
g = lambda x: 2*x

# Compute the integrals of f and g from 0 to 2
integral_f = integrate(f, 0, 2)
integral_g = integrate(g, 0, 2)

# Print the calculated integrals
print(f"Integral of f(x) = x^2 from 0 to 2: {integral_f}")
print(f"Integral of g(x) = 2x from 0 to 2: {integral_g}")

# Plotting the functions
x = np.linspace(0, 2, 1000)
y_f = f(x)
y_g = g(x)

plt.plot(x, y_f, label='f(x) = x^2')
plt.plot(x, y_g, label='g(x) = 2x')
plt.fill_between(x, y_f, alpha=0.3, label='Area under f(x)')
plt.fill_between(x, y_g, alpha=0.3, label='Area under g(x)')
plt.title("Comparison of Areas Under Curves")
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Integral of f(x) = x^2 from 0 to 2: 2.666668002670672
# Integral of g(x) = 2x from 0 to 2: 4.0

# %% [markdown]
# ## Car Fuel Consumption Integral Calculation
#
# # Hello, Space Explorer!
#
# Imagine you have the fuel consumption rate of a car over a 10-hour road trip, given by the function \(f(t) = 0.3t + 2\) liters per hour as a function of time \(t\). Your goal is to use the trapezoidal rule to approximate the total fuel consumed during the trip. Complete the missing parts of the `integrate` function and plot the fuel consumption rate.
#
# Let's embark on this journey!
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# def integrate(f, a, b, n=1000):
#     x = np.linspace(a, b, n)  # Generate n points between a and b
#     y = f(x)  # Apply the function to each point
#     area = np.trapz(y, x)  # Use trapezoidal rule to approximate the integral
#     return area
#
# # Define the fuel consumption rate function
# f = lambda t: 0.3 * t + 2
#
# # Call the integrate function and store the result in the result variable
# result = integrate(f, 0, 10)
#
# # Print the total fuel consumed
# print(f"Total fuel consumed over the trip: {result} liters")
#
# # Plot the fuel consumption rate
# t = np.linspace(0, 10, 1000)
# fuel_rate = f(t)
# plt.plot(t, fuel_rate, label='Fuel consumption rate: f(t) = 0.3t + 2')
# plt.xlabel('Time (hours)')
# plt.ylabel('Fuel Consumption Rate (liters/hour)')
# plt.title('Fuel Consumption Rate over 10-hour Trip')
# plt.legend()
# plt.grid(True)
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def integrate(f, a, b, n=1000):
    x = np.linspace(a, b, n)  # Generate n points between a and b
    y = f(x)  # Apply the function to each point
    area = np.trapz(y, x)  # Use trapezoidal rule to approximate the integral
    return area

# Define the fuel consumption rate function
f = lambda t: 0.3 * t + 2

# Call the integrate function and store the result in the result variable
result = integrate(f, 0, 10)

# Print the total fuel consumed
print(f"Total fuel consumed over the trip: {result} liters")

# Plot the fuel consumption rate
t = np.linspace(0, 10, 1000)
fuel_rate = f(t)
plt.plot(t, fuel_rate, label='Fuel consumption rate: f(t) = 0.3t + 2')
plt.xlabel('Time (hours)')
plt.ylabel('Fuel Consumption Rate (liters/hour)')
plt.title('Fuel Consumption Rate over 10-hour Trip')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Total fuel consumed over the trip: 35.0 liters

# %% [markdown]
# ## Calculate the Integral from Negative Infinity to Infinity
#
# # Hello, Stellar Navigator!
#
# Your mission is to calculate the integral of the function \( f(x) = e^{-x^2} \) from \( -\infty \) to \( \infty \). Note that we can't directly use the trapezoid rule here, as we would need an infinite amount of trapezoids. Luckily for us, we can simply use Python's `scipy.integrate.quad` method instead.
#
# This task will help you practice computing integrals with infinite limits programmatically. You have the `integrate.quad` method snippet provided; you just need to define the function and see the new method in action.
#
# You got this! Let's code!
#
# ```python
# import numpy as np
# from matplotlib import pyplot as plt
# from scipy.integrate import quad
#
# # TODO: Define the function
# def f(x):
#     return np.exp(-x**2)  # Hint: use np.exp(x) for e^x
#
# # Calculate the integral from -infinity to infinity
# result, error = quad(f, -np.inf, np.inf)
# print("Integral of f(x) from -∞ to ∞:", result)
#
# # Plot the function and the area under the curve
# x = np.linspace(-3, 3, 400)
# y = f(x)
#
# plt.plot(x, y, label=r'$f(x) = e^{-x^2}$')
# plt.fill_between(x, y, alpha=0.2)
# plt.title('Function $f(x) = e^{-x^2}$ and its Area Under the Curve')
# plt.xlabel('x')
# plt.ylabel('f(x)')
# plt.legend()
# plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import quad

# TODO: Define the function
def f(x):
    return np.exp(-x**2)  # Hint: use np.exp(x) for e^x

# Calculate the integral from -infinity to infinity
result, error = quad(f, -np.inf, np.inf)
print("Integral of f(x) from -∞ to ∞:", result)

# Plot the function and the area under the curve
x = np.linspace(-3, 3, 400)
y = f(x)

plt.plot(x, y, label=r'$f(x) = e^{-x^2}$')
plt.fill_between(x, y, alpha=0.2)
plt.title('Function $f(x) = e^{-x^2}$ and its Area Under the Curve')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()
# Out:
# Integral of f(x) from -∞ to ∞: 1.7724538509055159
