# %% [markdown]
# # Lesson 4: Understanding Gradient
#
# ```markdown
# # Lesson Introduction: Understanding Gradient 🌄
#
# ## Welcome!
#
# Hello and welcome to our lesson on **"Understanding Gradient"!** In this lesson, we will:
# - Explore **what gradients are**,
# - Learn **why gradients matter**,
# - Understand **how to compute gradients in Python**.
#
# By the end of this lesson, you will:
# - Be able to find the gradient of a multivariable function,
# - Understand its significance in optimizing machine learning models.
#
# ---
#
# ## What is a Gradient? 🤔
#
# Imagine a landscape of hills and valleys. The **gradient** tells you the direction of the steepest climb. Formally, the gradient is a **vector** containing all the partial derivatives of a multivariable function, pointing toward the steepest increase.
#
# ### Example: Hiking Analogy
# If you're climbing a hill and want to reach the top as quickly as possible, the gradient guides you on the steepest path.
#
# In **machine learning**, gradients are crucial for:
# - **Training models**: Finding the best parameters to minimize a loss function.
# - **Optimizing weights** in neural networks for better predictions.
#
# Think of the gradient as a map showing the quickest way to minimize errors.
#
# ---
#
# ## Example Function and Partial Derivatives as Vectors
#
# Consider the function:
# \[
# f(x, y) = x^2 + y^2
# \]
#
# ### Partial Derivatives
# For \(f(x, y) = x^2 + y^2\), the partial derivatives are:
# \[
# \frac{\partial f}{\partial x} = 2x \quad \text{and} \quad \frac{\partial f}{\partial y} = 2y
# \]
#
# ### Gradient Vector
# At any point \((x, y)\), the gradient is:
# \[
# \nabla f(x, y) = [2x, 2y]
# \]
# This vector points in the direction of the steepest increase of the function.
#
# ---
#
# ## Plotting the Function and Gradient Vector 📊
#
# Visualizing the gradient helps in understanding its meaning. A plot would show:
# - The function as a heatmap,
# - The gradient vector at a point (e.g., (1, -1)) as an arrow pointing toward the steepest ascent.
#
# The **negative gradient** points to the steepest descent, useful for minimizing the function value (e.g., optimizing machine learning models).
#
# ---
#
# ## Calculating the Gradient Using Central Difference Formula
#
# ### Part 1: Gradient Calculation
# To approximate gradients, we use the **central difference method**, which measures the difference in values at slightly different points. Here's the Python function:
#
# ```python
# # Centrally differenced gradient for multivariable functions
# def gradient(f, pt, h=1e-5):
#     grad = []
#     for i in range(len(pt)):
#         augmented_point = pt[:]
#         augmented_point[i] += h
#         grad.append((f(*augmented_point) - f(*pt)) / h)
#     return grad
# ```
#
# ### Explanation
# 1. `grad = []`: Initializes an empty list to store partial derivatives.
# 2. `for i in range(len(pt))`: Iterates over variables in `pt` (e.g., \(x, y\)).
# 3. `augmented_point = pt[:]`: Copies `pt` to avoid modifying the original.
# 4. `augmented_point[i] += h`: Slightly perturbs the \(i\)-th variable.
# 5. `grad.append((f(*augmented_point) - f(*pt)) / h)`: Calculates and appends the partial derivative.
# 6. `return grad`: Returns the gradient vector.
#
# This method works for functions with any number of variables.
#
# ---
#
# ### Part 2: Applying the Formula
#
# Example with a multivariable function:
# \[
# f(x, y) = x^2 + y^2
# \]
#
# ```python
# # Multivariable function example
# multivariable_fn = lambda x, y: x**2 + y**2
#
# print("Gradient of f(x, y) at (1, -1):", gradient(multivariable_fn, [1, -1]))
# # Expected output: [2, -2]
# ```
#
# ### Output
# The computed gradient at (1, -1) is approximately \([2, -2]\), demonstrating the central difference method's accuracy.
#
# ---
#
# ## Lesson Summary 🎯
#
# - **Gradients** show where a function increases the most.
# - They are vital for **optimizing machine learning models**.
# - The **central difference method** helps calculate gradients for multivariable functions.
#
# Now, it's your turn! Practice calculating gradients for different functions and discover their real-world applications. Let's get started! 🚀
# ```

# %% [markdown]
# ## Plot and Analyze Gradient Vector of a Given Function
#
# Hello, Galactic Pioneer! 🚀
#
# In this exercise, we will:
# 1. Define the function \( f(x, y) = x^2 - xy + y^2 \).
# 2. Compute the **gradient vector** at the point \( (2, 2) \).
# 3. Plot the function as a contour plot and overlay the gradient vector at the specified point.
#
# Let's visualize the gradient together!
#
# ---
#
# ## Code Implementation
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Step 1: Define the function
# def f(x, y):
#     return x**2 - x*y + y**2
#
# # Step 2: Compute partial derivatives
# def partial_derivative_x(x, y, h=1e-5):
#     """Compute partial derivative of f with respect to x."""
#     return (f(x + h, y) - f(x, y)) / h
#
# def partial_derivative_y(x, y, h=1e-5):
#     """Compute partial derivative of f with respect to y."""
#     return (f(x, y + h) - f(x, y)) / h
#
# # Step 3: Compute the gradient at a specific point
# point = (2, 2)
# grad_x = partial_derivative_x(point[0], point[1])
# grad_y = partial_derivative_y(point[0], point[1])
#
# print(f"Gradient at {point}: [{grad_x:.2f}, {grad_y:.2f}]")  # Expected gradient: [2.0, 2.0]
#
# # Step 4: Generate a grid for plotting
# x = np.linspace(-5, 5, 100)
# y = np.linspace(-5, 5, 100)
# X, Y = np.meshgrid(x, y)
# Z = f(X, Y)
#
# # Step 5: Plot the contour and the gradient vector
# plt.figure(figsize=(8, 6))
# plt.contourf(X, Y, Z, levels=20, cmap='viridis')  # Contour plot of the function
# plt.quiver(point[0], point[1], grad_x, grad_y, color='red', scale=10)  # Gradient vector
# plt.colorbar(label="Function Value")
# plt.title('Contour Plot of $f(x, y)$ with Gradient Vector at (2, 2)')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.scatter(*point, color='white', label='Point (2, 2)')  # Highlight the point
# plt.legend()
# plt.show()
# ```
#
# ---
#
# ## Explanation of the Code
#
# ### Function Definition
# We define \( f(x, y) = x^2 - xy + y^2 \), representing a simple multivariable function.
#
# ### Gradient Calculation
# - **Partial Derivatives**:
#   - \( \frac{\partial f}{\partial x} = \frac{f(x+h, y) - f(x, y)}{h} \)
#   - \( \frac{\partial f}{\partial y} = \frac{f(x, y+h) - f(x, y)}{h} \)
#   These approximate derivatives are computed using the **finite difference method**.
# - **Gradient Vector**: \([ \nabla_x, \nabla_y ] = [2.0, 2.0]\) at \( (2, 2) \).
#
# ### Visualization
# - **Contour Plot**: Visualizes \( f(x, y) \) as a landscape of values.
# - **Gradient Vector**: Indicates the steepest ascent direction at \( (2, 2) \), overlaid in red.
#
# ---
#
# ## Expected Output
#
# - **Gradient**: \([2.0, 2.0]\)
# - **Plot**: A contour map with the gradient vector pointing outward from the specified point.
#
# Enjoy exploring gradients! 🌟

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Define the function
def f(x, y):
    return x**2 - x*y + y**2

# Step 2: Compute partial derivatives
def partial_derivative_x(x, y, h=1e-5):
    """Compute partial derivative of f with respect to x."""
    return (f(x + h, y) - f(x, y)) / h

def partial_derivative_y(x, y, h=1e-5):
    """Compute partial derivative of f with respect to y."""
    return (f(x, y + h) - f(x, y)) / h

# Step 3: Compute the gradient at a specific point
point = (2, 2)
grad_x = partial_derivative_x(point[0], point[1])
grad_y = partial_derivative_y(point[0], point[1])

print(f"Gradient at {point}: [{grad_x:.2f}, {grad_y:.2f}]")  # Expected gradient: [2.0, 2.0]

# Step 4: Generate a grid for plotting
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Step 5: Plot the contour and the gradient vector
plt.figure(figsize=(8, 6))
plt.contourf(X, Y, Z, levels=20, cmap='viridis')  # Contour plot of the function
plt.quiver(point[0], point[1], grad_x, grad_y, color='red', scale=10)  # Gradient vector
plt.colorbar(label="Function Value")
plt.title('Contour Plot of $f(x, y)$ with Gradient Vector at (2, 2)')
plt.xlabel('x')
plt.ylabel('y')
plt.scatter(*point, color='white', label='Point (2, 2)')  # Highlight the point
plt.legend()
plt.show()
# Out:
# Gradient at (2, 2): [2.00, 2.00]

# %% [markdown]
# ## Calculating and Plotting the Negative Gradient
#
# # Complete the code to calculate and plot the negative gradient for the function
# # f(x, y) = x² − y² at the point (2, -3).
#
# Let's plot the direction toward the steepest descent, Space Explorer! You got this!
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Define the function f(x, y)
# def f(x, y):
#     return x**2 - y**2
#
# # Calculate analytical gradient at the given point
# def gradient(x, y):
#     fx = 2 * x  # Partial derivative with respect to x
#     fy = -2 * y  # Partial derivative with respect to y
#     return np.array([fx, fy])
#
# # The point at which to calculate and plot the gradient
# x0, y0 = 2, -3
#
# # Compute the negative gradient at (2, -3) using the gradient function
# neg_grad = -gradient(x0, y0)
#
# # Plot the function and gradient
# x = np.linspace(-5, 5, 400)
# y = np.linspace(-5, 5, 400)
# x, y = np.meshgrid(x, y)
# z = f(x, y)
#
# plt.contourf(x, y, z, 20, cmap='viridis')
# plt.colorbar()
# plt.quiver(x0, y0, neg_grad[0], neg_grad[1], color='white', scale=5, label="Negative Gradient")
# plt.title('Negative Gradient of f(x, y) = x² - y² at (2, -3)')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.legend()
# plt.show()
# ```
# ### Explanation of Fixes:
# 1. **Function Definition**: Added `f(x, y)` definition since it was missing.
# 2. **Negative Gradient Calculation**: Introduced `neg_grad` using `-gradient(x0, y0)`.
# 3. **Plotting Gradient Arrow**: Fixed `plt.quiver` arguments to use `neg_grad` correctly.
# 4. **Labels and Legends**: Improved plot labels and added a legend for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x, y)
def f(x, y):
    return x**2 - y**2

# Calculate analytical gradient at the given point
def gradient(x, y):
    fx = 2 * x  # Partial derivative with respect to x
    fy = -2 * y  # Partial derivative with respect to y
    return np.array([fx, fy])

# The point at which to calculate and plot the gradient
x0, y0 = 2, -3

# Compute the negative gradient at (2, -3) using the gradient function
neg_grad = -gradient(x0, y0)

# Plot the function and gradient
x = np.linspace(-5, 5, 400)
y = np.linspace(-5, 5, 400)
x, y = np.meshgrid(x, y)
z = f(x, y)

plt.contourf(x, y, z, 20, cmap='viridis')
plt.colorbar()
plt.quiver(x0, y0, neg_grad[0], neg_grad[1], color='white', scale=5, label="Negative Gradient")
plt.title('Negative Gradient of f(x, y) = x² - y² at (2, -3)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %% [markdown]
# ## Visualize and Compute Gradients of a Function at Multiple Points
#
#
# Let's calculate and visualize the gradient vectors of the function
# g(x, y) = x³ − 3xy + y³ at the points (2, -1) and (-1, -2).
# Complete the provided code to compute the gradient at these points, plot the function as a heatmap, and overlay the gradient vectors.
#
# You got this!
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # Define the function g(x, y)
# def g(x, y):
#     return x**3 - 3 * x * y + y**3
#
# # Define gradient functions using partial derivatives
# def gradient_x(x, y, h=1e-5):
#     return (g(x + h, y) - g(x, y)) / h
#
# def gradient_y(x, y, h=1e-5):
#     return (g(x, y + h) - g(x, y)) / h
#
# # Points to calculate gradients
# points = [(2, -1), (-1, -2)]
#
# # Calculate gradients at specified points
# gradients = [(gradient_x(x, y), gradient_y(x, y)) for x, y in points]
#
# # Print the gradients
# for point, gradient in zip(points, gradients):
#     print(f"Gradient at {point}: {gradient}")
#
# # Generate grid data for plotting
# x = np.linspace(-3, 3, 400)
# y = np.linspace(-3, 3, 400)
# x, y = np.meshgrid(x, y)
# z = g(x, y)
#
# # Plot the function as a heatmap
# plt.contourf(x, y, z, 50, cmap='viridis')
# plt.colorbar()
#
# # Overlay gradient vectors
# for (x_pt, y_pt), (grad_x_pt, grad_y_pt) in zip(points, gradients):
#     plt.quiver(x_pt, y_pt, grad_x_pt, grad_y_pt, color='white', scale=50)
#
# plt.title('Gradient Vectors on Heatmap of g(x, y) = x³ - 3xy + y³')
# plt.xlabel('x')
# plt.ylabel('y')
# plt.show()
# ```
#
# ### Explanation of Fixes:
# 1. **Function Definition**: Added `g(x, y)` to define the provided function.
# 2. **Points for Gradients**: Explicitly defined the list of points `[(2, -1), (-1, -2)]`.
# 3. **Gradient Calculation**: Included code to compute gradients using `gradient_x` and `gradient_y`.
# 4. **Heatmap Plotting**: Verified and adjusted the heatmap generation with proper function calls.
# 5. **Gradient Vectors Overlay**: Ensured `plt.quiver` overlays the computed gradient vectors at the correct points.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function g(x, y)
def g(x, y):
    return x**3 - 3 * x * y + y**3

# Define gradient functions using partial derivatives
def gradient_x(x, y, h=1e-5):
    return (g(x + h, y) - g(x, y)) / h

def gradient_y(x, y, h=1e-5):
    return (g(x, y + h) - g(x, y)) / h

# Points to calculate gradients
points = [(2, -1), (-1, -2)]

# Calculate gradients at specified points
gradients = [(gradient_x(x, y), gradient_y(x, y)) for x, y in points]

# Print the gradients
for point, gradient in zip(points, gradients):
    print(f"Gradient at {point}: {gradient}")

# Generate grid data for plotting
x = np.linspace(-3, 3, 400)
y = np.linspace(-3, 3, 400)
x, y = np.meshgrid(x, y)
z = g(x, y)

# Plot the function as a heatmap
plt.contourf(x, y, z, 50, cmap='viridis')
plt.colorbar()

# Overlay gradient vectors
for (x_pt, y_pt), (grad_x_pt, grad_y_pt) in zip(points, gradients):
    plt.quiver(x_pt, y_pt, grad_x_pt, grad_y_pt, color='white', scale=50)

plt.title('Gradient Vectors on Heatmap of g(x, y) = x³ - 3xy + y³')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# Gradient at (2, -1): (15.000060000325275, -3.0000299998889086)
# Gradient at (-1, -2): (8.99997000001207, 14.99994000013771)

# %% [markdown]
# ## Calculating Gradients at Multiple Points Near the Function's Maximum
#
# You have a function that calculates gradients using the central difference method.
# For the function
# h(x, y) = −x³ + 3xy − y², find the gradient at the points (0.5, 1), (0.25, 0.5), and (0.125, 0.25), moving closer to the function’s maximum.
# Fill in the code to print these gradients.
#
# Expect the gradient to become smaller as the point gets closer to the maximum.
#
# You've got this!
#
# ```python
# # Centrally differenced gradient for multivariable functions
# def gradient(f, pt, h=1e-5):
#     grad = []
#     for i in range(len(pt)):
#         augmented_point = list(pt)  # Convert tuple to list for modification
#         augmented_point[i] += h
#         grad.append((f(*augmented_point) - f(*pt)) / h)
#     return grad
#
# # Define the function h(x, y)
# def h(x, y):
#     return -x**3 + 3 * x * y - y**2
#
# # Compute gradients at multiple points getting closer to the function's maximum
# points = [(0.5, 1), (0.25, 0.5), (0.125, 0.25)]
#
# for pt in points:
#     grad = gradient(h, pt)
#     print(f"Gradient at {pt}: {grad}")
# ```
#
# ### Explanation of Fixes:
# 1. **Function Definition**: Added the definition of `h(x, y)` as `−x³ + 3xy − y²`.
# 2. **Tuple to List Conversion**: Ensured `pt` is converted to a list before modifying in the `gradient` function to avoid immutability issues with tuples.
# 3. **Points for Gradient Calculation**: Included the list `points` containing the specified points `(0.5, 1)`, `(0.25, 0.5)`, and `(0.125, 0.25)`.
# 4. **Printing Results**: Added code to calculate and print the gradient for each point in `points`.

# %%
# Centrally differenced gradient for multivariable functions
def gradient(f, pt, h=1e-5):
    grad = []
    for i in range(len(pt)):
        augmented_point = list(pt)  # Convert tuple to list for modification
        augmented_point[i] += h
        grad.append((f(*augmented_point) - f(*pt)) / h)
    return grad

# Define the function h(x, y)
def h(x, y):
    return -x**3 + 3 * x * y - y**2

# Compute gradients at multiple points getting closer to the function's maximum
points = [(0.5, 1), (0.25, 0.5), (0.125, 0.25)]

for pt in points:
    grad = gradient(h, pt)
    print(f"Gradient at {pt}: {grad}")
# Out:
# Gradient at (0.5, 1): [2.24998499986917, -0.500010000004103]
# Gradient at (0.25, 0.5): [1.3124924998997312, -0.2500100000024652]
# Gradient at (0.125, 0.25): [0.7031212499009064, -0.12501000000025853]

# %% [markdown]
# Here’s the corrected and properly formatted code in Markdown:
#
# Given the quadratic function
# f(x, y) = −x² − y², complete the Python code to calculate and print the gradient at the point (0, 0).
# This function has a maximum at this point. As there is no direction for the function to grow, expect the gradient to be 0.
#
# Fill in the missing parts of the code to demonstrate your understanding of gradients.
# Let's dive into gradients together!
#
# ```python
# # Define the function f(x, y)
# def f(x, y):
#     return -x**2 - y**2
#
# # Define partial derivatives using central differences
# def partial_derivative_x(f, x, y, h=1e-5):
#     return (f(x + h, y) - f(x - h, y)) / (2 * h)
#
# def partial_derivative_y(f, x, y, h=1e-5):
#     return (f(x, y + h) - f(x, y - h)) / (2 * h)
#
# # Evaluate and print gradient at the point (0, 0)
# x0, y0 = 0, 0
# grad_x = partial_derivative_x(f, x0, y0)
# grad_y = partial_derivative_y(f, x0, y0)
#
# print(f"Gradient at ({x0}, {y0}): ({grad_x}, {grad_y})")
# ```
#
# ### Explanation of Fixes:
# 1. **Function Definition**: Added `f(x, y) = −x² − y²`.
# 2. **Partial Derivatives**: Central difference formulas for `partial_derivative_x` and `partial_derivative_y` were included as per the code structure.
# 3. **Gradient Evaluation**: Computed the gradient at the point `(0, 0)` using the provided central difference formulas.
# 4. **Print Statement**: Added a print statement to display the gradient at `(0, 0)`.
#
# When run, the result should be approximately `(0.0, 0.0)`, confirming that the gradient is zero at the function's maximum.

# %%
# Define the function f(x, y)
def f(x, y):
    return -x**2 - y**2

# Define partial derivatives using central differences
def partial_derivative_x(f, x, y, h=1e-5):
    return (f(x + h, y) - f(x - h, y)) / (2 * h)

def partial_derivative_y(f, x, y, h=1e-5):
    return (f(x, y + h) - f(x, y - h)) / (2 * h)

# Evaluate and print gradient at the point (0, 0)
x0, y0 = 0, 0
grad_x = partial_derivative_x(f, x0, y0)
grad_y = partial_derivative_y(f, x0, y0)

print(f"Gradient at ({x0}, {y0}): ({grad_x}, {grad_y})")
# Out:
# Gradient at (0, 0): (0.0, 0.0)
