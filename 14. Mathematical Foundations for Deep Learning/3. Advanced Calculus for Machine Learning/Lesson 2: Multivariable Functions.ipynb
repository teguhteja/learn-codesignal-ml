# %% [markdown]
# # Lesson 2: Multivariable Functions
#
# Welcome to our lesson on **"Multivariable Functions"**! Understanding how functions work with multiple variables is crucial in machine learning, where models depend on more than one parameter. By the end of this lesson, you'll understand:
# - What multivariable functions are.
# - Why they're important.
# - How to work with them in Python.
#
# Imagine predicting the price of a house based on its **size** and **location**—both factors influence the price. Multivariable functions model such relationships.
#
# ---
#
# ## What Are Multivariable Functions?
#
# A **multivariable function** involves more than one input variable. For example:
#
# \[
# f(x, y) = x^2 + y^2
# \]
#
# This function takes two inputs, \(x\) and \(y\), and produces an output. Both \(x\) and \(y\) influence the result of \(f\).
#
# ### Example:
# For \(x = 1\) and \(y = 2\):
#
# \[
# f(1, 2) = 1^2 + 2^2 = 1 + 4 = 5
# \]
#
# ---
#
# ## Real-Life Example of Multivariable Functions
#
# **Calculating the total cost of a meal with tip and tax:**
#
# - Meal cost: $50
# - Tip rate: 15%
# - Tax rate: 8%
#
# The function:
#
# \[
# f(\text{meal cost}, \text{tip rate}, \text{tax rate}) = \text{meal cost} \times (1 + \text{tip rate} + \text{tax rate})
# \]
#
# ### Example:
# \[
# f(50, 0.15, 0.08) = 50 \times (1 + 0.15 + 0.08) = 50 \times 1.23 = 61.5
# \]
#
# ---
#
# ## Defining Multivariable Functions in Python
#
# Here’s how to define a function that takes two parameters, \(x\) and \(y\), and returns their sum of squares:
#
# ```python
# # Defining a multivariable function
# def multivariable_function(x, y):
#     return x**2 + y**2
#
# # Evaluate function at (1, 2)
# result = multivariable_function(1, 2)
# print("f(1, 2) =", result)  # f(1, 2) = 5
# ```
#
# ### Step-by-Step Explanation:
# 1. **Function Definition**: `def multivariable_function(x, y):` defines the function with two arguments \(x\) and \(y\).
# 2. **Return Statement**: `return x**2 + y**2` calculates the sum of squares of \(x\) and \(y\).
# 3. **Evaluation**: `result = multivariable_function(1, 2)` evaluates the function at \(x = 1\) and \(y = 2\).
# 4. **Print Result**: `print("f(1, 2) =", result)` outputs the result (5).
#
# ---
#
# ## Exploring More Complex Multivariable Functions
#
# Consider a function:
#
# \[
# f(x, y) = x^2 - xy + y^2
# \]
#
# Here’s how you can define and evaluate it in Python:
#
# ```python
# # Defining a more complex multivariable function
# def complex_function(x, y):
#     return x**2 - x*y + y**2
#
# # Evaluate function at (1, 2)
# result = complex_function(1, 2)
# print("f(1, 2) =", result)  # f(1, 2) = 3
# ```
#
# ### Visualization Example:
# Visualizing helps understand how the function behaves with different inputs. For example, let’s plot:
#
# \[
# f(x, y) = x^2 - xy + y^2
# \]
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# # Define the function
# def surface_function(x, y):
#     return x**2 - x*y + y**2
#
# # Create meshgrid
# x = np.linspace(-5, 5, 100)
# y = np.linspace(-5, 5, 100)
# X, Y = np.meshgrid(x, y)
# Z = surface_function(X, Y)
#
# # Plot the surface
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# ax.plot_surface(X, Y, Z, cmap='viridis', alpha=0.8)
#
# # Add labels
# ax.set_title("Surface Plot of f(x, y) = x^2 - xy + y^2")
# ax.set_xlabel("x")
# ax.set_ylabel("y")
# ax.set_zlabel("f(x, y)")
#
# plt.show()
# ```
#
# ---
#
# ## Lesson Summary
#
# Congratulations! You’ve learned:
# - **What multivariable functions are** and their real-life importance.
# - How these functions involve multiple inputs.
# - How to implement them in Python.
# - How to visualize them to understand their behavior.
#
# Now it’s time to practice! Create, evaluate, and explore more complex multivariable functions to solidify your skills. Let’s get coding! 🚀

# %% [markdown]
# ## Define and Visualize a Multivariable Function
#
#
# ### Exploring a New Function
#
# Great job so far! 🎉 Now, let's explore a new function. Given the function:
#
# \[
# f(x, y) = x^3 - 3xy + y^2
# \]
#
# ### Your Tasks:
# 1. **Define the function \(f(x, y)\).**
# 2. **Evaluate \(f(x, y)\) at specific points:**
#    - \( (1, 2) \)
#    - \( (-1, -3) \)
# 3. **Visualize a 3D surface graph** for \(x\) and \(y\) values ranging from \(-5\) to \(5\).
#
# ### Let’s Code! 🚀
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# # Step 1: Define the function f(x, y)
# def f(x, y):
#     return x**3 - 3*x*y + y**2
#
# # Step 2: Evaluate function at (1, 2)
# result1 = f(1, 2)
# print("f(1, 2) =", result1)  # Output: f(1, 2) = -1
#
# # Step 3: Evaluate function at (-1, -3)
# result2 = f(-1, -3)
# print("f(-1, -3) =", result2)  # Output: f(-1, -3) = -1
#
# # Step 4: Plot the 3D surface graph
# x = np.linspace(-5, 5, 100)
# y = np.linspace(-5, 5, 100)
# x, y = np.meshgrid(x, y)
# z = f(x, y)
#
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# surface = ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none', alpha=0.8)
#
# # Add labels and title
# ax.set_title("3D Surface Plot of f(x, y) = x^3 - 3xy + y^2")
# ax.set_xlabel("X axis")
# ax.set_ylabel("Y axis")
# ax.set_zlabel("Z axis")
# plt.colorbar(surface, ax=ax, shrink=0.5, aspect=10)
#
# plt.show()
# ```
#
# ### What to Observe:
# - The **evaluations** of \(f(x, y)\) at \((1, 2)\) and \((-1, -3)\).
# - The **3D surface graph** showcasing how \(f(x, y)\) behaves over the range of \(-5\) to \(5\) for \(x\) and \(y\).
#
# Enjoy visualizing multivariable functions, Galactic Pioneer! 🌌

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Step 1: Define the function f(x, y)
def f(x, y):
    return x**3 - 3*x*y + y**2

# Step 2: Evaluate function at (1, 2)
result1 = f(1, 2)
print("f(1, 2) =", result1)  # Output: f(1, 2) = -1

# Step 3: Evaluate function at (-1, -3)
result2 = f(-1, -3)
print("f(-1, -3) =", result2)  # Output: f(-1, -3) = -1

# Step 4: Plot the 3D surface graph
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = f(x, y)

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none', alpha=0.8)

# Add labels and title
ax.set_title("3D Surface Plot of f(x, y) = x^3 - 3xy + y^2")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")
plt.colorbar(surface, ax=ax, shrink=0.5, aspect=10)

plt.show()
# Out:
# f(1, 2) = -1
# f(-1, -3) = -1

# %% [markdown]
# ## Plotting a Multivariable Sine-Cosine Function
#
#
# Exploring the Function \(g(x, y) = \sin(x) + \cos(y)\)
#
# Hello, Space Voyager! 🚀
#
# Your mission is to:
# 1. Define the multivariable function:
#    \[
#    g(x, y) = \sin(x) + \cos(y)
#    \]
# 2. Visualize its 3D surface plot for \(x, y \in [-2\pi, 2\pi]\).
#
# Let’s dive into the code and explore the fascinating surface this function creates!
#
# ### Code Implementation
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# # Step 1: Define the multivariable function g(x, y)
# def g(x, y):
#     return np.sin(x) + np.cos(y)
#
# # Step 2: Generate data points for X and Y
# x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
# y = np.linspace(-2 * np.pi, 2 * np.pi, 100)
# X, Y = np.meshgrid(x, y)
#
# # Step 3: Compute Z values using g(X, Y)
# Z = g(X, Y)
#
# # Step 4: Plot the 3D surface
# fig = plt.figure(figsize=(10, 7))
# ax = fig.add_subplot(111, projection='3d')
# surface = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)
#
# # Add labels and title
# ax.set_title("3D Surface Plot of g(x, y) = sin(x) + cos(y)")
# ax.set_xlabel("X axis")
# ax.set_ylabel("Y axis")
# ax.set_zlabel("Z axis")
# plt.colorbar(surface, ax=ax, shrink=0.5, aspect=10)
#
# # Display the plot
# plt.show()
# ```
#
# ### Observations:
# - The surface plot exhibits **periodic behavior**, characteristic of sine and cosine functions.
# - Peaks and valleys correspond to the sum of \(\sin(x)\) and \(\cos(y)\).
#
# You've got this, Space Voyager! 🌌
# Enjoy exploring the beauty of multivariable functions in Python.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Step 1: Define the multivariable function g(x, y)
def g(x, y):
    return np.sin(x) + np.cos(y)

# Step 2: Generate data points for X and Y
x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
y = np.linspace(-2 * np.pi, 2 * np.pi, 100)
X, Y = np.meshgrid(x, y)

# Step 3: Compute Z values using g(X, Y)
Z = g(X, Y)

# Step 4: Plot the 3D surface
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
surface = ax.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.8)

# Add labels and title
ax.set_title("3D Surface Plot of g(x, y) = sin(x) + cos(y)")
ax.set_xlabel("X axis")
ax.set_ylabel("Y axis")
ax.set_zlabel("Z axis")
plt.colorbar(surface, ax=ax, shrink=0.5, aspect=10)

# Display the plot
plt.show()

# %% [markdown]
# ## Calculate the Area of a Rectangle Using Multivariable Function
#
# # Hello, Galactic Pioneer! 🌌
#
# Let's create a function that calculates the **area of a rectangle**.
# This function should take the **width** and **length** as inputs and then return the area.
#
# For instance, when the width is `5` and the length is `10`, your function should return the correct area. This will help you understand how to apply multivariable functions to real-world scenarios.
#
# You can do this! 🚀
#
# ```python
# # Define the function to calculate the area of a rectangle
# def rectangle_area(width, length):
#     return width * length  # TODO: Complete the function to return the area of the rectangle
#
# # Given values
# width = 5
# length = 10
#
# # Calculate and print the area
# area = rectangle_area(width, length)
# print(f"The area of the rectangle is: {area}")

# %%
def rectangle_area(width, length):
    return width * length  # TODO: Complete the function to return the area of the rectangle

# Given values
width = 5
length = 10

# Calculate and print the area
area = rectangle_area(width, length)
print(f"The area of the rectangle is: {area}")
# Out:
# The area of the rectangle is: 50

# %% [markdown]
# ## Calculating Total Revenue with Multivariable Functions
#
# # Calculate Total Revenue 💰
#
# Calculate the total revenue of a store where both the **number of items sold** and the **price per item** vary.
#
# Define the function `total_revenue(items_sold, price_per_item)` and complete the starter code to evaluate the function for **5 items sold at $20 each**.
#
# You got this, Stellar Navigator! 🚀
#
# ```python
# # Define the total_revenue function
# def total_revenue(items_sold, price_per_item):
#     return items_sold * price_per_item  # TODO: Implement the function to calculate total revenue
#
# # Evaluate the function for 5 items sold at $20 each
# items_sold = 5
# price_per_item = 20
# revenue = total_revenue(items_sold, price_per_item)
#
# # Print the result
# print(f"The total revenue is: ${revenue}")

# %%
def total_revenue(items_sold, price_per_item):
    return items_sold * price_per_item  # TODO: Implement the function to calculate total revenue

# Evaluate the function for 5 items sold at $20 each
items_sold = 5
price_per_item = 20
revenue = total_revenue(items_sold, price_per_item)

# Print the result
print(f"The total revenue is: ${revenue}")
# Out:
# The total revenue is: $100

# %% [markdown]
# ## Define and Plot a 2-Variable Function as a Contour
#
# # Hey Space Voyager! 🌌
#
# Let's create a colorful visualization of the function
#
# **g(x, y) = x * y + x - y**
#
# by plotting it as a contour plot. A contour plot is a graphical representation where individual values are shown using different colors.
#
# Your task is to define this function and then run the code to plot it over a specified range of `x` and `y`.
#
# ### Give it a try!
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
#
# # TODO: Define the two-variable function g(x, y)
# def g(x, y):
#     return x * y + x - y
#
# # Generate the data for the heatmap
# x = np.linspace(-5, 5, 500)
# y = np.linspace(-5, 5, 500)
# X, Y = np.meshgrid(x, y)
# Z = g(X, Y)
#
# # Plot the heatmap
# plt.contourf(X, Y, Z, 20, cmap='viridis')  # Use 'viridis' colormap for better visuals
# plt.colorbar()
# plt.xlabel('x')
# plt.ylabel('y')
# plt.title('Heatmap of g(x, y) = x * y + x - y')
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# TODO: Define the two-variable function g(x, y)
def g(x, y):
    return x * y + x - y

# Generate the data for the heatmap
x = np.linspace(-5, 5, 500)
y = np.linspace(-5, 5, 500)
X, Y = np.meshgrid(x, y)
Z = g(X, Y)

# Plot the heatmap
plt.contourf(X, Y, Z, 20, cmap='viridis')  # Use 'viridis' colormap for better visuals
plt.colorbar()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Heatmap of g(x, y) = x * y + x - y')
plt.show()

# %% [markdown]
# ## Visualize Two Variable Function with Contourf and 3D Plot
#
# Here’s the corrected and properly formatted Markdown version of your content:
#
#
# Let's have some fun visualizing the multivariable function:
#
# **f(x, y) = x² - xy + y²**
#
# Run the provided code to observe both a **contour plot** and a **3D surface plot**. These visualizations show the same picture in two different ways!
#
# ### You've got this! 🚀
#
# ```python
# import numpy as np
# import matplotlib.pyplot as plt
# from mpl_toolkits.mplot3d import Axes3D
#
# # Define the multivariable function
# def f(x, y):
#     return x**2 - x*y + y**2
#
# # Define the range for x and y
# x = np.linspace(-5, 5, 100)
# y = np.linspace(-5, 5, 100)
# X, Y = np.meshgrid(x, y)
# Z = f(X, Y)
#
# # Create a figure with two subplots
# fig = plt.figure(figsize=(12, 6))
#
# # Contour plot
# ax1 = fig.add_subplot(121)
# contour = ax1.contourf(X, Y, Z, cmap='viridis')  # Filled contour plot
# fig.colorbar(contour, ax=ax1)
# ax1.set_title('Contour Plot')
# ax1.set_xlabel('x')
# ax1.set_ylabel('y')
#
# # 3D surface plot
# ax2 = fig.add_subplot(122, projection='3d')
# ax2.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')  # 3D surface plot
# ax2.set_title('3D Plot')
# ax2.set_xlabel('x')
# ax2.set_ylabel('y')
# ax2.set_zlabel('f(x, y)')
#
# # Show the plots
# plt.tight_layout()
# plt.show()
# ```
#
# ### Explanation:
# - **Contour Plot:** Shows the function values in 2D using color gradients for better clarity.
# - **3D Surface Plot:** Provides a 3D perspective of the same function.
# - **Colormap:** The `viridis` colormap ensures vibrant and readable visuals.
#
# Happy exploring! 🌠

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the multivariable function
def f(x, y):
    return x**2 - x*y + y**2

# Define the range for x and y
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# Create a figure with two subplots
fig = plt.figure(figsize=(12, 6))

# Contour plot
ax1 = fig.add_subplot(121)
contour = ax1.contourf(X, Y, Z, cmap='viridis')  # Filled contour plot
fig.colorbar(contour, ax=ax1)
ax1.set_title('Contour Plot')
ax1.set_xlabel('x')
ax1.set_ylabel('y')

# 3D surface plot
ax2 = fig.add_subplot(122, projection='3d')
ax2.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none')  # 3D surface plot
ax2.set_title('3D Plot')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.set_zlabel('f(x, y)')

# Show the plots
plt.tight_layout()
plt.show()
