# %% [markdown]
# # Lesson 1: Understanding Functions
#
# Here's your text, fixed and formatted in Markdown:
#
# ---
#
# # Lesson Introduction
#
# Hi there! Today, we're talking about **functions**. By the end of this lesson, you'll know what functions are in math and how they apply to machine learning. We'll also teach you how to define and use functions in Python. Let's begin!
#
# ---
#
# ## What is a Function?
#
# A function in math relates an input to an output. It's like a machine: you put something in, and it gives you something back. For instance, if a function adds 2 to any number you give it, putting in 3 gives you 5, and putting in 7 gives you 9.
#
# Formally, if \(x\) is our input and \(f\) is our function, our output is \(f(x)\), written as:
#
# \[
# f: x \mapsto f(x)
# \]
#
# ---
#
# ## Function Examples
#
# Here are some common examples of functions in math:
#
# 1. **Linear Function**:
#    \[
#    f(x) = 2x + 3
#    \]
#
# 2. **Quadratic Function**:
#    \[
#    f(x) = x^2 - 4x + 4
#    \]
#
# 3. **Exponential Function**:
#    \[
#    f(x) = e^x
#    \]
#
# 4. **Logarithmic Function**:
#    \[
#    f(x) = \log(x)
#    \]
#
# ---
#
# ## Defining a Function in Python
#
# Let's define a quadratic function in Python. We'll use the example function \(f(x) = x^2 + 2x + 1\).
#
# ```python
# # Defining a simple function
# def simple_function(x):
#     return x**2 + 2*x + 1
# ```
#
# ### Code Breakdown:
# - **`def`**: The keyword to define a function.
# - **`simple_function(x)`**: The name of the function and its parameter.
# - **`return x**2 + 2*x + 1`**: What the function computes.
#
# Quadratic functions are common in machine learning for optimization problems. For example, finding the best-fit line for data points involves solving a quadratic problem.
#
# ---
#
# ## Evaluating a Function
#
# We can find our function's value at different \(x\). For \(x = 3\), what does `simple_function` return? Let's see:
#
# ```python
# def simple_function(x):
#     return x**2 + 2*x + 1
#
# # Evaluate function at x=3
# result = simple_function(3)
# print("f(3) =", result)  # f(3) = 16
# ```
#
# ### How it Works:
# 1. Takes \(x = 3\) as the input.
# 2. Computes \(3^2 + 2 \times 3 + 1\).
# 3. Returns 16, which is printed as `f(3) = 16`.
#
# ---
#
# ## Plotting the Function
#
# If we evaluate the function at every possible \(x\), we will get a list of corresponding \(f(x)\) values. These pairs can be represented as points on the XY plane. Plotting all such pairs creates the graph of the function.
#
# Here’s how to plot the function in Python:
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the function
# def simple_function(x):
#     return x**2 + 2*x + 1
#
# # Generate x values
# x = np.linspace(-10, 10, 400)
# # Generate y values using the function
# y = simple_function(x)
#
# # Plot the function
# plt.plot(x, y, label='f(x) = x^2 + 2x + 1')
# plt.xlabel('x')
# plt.ylabel('f(x)')
# plt.title('Plot of the Function f(x) = x^2 + 2x + 1')
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
# ### Code Breakdown:
# 1. **`matplotlib.pyplot`**: For plotting.
# 2. **`numpy`**: For handling arrays.
# 3. **`np.linspace(-10, 10, 400)`**: Generates 400 evenly spaced points between -10 and 10.
# 4. **`plt.plot(x, y)`**: Creates the plot.
#
# ---
#
# ## Evaluating Function with the Plot
#
# Once you have the function's plot, you can visualize its behavior. For example, at \(x = 5\), \(f(x)\) is approximately 36. Here's what we can observe from the plot:
# - The function is zero around \(x = -1\).
# - Before \(x = -1\), the function decreases.
# - After \(x = -1\), the function increases.
# - The farther away from \(x = -1\), the faster the function grows.
#
# ---
#
# With this understanding, you're ready to define and analyze functions in both math and Python!
#
# ---

# %% [markdown]
# ## Evaluate Exponential Function
#
# Here's the fixed and formatted Markdown version of your text, including the code and the correct result:
#
# ---
#
# # Hello, Space Explorer! 🚀
#
# Today, let’s explore the world of **exponential functions**. Your mission is to create a new function called `exponential_function(x)` that calculates the value of the function:
#
# \[
# f(x) = 2^x
# \]
#
# Once you’ve done that, run the code to evaluate this function at \(x = 4\) and print the result.
#
# You’ve got this! Let's code! 💻
#
# ```python
# # Define the exponential function
# def exponential_function(x):
#     return 2**x  # This function returns 2 raised to the power of x
#
# # Evaluate the function at x=4
# result = exponential_function(4)
# print("f(4) =", result)  # f(4) = 16
# ```
#
# ### Output:
# ```
# f(4) = 16
# ```
#
# ---
#
# Great job, Space Explorer! 🚀 Keep pushing the boundaries of your coding skills! 🌌

# %% [markdown]
# ## Define and Evaluate a Linear Function
#
# Here is the corrected version in Markdown format with the solution included:
#
# # Practice Linear Functions in Python
#
# Hello, Space Voyager!
#
# Let's practice defining and evaluating functions. Your task is to define a function `g(x)` that represents the linear function:
#
# **g(x) = 4x + 7**
#
# Once defined, evaluate this function for:
# - **x = 6**
# - **x = -3**
#
# and print the results.
#
# You've got this!
#
# ---
#
# ### Python Code
#
# ```python
# # Define the linear function
# def g(x):
#     # Return the result of the linear function g(x) = 4x + 7
#     return 4 * x + 7
#
# # Evaluate the function at x = 6
# result_1 = g(6)
# print(f"g(6) = {result_1}")
#
# # Evaluate the function at x = -3
# result_2 = g(-3)
# print(f"g(-3) = {result_2}")
# ```
#
# ---
#
# ### Output
# ```
# g(6) = 31
# g(-3) = -5
# ```

# %% [markdown]
# ## Define and Plot a Cubic Function
#
# Here’s the corrected Markdown version with the solution included:
#
# # Visualizing a Mathematical Function in Python
#
# Hello, Space Voyager!
#
# Your mission is to define a new function:
#
# **g(x) = x³ - 3x² + 2x + 10**
#
# ...and plot its graph. Complete the provided code to achieve this. This task will help you understand how functions are represented and visualized.
#
# Let's code!
#
# ---
#
# ### Python Code
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the new function
# def new_function(x):
#     # Implement the function g(x) = x^3 - 3x^2 + 2x + 10
#     return x**3 - 3*x**2 + 2*x + 10
#
# # Generate x values
# x = np.linspace(-10, 10, 400)
#
# # Generate y values using the new function
# y = new_function(x)
#
# # Plot the function
# plt.plot(x, y, label='g(x) = x³ - 3x² + 2x + 10')
# plt.xlabel('x')
# plt.ylabel('g(x)')
# plt.title('Plot of the Function g(x) = x³ - 3x² + 2x + 10')
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# ### Result
#
# When you execute the code above, you will see a graph representing the function **g(x) = x³ - 3x² + 2x + 10**, plotted over the range **x = -10 to x = 10**.
#
# The graph will show:
# - The cubic nature of the function
# - Key features such as turning points and asymmetry

# %% [markdown]
# ## Define and Plot a Sine Function
#
# Here’s the corrected Markdown version with the code fixed to display "Hello, Space Explorer!" and to properly define the function for plotting:
#
# # Hello, Space Explorer!
#
# Let's dive into trigonometric functions by defining and plotting
# \( f(x) = \sin x \). Complete the given code to define this function and visualize it within the range
# \(-2\pi\) to \(2\pi\). This will help you understand how trigonometric functions behave.
#
# You've got this!

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the trigonometric function
def trig_function(x):
    # Complete the function definition
    return np.sin(x)  # Calculate the sin of x using numpy

# Generate x values
x = np.linspace(-2 * np.pi, 2 * np.pi, 400)
# Generate y values using the function
y = trig_function(x)

# Plot the function
plt.plot(x, y, label='f(x) = sin(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the Function f(x) = sin(x)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Modify Quadratic Function to Vertex at Origin
#
# Here’s the corrected Markdown version with the code fixed to display "Hello, Space Voyager!" and properly modify the quadratic function to place its vertex at the origin:
#
# # Hello, Space Voyager!
#
# You have a quadratic function with given coefficients that place its vertex away from the origin. Your mission is to modify these coefficients so that the vertex moves to the origin \((0, 0)\). Use plotting to understand how different coefficients affect the function's shape and position.
#
# You can do it!

# %%
import matplotlib.pyplot as plt
import numpy as np

# Original function
def original_function(x):
    return x**2 + 2*x + 1

# Modified function with vertex at the origin (0, 0)
def modified_function(x):
    # Modify the coefficients such that the vertex is at the origin
    return x**2  # Vertex at (0, 0) achieved by removing linear and constant terms

# Generate x values
x = np.linspace(-10, 10, 400)
# Generate y values using the original function
y_original = original_function(x)
# Generate y values using the modified function
y_modified = modified_function(x)

# Plot the original function
plt.plot(x, y_original, label='Original f(x) = x^2 + 2*x + 1')
# Plot the modified function
plt.plot(x, y_modified, label='Modified f(x) = x^2')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the Original and Modified Functions')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Modeling Temperature Change Over a Day
#
# Here’s the corrected Markdown version with the code fixed to display "Hello, Space Voyager!" and properly define the temperature function for plotting:
#
# # Hello, Space Voyager!
#
# Imagine you are an astronomer tracking the temperature changes over a day. The temperature follows a sine function given by:
# $$
# T(h) = 15 + 10 \sin\left(\frac{\pi}{12}(h - 5)\right)
# $$
# where \(h\) is the number of hours since midnight. Your task is to complete the code to define this function and plot it over a 24-hour period.
#
# Let's explore the temperature variations in a day!

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the temperature function
def temperature_function(h):
    return 15 + 10 * np.sin((np.pi / 12) * (h - 5))

# Generate hour values
h = np.linspace(0, 24, 400)
# Generate temperature values using the function
T = temperature_function(h)

# Plot the function
plt.plot(h, T, label=r'T(h) = 15 + 10sin($\frac{\pi}{12}(h - 5)$)')
plt.xlabel('Hour (h)')
plt.ylabel('Temperature (°C)')
plt.title('Temperature Change Over a Day')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plotting Maintenance Cost of a Garden
#
# Here’s the corrected Markdown version with the code fixed to display "Hello, Space Explorer!" and properly define the function for plotting:
#
# # Hello, Space Explorer!
#
# Imagine you have a garden, and maintaining it costs money. The cost \(C(x)\) depends on the number of plants \(x\). Use the linear function:
# $C(x) = 5x + 20$
#
# to determine the total cost. Plot this function for the number of plants ranging from 0 to 100.
#
# You can do it!

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function for the cost of maintaining the garden
def garden_cost(x):
    return 5 * x + 20

# Generate x values
x = np.linspace(0, 100, 400)
# Generate y values using the function
y = garden_cost(x)

# Plot the function
plt.plot(x, y, label='C(x) = 5x + 20')
plt.xlabel('Number of plants (x)')
plt.ylabel('Total cost (C(x))')
plt.title('Cost of Maintaining a Garden')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plotting a Complex Mathematical Function
#
# Ah, thanks for pointing that out! Let me fix the Markdown and adjust the code to reflect the correct function \( f(x) = \frac{e^x}{\sin(x) + 1} \). Here's the updated Markdown and code:
#
#
# # Hey there, Space Voyager!
#
# Your mission is to complete the code to plot a more complex function:
# $$
# f(x) = \frac{e^x}{\sin(x) + 1}
# $$
#
# Fill in the missing parts and ensure the plot displays correctly. This exercise will solidify your understanding of how different mathematical functions can be combined and visualized.
#
# Good luck, and let's code!
#
# ```python
# import matplotlib.pyplot as plt
# import numpy as np
#
# # Define the function
# def complex_function(x):
#     # Avoid division by zero by adding a small constant where sin(x) + 1 = 0
#     return np.exp(x) / (np.sin(x) + 1 + 1e-9)
#
# # Generate x values
# x = np.linspace(-10, 10, 400)
# # Generate y values using the function
# y = complex_function(x)
#
# # Plot the function
# plt.plot(x, y, label=r'$f(x) = \frac{e^x}{\sin(x) + 1}$')
# plt.xlabel('x')
# plt.ylabel('f(x)')
# plt.title('Plot of the Function $f(x) = \frac{e^x}{\sin(x) + 1}$')
# plt.legend()
# plt.grid(True)
# plt.show()
# ```
#
#
# ### Explanation of Changes:
# 1. **Correct Formula**: Updated the function to match \( f(x) = \frac{e^x}{\sin(x) + 1} \).
# 2. **Avoid Division by Zero**: Added a small constant \( 1e-9 \) to prevent division errors when \( \sin(x) + 1 \) is zero.
# 3. **LaTeX in Plot**: Used raw strings (`r''`) for labels to correctly display mathematical expressions in the plot.
#
# Let me know if you need further refinements! 🚀

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the function
def complex_function(x):
    return np.exp(x) * np.sin(x) + 1

# Generate x values
x = np.linspace(-10, 10, 400)
# Generate y values using the function
y = complex_function(x)

# Plot the function
plt.plot(x, y, label='f(x) = e^x sin(x) + 1')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the Function f(x) = e^x sin(x) + 1')
plt.legend()
plt.grid(True)
plt.show()

# %%
def complex_function(x):
    # Avoid division by zero by adding a small constant where sin(x) + 1 = 0
    return np.exp(x) / (np.sin(x) + 1 + 1e-9)

# Generate x values
x = np.linspace(-10, 10, 400)
# Generate y values using the function
y = complex_function(x)

# Plot the function
plt.plot(x, y, label=r'f(x) = \frac{e^x}{\sin(x) + 1}')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of the Function f(x) = \frac{e^x}{\sin(x) + 1}')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# <>:14: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_249939/3532002724.py:14: SyntaxWarning: invalid escape sequence '\s'
#   plt.title('Plot of the Function f(x) = \frac{e^x}{\sin(x) + 1}')
# /home/teguhteja/miniconda3/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 12 () missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
