# %% [markdown]
# # Unit 3

# %% [markdown]
# ## Plan Mode Task Delegation

# %% [markdown]
# ## Delegating Verbose Work to Task Subagents

# %% [markdown]
# ## Delegating Verbose Work to Task Subagents
